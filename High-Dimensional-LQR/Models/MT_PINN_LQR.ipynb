# %% [markdown]
# **RAN ON GOOGLE COLAB**

# %%
# !pip install ml-collections
# Out:
# Collecting ml-collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml-collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: ml-collections
# Successfully installed ml-collections-1.1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
from jax import grad, vmap
from flax import linen as nn
import optax
import matplotlib.pyplot as plt
import numpy as np
from typing import Any, Callable, Dict, Optional, Sequence, Tuple, Union
from jax.nn.initializers import glorot_normal, normal, zeros
from jax import jit, random as jran
import ml_collections
from flax.training import train_state
import pickle
import time
from jax import jit, value_and_grad
import pandas as pd
import seaborn as sns
import orbax.checkpoint as ocp
import os, json, time, pickle, shutil

# %%
import jax.numpy as jnp

dtype=jnp.float32
dim = 20
shift_factor= 0.1
# Base 4×4 prototype (Ntogramatzidis, 2003)
A_base = jnp.array([
    [-8.95,  -6.45,   0.00,   0.00],
    [ 2.15,  -0.35,   0.00,   0.00],
    [-10.89, -40.94, -16.10, -7.95],
    [ 8.17,  28.87,   7.07,  -0.20]
], dtype=dtype)

B_base = jnp.array([
    [1., 0.],
    [0., 0.],
    [0., 1.],
    [1., 1.]
], dtype=dtype)

Q_base = jnp.array([
    [ 5.,  4., 13., 16.],
    [ 4.,  5., 11., 14.],
    [13., 11., 34., 42.],
    [16., 14., 42., 52.]
], dtype=dtype)

R_base = jnp.eye(2, dtype=dtype)

S_base = jnp.array([
    [1., 2.],
    [2., 1.],
    [3., 5.],
    [4., 6.]
], dtype=dtype)

# Small utility: block-diagonal assembly 
def blkdiag(*blocks):
    n = len(blocks)
    return jnp.block([
        [blocks[i] if i == j else jnp.zeros((blocks[i].shape[0], blocks[j].shape[1]), dtype=dtype)
            for j in range(n)]
        for i in range(n)
    ])

full = dim // 4         # number of full 4×4 blocks
rem  = dim % 4          # size of the final truncated block 
n_blocks = full + (1 if rem > 0 else 0)

A_blocks, B_blocks, Q_blocks, R_blocks, S_blocks = [], [], [], [], []

for j in range(n_blocks):
    # block size r: 4 for full blocks; 'rem' for the last (if rem > 0)
    r = 4 if (j < full) else (rem if rem > 0 else 4)

    # slice top-left sub-blocks of proper size
    A_j = A_base[:r, :r]
    B_j = B_base[:r, :]          # r×2
    Q_j = Q_base[:r, :r]
    S_j = S_base[:r, :]          # r×2
    R_j = R_base                 # 2×2

    # vary dynamics slightly per block with a diagonal shift
    shift = shift_factor * (j + 1)
    A_j = A_j - shift * jnp.eye(r, dtype=dtype)

    A_blocks.append(A_j)
    B_blocks.append(B_j)
    Q_blocks.append(Q_j)
    R_blocks.append(R_j)
    S_blocks.append(S_j)

# assemble big block-diagonal matrices
A = blkdiag(*A_blocks)                      # (dim, dim)
B = blkdiag(*B_blocks)                      # (dim, 2*n_blocks)
Q = blkdiag(*Q_blocks)                      # (dim, dim)
R = blkdiag(*R_blocks)                      # (2*n_blocks, 2*n_blocks)
S = blkdiag(*S_blocks)                      # (dim, 2*n_blocks)

#  shape checks 
print(A.shape == (dim, dim), f"A shape {A.shape} != {(dim, dim)}")
print(Q.shape == (dim, dim), f"Q shape {Q.shape} != {(dim, dim)}")
print(B.shape[0] == dim and S.shape[0] == dim, "B/S row dims must match 'dim'")
print(R.shape[0] == R.shape[1] == 2 * n_blocks, "R must be 2×2 per block")
# Out:
# Shapes -> A: (20, 20) B: (20, 10) Q: (20, 20) R: (10, 10) S: (20, 10)
# R SPD?: True
# Popov (Q - S R^{-1} S^T) >= 0 ? True
# x0 in [-4,4] and integer? True int32

# %%
"""Step 1: NN definition (see Kentaro DC_PINNs_IVS_calibration.ipynb)"""
activation_fn = {
    "tanh": jnp.tanh,
    "sin": jnp.sin,
}

def _get_activation(str):
    if str in activation_fn:
        return activation_fn[str]

    else:
        raise NotImplementedError(f"Activation {str} not supported yet!")

def _weight_fact(init_fn, mean, stddev):
    def init(key, shape):
        key1, key2 = jran.split(key)
        w = init_fn(key1, shape)
        g = mean + normal(stddev)(key2, (shape[-1],))
        g = jnp.exp(g)
        v = w / g
        return g, v

    return init

class Dense(nn.Module):
    features: int
    kernel_init: Callable = glorot_normal()
    bias_init: Callable = zeros
    reparam: Union[None, Dict] = None

    @nn.compact
    def __call__(self, x):
        if self.reparam is None:
            kernel = self.param(
                "kernel", self.kernel_init, (x.shape[-1], self.features)
            )

        elif self.reparam["type"] == "weight_fact":
            g, v = self.param(
                "kernel",
                _weight_fact(
                    self.kernel_init,
                    mean=self.reparam["mean"],
                    stddev=self.reparam["stddev"],
                ),
                (x.shape[-1], self.features),
            )
            kernel = g * v
        bias = self.param("bias", self.bias_init, (self.features,))
        y = jnp.dot(x, kernel) + bias

        return y

class MLP(nn.Module):
    arch_name: Optional[str]="MLP"
    hidden_dim: Tuple[int]=(32, 16)
    out_dim: int=1
    activation: str="tanh"
    periodicity: Union[None, Dict]=None
    fourier_emb: Union[None, Dict]=None
    reparam: Union[None, Dict]=None

    def setup(self):
        self.activation_fn = _get_activation(self.activation)

    @nn.compact
    def __call__(self, x):
        for i in range(len(self.hidden_dim)):
            x = Dense(features=self.hidden_dim[i], reparam=self.reparam)(x)
            x = self.activation_fn(x)
        x = Dense(features=self.out_dim, reparam=self.reparam)(x)
        return x



def ann_gen(config):
    ann = None
    reparam = None
    if config.ann_reparam=="weight_fact":
        reparam = ml_collections.ConfigDict({"type": "weight_fact", "mean": 0.5, "stddev": 0.1})

    if config.ann_str == "MLP":
        ann = MLP(arch_name=config.ann_str,
                  hidden_dim=config.ann_hidden_dim,
                  out_dim=config.ann_out_dim,
                  activation=config.ann_activation_str,
                  periodicity=config.ann_periodicity,
                  fourier_emb=config.ann_fourier_emb,
                  reparam=reparam)

    return ann


optimizer = "Adam"
beta1 = 0.9
beta2 = 0.999
eps = 1e-8
learning_rate = 1e-3
decay_rate = 0.9
decay_steps = 2000
grad_accum_steps = 0

lr = optax.exponential_decay(
        init_value=learning_rate,
        transition_steps=decay_steps,
        decay_rate=decay_rate,
    )
tx = optax.adam(
    learning_rate=lr, b1=beta1, b2=beta2, eps=eps
)


#####################################################################################
#####################################################################################


def derivatives(fn, x):
    def f(z):
        y = fn(z)             
        return y.squeeze()    
    J = jax.vmap(jax.jacrev(f))(x)   
    return J[:, 0], J[:, 1:]


def quad_form(v, M):
    """Compute v^T M v for each sample in a batch.
       v: (batch, d) M: (d, d) -> (batch,)"""
    return jnp.einsum('bi,ij,bj->b', v, M, v)

def bilinear(u, M, x):
    """Compute u^T M x per sample."""
    return jnp.einsum('bi,ij,bj->b', u, M, x)

def u_star_batch(fn, t_batch, X_batch, A, B, R, S):
    Z = jnp.hstack([t_batch, X_batch]) # (B, 1+d)

    _, V_x = derivatives(fn, Z)

    VB = V_x @ B # (B,m)
    XS = X_batch @ S # (B,m)
    W  = VB + 2.0 * XS # (B,m)

    u = -0.5 * jnp.linalg.solve(R, W.T).T # (B,m)
    return u

def quad_form_solve(v, M):
    """
    Return diag(v @ M^{-1} @ v^T) for a batch.
    v : (batch, m)
    M : (m, m)
    """
    y = jnp.linalg.solve(M, v.T).T # (batch, m) 
    return jnp.einsum('bi,bi->b', v, y)

def single_path_penalty(fn, *, X0, T, Ndt, A, B, R, S):
    dt = T / Ndt # (P,1)
    X0 = jnp.atleast_2d(jnp.asarray(X0, dtype=jnp.float32))

    P, d = X0.shape

    t0 = jnp.zeros((P, 1), dtype=X0.dtype)

    def step(carry, _):
        X, t = carry
        # X:(P,4) t:(P,1)
        tau = T - t
        u = u_star_batch(fn, tau, X, A, B, R, S) # (P,2)
        # A x + B u
        Ax   = jnp.einsum('bi,ji->bj', X, A) # (P,4)
        Bu   = jnp.einsum('bi,ji->bj', u, B) # (P,4)  
        Xdot = Ax + Bu
        X_next = X + dt * Xdot
        t_next = t + dt
        return (X_next, t_next), None

    (X_T, _), _ = jax.lax.scan(step, (X0, t0), None, length=int(Ndt))

    r = jnp.linalg.norm(X_T, axis=1) # (P,)
    loss_per_path = jnp.where(r <= 1.0, r, r**2)
    return jnp.mean(loss_per_path)


def multi_traj_penalty(fn, *, X0, T_list, A, B, R, S, Ndt=50, weights=None):
    T_list = jnp.atleast_1d(jnp.array(T_list))

    penalties = jax.vmap(lambda Ti: single_path_penalty(
        fn, X0=X0, T=Ti, Ndt=Ndt, A=A, B=B, R=R, S=S))(T_list)

    if weights is not None:
        w = jnp.array(weights)
        w = w / jnp.sum(w)
        return jnp.sum(w * penalties)
    return jnp.mean(penalties)

def error(fn, data, Q, A, B, R, S):
    x_tau_pde, x_term_zero, T, X0_batch = data
    tau = x_tau_pde[:, :1]                 
    X   = x_tau_pde[:, 1:]
    Z   = jnp.hstack([tau, X])

    V_tau, V_x = derivatives(fn, Z)        
    term_AX = bilinear(V_x, A, X)
    term_Q  = quad_form(X, Q)
    W       = V_x @ B + 2.0 * (X @ S)
    term_R  = 0.25 * quad_form_solve(W, R)

    # PDE residual
    e_pde = (V_tau + term_AX + term_Q - term_R) ** 2  # τ-form HJB

    # Terminal condition
    e_term_zero = jnp.squeeze(fn(x_term_zero))**2

    # Trajectory penalty
    e_traj = multi_traj_penalty(fn, X0=X0_batch, T_list=jnp.array([T]),
                                A=A, B=B, R=R, S=S, Ndt=50)
    return {"e_pde": e_pde, "e_term_zero": e_term_zero, "e_traj": e_traj}, {
        "e_pde": jnp.mean(e_pde), "e_term_zero": jnp.mean(e_term_zero), "e_traj": e_traj
    }

#####################################################################################
#####################################################################################


def adj(loss, lw, m):  
    return lw * jnp.mean(m * loss)

ALL_COMPONENTS = ['e_pde','e_term_zero', 'e_traj']

def make_loss_lb():
    def loss_fn(config, fn, data, l_ws, params_sa):
        err, metrics = error(fn, data, Q, A, B, R, S)
        loss_terms = {}
        for k in ALL_COMPONENTS:
            if k in err:
                w_k = l_ws.get(k, 1.0)
                m_k = params_sa.get(k, jnp.ones_like(err[k]))
                loss_terms[k] = adj(err[k], w_k, m_k)
        return loss_terms, metrics
    return loss_fn

loss_fn_lb = { "MLP": make_loss_lb(), "PINN": make_loss_lb() }

def make_loss_fn(components_key):
    def loss_fn(config, fn, data, l_ws, params_sa):
        loss_terms, metrics = loss_fn_lb[components_key](config, fn, data, l_ws, params_sa)
        total = jnp.sum(jnp.array(list(loss_terms.values())))
        return total, metrics
    return loss_fn

loss_fn = { "MLP": make_loss_fn("MLP"), "PINN": make_loss_fn("PINN") }

def init_params_sa(loss_str, data):
    x_tau_pde, x_term_zero, _, _ = data

    return {
        "MLP": {'e_pde': jnp.ones(len(x_tau_pde))},
        "PINN": {
            'e_pde': jnp.ones(len(x_tau_pde)),
            'e_term_zero': jnp.ones(len(x_term_zero)),
            'e_traj': jnp.ones(1)

        }
    }[loss_str]

# Initial static weights
init_l_ws = {
    "PINN": {
        'e_pde': 1.,
        'e_term_zero': 0.1,
        'e_traj': 1.,
    }
}


#####################################################################################
#####################################################################################

def sample_X0_near(key, x0, n_samples, radius=1, low=-2, high=2):
    """
    Sample integer vectors near x0 within [-radius, radius] per coordinate,
    clipped to [low, high].

    x0:       (d,) test vector
    n_samples number of extra X0 to generate
    radius:   max integer change per coordinate
    low/high: value bounds for each coordinate
    """
    x0 = jnp.asarray(x0)
    d  = x0.shape[0]
    deltas = jax.random.randint(key, (n_samples, d), -radius, radius+1)
    return jnp.clip(x0 + deltas, low, high).astype(jnp.float32)

def get_data(n_pde=1000, n_term_zero=50, T=1.0, x_ranges=[(-4, 4)]*4, seed=0):
    rng = np.random.default_rng(seed)
    d   = len(x_ranges)                    

    # PDE collocation points
    tau_pde = rng.uniform(1e-3, T, size=(n_pde, 1))          # τ in (0,T]
    x_pde   = np.hstack([rng.uniform(lo, hi, (n_pde, 1)) for lo, hi in x_ranges])
    x_tau_pde = np.hstack([tau_pde, x_pde])

    # terminal points
    x_term_zero = np.hstack([np.zeros((n_term_zero, 1)), np.zeros((n_term_zero, d))])

    x0_test = jnp.array([
        1, -2,  0,  2,
        -1,  2, -2,  2,
        0, -2,  1, -1,
        2,  0,  2, -2,
        2, -2,  1,  0
        ], dtype=jnp.float32)


    key = jax.random.PRNGKey(seed)
    # Sample initial points near x0_test
    X0_batch = sample_X0_near(key, x0_test, n_samples=100, radius=1, low=-2, high=2)
    return jnp.array(x_tau_pde), jnp.array(x_term_zero), T, X0_batch



#####################################################################################
#####################################################################################

# Rebalancer 
class Rebalancer:
    def __init__(
        self, keys,
        ema_beta=0.95,
        power=0.2,
        w_clip=(0.5, 2.0),
        ema_floor=1e-4,
        allow_upweight_small=False,
        freeze_tol=1e-5,
        freeze_patience=10,
        base_weights=None,
        static_keys=None,
        relative_to_init=True,
        eps=1e-12,
    ):
        self.keys = list(keys)
        self.ema_beta = float(ema_beta)
        self.power = float(power)
        self.w_min, self.w_max = map(float, w_clip)
        self.ema_floor = float(ema_floor)
        self.allow_upweight_small = bool(allow_upweight_small)
        self.freeze_tol = float(freeze_tol)
        self.freeze_patience = int(freeze_patience)
        self.base_weights = dict(base_weights or {})
        self.static_keys = set(static_keys or ())
        self.relative_to_init = bool(relative_to_init)
        self.eps = float(eps)
        self.ema = {k: None for k in self.keys}
        self.init_ema = {k: None for k in self.keys}
        self.below_ctr = {k: 0 for k in self.keys}
        self.frozen = {k: False for k in self.keys}

    def _smooth_update(self, old, new):
        if old is None:
            return new
        return self.ema_beta * old + (1.0 - self.ema_beta) * new

    def step(self, metrics, weights):
        for k in self.keys:
            if k not in metrics:
                continue
            val = float(metrics[k])
            val = max(val, self.ema_floor)
            self.ema[k] = self._smooth_update(self.ema[k], val)
            if self.init_ema[k] is None:
                self.init_ema[k] = self.ema[k]
            if self.ema[k] < self.freeze_tol:
                self.below_ctr[k] += 1
            else:
                self.below_ctr[k] = 0
            if self.freeze_patience > 0 and self.below_ctr[k] >= self.freeze_patience:
                self.frozen[k] = True

        present = [k for k in self.keys
                   if (k in metrics and self.ema[k] is not None and not self.frozen[k] and k not in self.static_keys)]
        if not present:
            new_w = dict(weights)
            for k in self.keys:
                if self.frozen[k]:
                    new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
            return new_w

        def rel_ema(k):
            if not self.relative_to_init:
                return max(self.ema[k], self.ema_floor)
            denom = max(self.init_ema[k] or self.ema_floor, self.ema_floor)
            return max(self.ema[k] / denom, self.ema_floor)

        rels = {k: rel_ema(k) for k in present}
        gmean = float(np.exp(np.mean([np.log(max(rels[k], self.eps)) for k in present])))

        new_w = dict(weights)
        for k in self.keys:
            if self.frozen[k]:
                new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
                continue
            if k in self.static_keys or k not in rels:
                new_w[k] = float(new_w.get(k, 1.0))
                continue
            ratio = max(rels[k] / gmean, self.eps)
            mult = 1.0 if (not self.allow_upweight_small and ratio < 1.0) else ratio ** (-self.power)
            new_w[k] = float(np.clip(new_w.get(k, 1.0) * mult, self.w_min, self.w_max))

        mean_w = float(np.mean([new_w[k] for k in present])) if present else 1.0
        if mean_w > 0:
            for k in present:
                new_w[k] = new_w[k] / mean_w
        return new_w


#####################################################################################
#####################################################################################

# ====== Training ======
def calibration(config, data, params_init=None, l_ws=None, params_sa=None):
    ann = ann_gen(config)
    ofunc = loss_fn[config.loss_str]

    if l_ws is None:
        l_ws = dict(init_l_ws[config.loss_str])
    if params_sa is None:
        params_sa = init_params_sa(config.loss_str, data)

    rebal_cfg = getattr(config, "rebal", None)
    if rebal_cfg is None:
        rebal_cfg = ml_collections.ConfigDict({})

    rebal = Rebalancer(
        keys=[k for k in ALL_COMPONENTS if k in (params_sa.keys())],
        ema_beta=getattr(rebal_cfg, "ema_beta", 0.98),
        power=getattr(rebal_cfg, "power", 0.2),
        w_clip=tuple(getattr(rebal_cfg, "w_clip", (0.3, 3.0))),
        ema_floor=getattr(rebal_cfg, "ema_floor", 1e-3),
        allow_upweight_small=getattr(rebal_cfg, "allow_upweight_small", False),
        freeze_tol=getattr(rebal_cfg, "freeze_tol", 1e-4),
        freeze_patience=getattr(rebal_cfg, "freeze_patience", 10),
        static_keys=set(getattr(rebal_cfg, "static_keys", ())),
        relative_to_init=getattr(rebal_cfg, "relative_to_init", True),
    )

    key = jran.PRNGKey(config.seed)
    _, key_init = jran.split(key, 2)
    dummy = jnp.ones((1, config.ann_in_dim))
    params0 = ann.init(key_init, dummy) if params_init is None else params_init

    state = train_state.TrainState.create(
        apply_fn=ann.apply,
        params=params0,
        tx=optax.adamw(learning_rate=1e-4)
    )

    @jit
    def train_step(state, data, l_ws, params_sa):
        def wrapped_loss(params):
            def fn(x): return ann.apply(params, x)
            return ofunc(config, fn, data, l_ws, params_sa)
        (loss, metrics), grads = value_and_grad(wrapped_loss, has_aux=True)(state.params)
        state = state.apply_gradients(grads=grads)
        return state, loss, metrics

    hist = []
    start_epoch = getattr(rebal_cfg, "start_epoch", 0)
    every = getattr(rebal_cfg, "every", 1000)

    for epoch in range(config.num_epochs):
        state, loss, metrics = train_step(state, data, l_ws, params_sa)
        if (epoch >= start_epoch) and ((epoch - start_epoch) % every == 0):
            l_ws = rebal.step(metrics, l_ws)
        if epoch % 100 == 0:
            w_str = "{"+", ".join(f"{k}:{l_ws.get(k,1.0):.3g}" for k in sorted(l_ws.keys()))+"}"
            keys = ['e_pde','e_term_zero', 'e_traj']
            msg  = " | ".join(f"{k}={float(metrics[k]):.6f}" for k in keys if k in metrics)
            print(f"Epoch {epoch}: total={float(loss):.6f} | {msg} | w={w_str}")
        hist.append((int(epoch), float(loss), {k: float(metrics[k]) for k in metrics}))

    return (lambda x: ann.apply(state.params, x)), hist, state.params, ann


# saving helpers
def save_params_overwrite(path, params):
    path = os.path.abspath(path)
    if os.path.exists(path):
        shutil.rmtree(path)
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    try:
        ckptr.save(path, params, force=True)
    except TypeError:
        ckptr.save(path, params)

def _to_jsonable(obj):
    if isinstance(obj, ml_collections.ConfigDict):
        return {k: _to_jsonable(v) for k, v in obj.items()}
    if isinstance(obj, dict):
        return {k: _to_jsonable(v) for k, v in obj.items()}
    if isinstance(obj, (list, tuple)):
        return [_to_jsonable(v) for v in obj]
    if isinstance(obj, (str, int, float, bool)) or obj is None:
        return obj
    return str(obj)

def save_stage(run_dir, tag, *, params, config, history):
    run_dir = os.path.abspath(run_dir)
    os.makedirs(run_dir, exist_ok=True)
    save_params_overwrite(os.path.join(run_dir, f"{tag}_params"), params)
    with open(os.path.join(run_dir, f"{tag}_config.json"), "w") as f:
        json.dump(_to_jsonable(config), f, indent=2)
    with open(os.path.join(run_dir, f"{tag}_history.pkl"), "wb") as f:
        pickle.dump(history, f)

def restore_params(run_dir, tag):
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    return ckptr.restore(os.path.abspath(os.path.join(run_dir, f"{tag}_params")))



def run_experiment(config, workdir=None):
    wd = os.path.abspath(workdir or getattr(config, "workdir", "runs/pinn_LQR"))
    os.makedirs(wd, exist_ok=True)
    data = get_data(
        n_pde=config.pts_num,
        n_term_zero=config.n_term_zero,
        T=config.T,
        x_ranges=config.x_ranges,
        seed=config.seed,
    )

    _, hist, params, _ = calibration(config, data)
    tag = f"MT-PINN_LQR"

    save_stage(wd, tag, params=params, config=config, history=hist)
    return params, {tag: hist}



#####################################################################################
#####################################################################################

# Config
config_PINN = ml_collections.ConfigDict({
    "pts_num": 30000,
    "n_term_zero": 1000,
    "x_ranges": [(-2, 2)] * 20,  
    "T": 1.0,
    "seed": 42,
    "ann_str": "MLP",
    "loss_str": "PINN",
    "num_epochs": 50000,  
    "ann_in_dim": 21,  
    "ann_out_dim": 1,
    "ann_activation_str": "tanh",
    "ann_periodicity": None,
    "ann_fourier_emb": None,
    "ann_reparam": False,
    "ann_hidden_dim": (128, 128, 128),
    "workdir": os.path.abspath("runs/pinn_LQR"),
    "rebal": ml_collections.ConfigDict({
        "start_epoch": 500,
        "every": 5000,
        "ema_beta": 0.9,
        "power": 0.3,
        "w_clip": (0.1, 5.0),
    }),

})

def build_model_fn(config, params):
    ann = ann_gen(config)
    return jax.jit(lambda x: ann.apply(params, x))

final_params, all_hist = run_experiment(config_PINN, workdir=config_PINN.workdir)
model_PINN = build_model_fn(config_PINN, final_params)
# Out:
# Epoch 0: total=154.313370 | e_pde=153.679535 | e_term_zero=0.000000 | e_traj=0.633828 | w={e_pde:1, e_term_zero:0.1, e_traj:1}
# Epoch 100: total=12.104628 | e_pde=11.405900 | e_term_zero=0.002344 | e_traj=0.698493 | w={e_pde:1, e_term_zero:0.1, e_traj:1}
# Epoch 200: total=6.148886 | e_pde=5.443377 | e_term_zero=0.000187 | e_traj=0.705491 | w={e_pde:1, e_term_zero:0.1, e_traj:1}
# Epoch 300: total=3.965752 | e_pde=3.257679 | e_term_zero=0.000001 | e_traj=0.708073 | w={e_pde:1, e_term_zero:0.1, e_traj:1}
# Epoch 400: total=2.961757 | e_pde=2.252255 | e_term_zero=0.000047 | e_traj=0.709497 | w={e_pde:1, e_term_zero:0.1, e_traj:1}
# Epoch 500: total=2.417915 | e_pde=1.707290 | e_term_zero=0.000074 | e_traj=0.710618 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 600: total=2.838758 | e_pde=1.275808 | e_term_zero=0.000055 | e_traj=0.711317 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 700: total=2.468810 | e_pde=1.016337 | e_term_zero=0.000030 | e_traj=0.711827 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 800: total=2.227208 | e_pde=0.847038 | e_term_zero=0.000014 | e_traj=0.712006 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 900: total=2.058736 | e_pde=0.728998 | e_term_zero=0.000010 | e_traj=0.712116 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1000: total=1.933588 | e_pde=0.641365 | e_term_zero=0.000006 | e_traj=0.712146 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1100: total=1.837600 | e_pde=0.574091 | e_term_zero=0.000005 | e_traj=0.712228 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1200: total=1.761829 | e_pde=0.521039 | e_term_zero=0.000004 | e_traj=0.712241 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1300: total=1.701170 | e_pde=0.478617 | e_term_zero=0.000002 | e_traj=0.712201 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1400: total=1.650885 | e_pde=0.443408 | e_term_zero=0.000002 | e_traj=0.712211 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1500: total=1.610018 | e_pde=0.414727 | e_term_zero=0.000001 | e_traj=0.712285 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1600: total=1.575087 | e_pde=0.390354 | e_term_zero=0.000001 | e_traj=0.712207 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1700: total=1.545750 | e_pde=0.369824 | e_term_zero=0.000000 | e_traj=0.712201 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1800: total=1.520588 | e_pde=0.352203 | e_term_zero=0.000000 | e_traj=0.712208 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 1900: total=1.498536 | e_pde=0.336808 | e_term_zero=0.000000 | e_traj=0.712168 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2000: total=1.479792 | e_pde=0.323723 | e_term_zero=0.000000 | e_traj=0.712131 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2100: total=1.462875 | e_pde=0.311912 | e_term_zero=0.000000 | e_traj=0.712101 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2200: total=1.448402 | e_pde=0.301795 | e_term_zero=0.000000 | e_traj=0.712086 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2300: total=1.435494 | e_pde=0.292719 | e_term_zero=0.000000 | e_traj=0.712127 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2400: total=1.423599 | e_pde=0.284484 | e_term_zero=0.000000 | e_traj=0.712035 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2500: total=1.413157 | e_pde=0.277192 | e_term_zero=0.000000 | e_traj=0.712018 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2600: total=1.404283 | e_pde=0.270995 | e_term_zero=0.000000 | e_traj=0.712003 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2700: total=1.396056 | e_pde=0.265213 | e_term_zero=0.000000 | e_traj=0.712026 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2800: total=1.388617 | e_pde=0.260080 | e_term_zero=0.000000 | e_traj=0.711951 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 2900: total=1.382010 | e_pde=0.255446 | e_term_zero=0.000000 | e_traj=0.711961 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3000: total=1.375520 | e_pde=0.250910 | e_term_zero=0.000000 | e_traj=0.711954 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3100: total=1.370090 | e_pde=0.247170 | e_term_zero=0.000000 | e_traj=0.711893 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3200: total=1.364855 | e_pde=0.243546 | e_term_zero=0.000000 | e_traj=0.711852 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3300: total=1.360040 | e_pde=0.240198 | e_term_zero=0.000000 | e_traj=0.711830 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3400: total=1.355669 | e_pde=0.237178 | e_term_zero=0.000000 | e_traj=0.711790 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3500: total=1.351676 | e_pde=0.234404 | e_term_zero=0.000000 | e_traj=0.711769 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3600: total=1.348060 | e_pde=0.231864 | e_term_zero=0.000000 | e_traj=0.711777 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3700: total=1.344564 | e_pde=0.229510 | e_term_zero=0.000000 | e_traj=0.711685 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3800: total=1.341450 | e_pde=0.227383 | e_term_zero=0.000000 | e_traj=0.711632 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 3900: total=1.338421 | e_pde=0.225287 | e_term_zero=0.000000 | e_traj=0.711608 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4000: total=1.335582 | e_pde=0.223380 | e_term_zero=0.000000 | e_traj=0.711527 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4100: total=1.332870 | e_pde=0.221651 | e_term_zero=0.000000 | e_traj=0.711358 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4200: total=1.330259 | e_pde=0.219871 | e_term_zero=0.000000 | e_traj=0.711310 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4300: total=1.328067 | e_pde=0.218418 | e_term_zero=0.000000 | e_traj=0.711229 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4400: total=1.325604 | e_pde=0.216788 | e_term_zero=0.000000 | e_traj=0.711134 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4500: total=1.323540 | e_pde=0.215422 | e_term_zero=0.000000 | e_traj=0.711057 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4600: total=1.321563 | e_pde=0.214124 | e_term_zero=0.000000 | e_traj=0.710970 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4700: total=1.319663 | e_pde=0.212878 | e_term_zero=0.000000 | e_traj=0.710886 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4800: total=1.317836 | e_pde=0.211744 | e_term_zero=0.000000 | e_traj=0.710741 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 4900: total=1.316401 | e_pde=0.210814 | e_term_zero=0.000000 | e_traj=0.710667 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5000: total=1.314205 | e_pde=0.209472 | e_term_zero=0.000000 | e_traj=0.710472 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5100: total=1.312560 | e_pde=0.208392 | e_term_zero=0.000000 | e_traj=0.710400 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5200: total=1.310841 | e_pde=0.207329 | e_term_zero=0.000000 | e_traj=0.710260 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5300: total=1.309350 | e_pde=0.206415 | e_term_zero=0.000000 | e_traj=0.710131 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5400: total=1.308677 | e_pde=0.206077 | e_term_zero=0.000000 | e_traj=0.709997 | w={e_pde:1.43, e_term_zero:0.143, e_traj:1.43}
# Epoch 5500: total=1.306087 | e_pde=0.204607 | e_term_zero=0.000000 | e_traj=0.709654 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 5600: total=1.301942 | e_pde=0.203912 | e_term_zero=0.000000 | e_traj=0.709569 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 5700: total=1.300245 | e_pde=0.202962 | e_term_zero=0.000000 | e_traj=0.709335 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 5800: total=1.298495 | e_pde=0.202047 | e_term_zero=0.000000 | e_traj=0.709028 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 5900: total=1.296927 | e_pde=0.201083 | e_term_zero=0.000000 | e_traj=0.708898 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6000: total=1.295734 | e_pde=0.200462 | e_term_zero=0.000000 | e_traj=0.708686 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6100: total=1.294178 | e_pde=0.199588 | e_term_zero=0.000000 | e_traj=0.708474 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6200: total=1.292850 | e_pde=0.198897 | e_term_zero=0.000000 | e_traj=0.708238 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6300: total=1.291286 | e_pde=0.198109 | e_term_zero=0.000000 | e_traj=0.707933 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6400: total=1.290033 | e_pde=0.197583 | e_term_zero=0.000000 | e_traj=0.707583 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6500: total=1.288113 | e_pde=0.196797 | e_term_zero=0.000000 | e_traj=0.707027 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6600: total=1.286578 | e_pde=0.196041 | e_term_zero=0.000000 | e_traj=0.706711 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6700: total=1.285521 | e_pde=0.195630 | e_term_zero=0.000000 | e_traj=0.706382 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6800: total=1.283791 | e_pde=0.194792 | e_term_zero=0.000000 | e_traj=0.706011 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 6900: total=1.281890 | e_pde=0.193956 | e_term_zero=0.000000 | e_traj=0.705519 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7000: total=1.279780 | e_pde=0.192975 | e_term_zero=0.000000 | e_traj=0.705026 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7100: total=1.278126 | e_pde=0.192461 | e_term_zero=0.000000 | e_traj=0.704381 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7200: total=1.276326 | e_pde=0.191743 | e_term_zero=0.000000 | e_traj=0.703841 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7300: total=1.275206 | e_pde=0.191541 | e_term_zero=0.000000 | e_traj=0.703256 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7400: total=1.273276 | e_pde=0.190684 | e_term_zero=0.000000 | e_traj=0.702765 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7500: total=1.270966 | e_pde=0.189995 | e_term_zero=0.000000 | e_traj=0.701835 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7600: total=1.268046 | e_pde=0.188986 | e_term_zero=0.000000 | e_traj=0.700801 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7700: total=1.266573 | e_pde=0.188683 | e_term_zero=0.000000 | e_traj=0.700071 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7800: total=1.264289 | e_pde=0.187988 | e_term_zero=0.000000 | e_traj=0.699167 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 7900: total=1.262361 | e_pde=0.187889 | e_term_zero=0.000000 | e_traj=0.697911 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8000: total=1.260072 | e_pde=0.187663 | e_term_zero=0.000000 | e_traj=0.696530 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8100: total=1.255827 | e_pde=0.186089 | e_term_zero=0.000000 | e_traj=0.695134 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8200: total=1.252660 | e_pde=0.185588 | e_term_zero=0.000000 | e_traj=0.693413 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8300: total=1.251819 | e_pde=0.186677 | e_term_zero=0.000000 | e_traj=0.691723 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8400: total=1.246429 | e_pde=0.185083 | e_term_zero=0.000000 | e_traj=0.689541 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8500: total=1.242858 | e_pde=0.185021 | e_term_zero=0.000000 | e_traj=0.687094 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8600: total=1.238411 | e_pde=0.184679 | e_term_zero=0.000000 | e_traj=0.684313 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8700: total=1.234440 | e_pde=0.185210 | e_term_zero=0.000000 | e_traj=0.680984 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8800: total=1.229967 | e_pde=0.186119 | e_term_zero=0.000000 | e_traj=0.676922 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 8900: total=1.223059 | e_pde=0.185918 | e_term_zero=0.000000 | e_traj=0.672268 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9000: total=1.216636 | e_pde=0.187105 | e_term_zero=0.000000 | e_traj=0.666554 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9100: total=1.209762 | e_pde=0.189623 | e_term_zero=0.000000 | e_traj=0.659179 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9200: total=1.199023 | e_pde=0.191476 | e_term_zero=0.000000 | e_traj=0.649760 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9300: total=1.186538 | e_pde=0.194863 | e_term_zero=0.000000 | e_traj=0.637564 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9400: total=1.171136 | e_pde=0.200484 | e_term_zero=0.000000 | e_traj=0.621061 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9500: total=1.149222 | e_pde=0.207606 | e_term_zero=0.000000 | e_traj=0.598467 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9600: total=1.119957 | e_pde=0.217717 | e_term_zero=0.000001 | e_traj=0.567687 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9700: total=1.080820 | e_pde=0.228887 | e_term_zero=0.000000 | e_traj=0.528898 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9800: total=1.035953 | e_pde=0.238626 | e_term_zero=0.000003 | e_traj=0.487524 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 9900: total=0.992617 | e_pde=0.243513 | e_term_zero=0.000006 | e_traj=0.452123 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10000: total=0.955183 | e_pde=0.241950 | e_term_zero=0.000005 | e_traj=0.427382 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10100: total=0.925261 | e_pde=0.236918 | e_term_zero=0.000004 | e_traj=0.411423 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10200: total=0.901083 | e_pde=0.230944 | e_term_zero=0.000001 | e_traj=0.400454 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10300: total=0.881511 | e_pde=0.225290 | e_term_zero=0.000000 | e_traj=0.392399 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10400: total=0.864255 | e_pde=0.220076 | e_term_zero=0.000000 | e_traj=0.385529 | w={e_pde:1.44, e_term_zero:0.142, e_traj:1.42}
# Epoch 10500: total=0.849194 | e_pde=0.215815 | e_term_zero=0.000000 | e_traj=0.379240 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 10600: total=0.834987 | e_pde=0.211830 | e_term_zero=0.000000 | e_traj=0.373459 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 10700: total=0.822217 | e_pde=0.208712 | e_term_zero=0.000000 | e_traj=0.367623 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 10800: total=0.809344 | e_pde=0.205342 | e_term_zero=0.000000 | e_traj=0.361973 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 10900: total=0.797379 | e_pde=0.202359 | e_term_zero=0.000000 | e_traj=0.356568 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11000: total=0.786202 | e_pde=0.199292 | e_term_zero=0.000001 | e_traj=0.351804 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11100: total=0.775016 | e_pde=0.195928 | e_term_zero=0.000000 | e_traj=0.347337 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11200: total=0.764918 | e_pde=0.192876 | e_term_zero=0.000000 | e_traj=0.343319 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11300: total=0.755427 | e_pde=0.189757 | e_term_zero=0.000000 | e_traj=0.339798 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11400: total=0.745874 | e_pde=0.186169 | e_term_zero=0.000000 | e_traj=0.336711 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11500: total=0.737614 | e_pde=0.183045 | e_term_zero=0.000000 | e_traj=0.334063 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11600: total=0.729987 | e_pde=0.180109 | e_term_zero=0.000000 | e_traj=0.331671 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11700: total=0.721670 | e_pde=0.176424 | e_term_zero=0.000000 | e_traj=0.329555 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11800: total=0.714773 | e_pde=0.173517 | e_term_zero=0.000000 | e_traj=0.327648 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 11900: total=0.708938 | e_pde=0.171195 | e_term_zero=0.000000 | e_traj=0.325895 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12000: total=0.701429 | e_pde=0.167586 | e_term_zero=0.000000 | e_traj=0.324272 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12100: total=0.694996 | e_pde=0.164549 | e_term_zero=0.000000 | e_traj=0.322824 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12200: total=0.689343 | e_pde=0.162027 | e_term_zero=0.000000 | e_traj=0.321403 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12300: total=0.683104 | e_pde=0.159002 | e_term_zero=0.000000 | e_traj=0.320081 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12400: total=0.677463 | e_pde=0.156392 | e_term_zero=0.000000 | e_traj=0.318758 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12500: total=0.672142 | e_pde=0.153969 | e_term_zero=0.000000 | e_traj=0.317471 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12600: total=0.667049 | e_pde=0.151606 | e_term_zero=0.000000 | e_traj=0.316283 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12700: total=0.661595 | e_pde=0.149001 | e_term_zero=0.000000 | e_traj=0.315087 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12800: total=0.656623 | e_pde=0.146604 | e_term_zero=0.000000 | e_traj=0.314019 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 12900: total=0.652170 | e_pde=0.144525 | e_term_zero=0.000000 | e_traj=0.312995 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13000: total=0.647170 | e_pde=0.142109 | e_term_zero=0.000000 | e_traj=0.311925 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13100: total=0.642832 | e_pde=0.140066 | e_term_zero=0.000000 | e_traj=0.310945 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13200: total=0.637749 | e_pde=0.137536 | e_term_zero=0.000000 | e_traj=0.309935 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13300: total=0.633844 | e_pde=0.135764 | e_term_zero=0.000001 | e_traj=0.308983 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13400: total=0.629434 | e_pde=0.133649 | e_term_zero=0.000001 | e_traj=0.308024 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13500: total=0.625809 | e_pde=0.131834 | e_term_zero=0.000003 | e_traj=0.307315 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13600: total=0.621278 | e_pde=0.129742 | e_term_zero=0.000001 | e_traj=0.306248 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13700: total=0.617375 | e_pde=0.127755 | e_term_zero=0.000000 | e_traj=0.305517 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13800: total=0.613954 | e_pde=0.126178 | e_term_zero=0.000000 | e_traj=0.304709 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 13900: total=0.610534 | e_pde=0.124559 | e_term_zero=0.000002 | e_traj=0.303943 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14000: total=0.606579 | e_pde=0.122594 | e_term_zero=0.000000 | e_traj=0.303154 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14100: total=0.604737 | e_pde=0.121489 | e_term_zero=0.000008 | e_traj=0.302979 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14200: total=0.600309 | e_pde=0.119617 | e_term_zero=0.000000 | e_traj=0.301761 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14300: total=0.596843 | e_pde=0.117878 | e_term_zero=0.000000 | e_traj=0.301086 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14400: total=0.594066 | e_pde=0.116546 | e_term_zero=0.000000 | e_traj=0.300483 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14500: total=0.590848 | e_pde=0.114916 | e_term_zero=0.000001 | e_traj=0.299871 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14600: total=0.587988 | e_pde=0.113514 | e_term_zero=0.000000 | e_traj=0.299281 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14700: total=0.584618 | e_pde=0.111927 | e_term_zero=0.000002 | e_traj=0.298519 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14800: total=0.582676 | e_pde=0.110799 | e_term_zero=0.000002 | e_traj=0.298297 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 14900: total=0.578986 | e_pde=0.109174 | e_term_zero=0.000000 | e_traj=0.297348 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15000: total=0.576553 | e_pde=0.108008 | e_term_zero=0.000000 | e_traj=0.296819 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15100: total=0.577540 | e_pde=0.107937 | e_term_zero=0.000007 | e_traj=0.297586 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15200: total=0.572239 | e_pde=0.106263 | e_term_zero=0.000000 | e_traj=0.295551 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15300: total=0.569097 | e_pde=0.104471 | e_term_zero=0.000001 | e_traj=0.295159 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15400: total=0.566322 | e_pde=0.103408 | e_term_zero=0.000000 | e_traj=0.294284 | w={e_pde:1.44, e_term_zero:0.14, e_traj:1.42}
# Epoch 15500: total=0.563272 | e_pde=0.101709 | e_term_zero=0.000000 | e_traj=0.293861 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 15600: total=0.561509 | e_pde=0.101014 | e_term_zero=0.000001 | e_traj=0.293338 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 15700: total=0.558996 | e_pde=0.099729 | e_term_zero=0.000000 | e_traj=0.292880 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 15800: total=0.556327 | e_pde=0.098419 | e_term_zero=0.000000 | e_traj=0.292336 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 15900: total=0.554292 | e_pde=0.097581 | e_term_zero=0.000000 | e_traj=0.291755 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16000: total=0.551757 | e_pde=0.096300 | e_term_zero=0.000000 | e_traj=0.291277 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16100: total=0.550004 | e_pde=0.095553 | e_term_zero=0.000000 | e_traj=0.290805 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16200: total=0.547427 | e_pde=0.094291 | e_term_zero=0.000000 | e_traj=0.290275 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16300: total=0.545664 | e_pde=0.093558 | e_term_zero=0.000000 | e_traj=0.289781 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16400: total=0.543089 | e_pde=0.092370 | e_term_zero=0.000001 | e_traj=0.289179 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16500: total=0.541196 | e_pde=0.091627 | e_term_zero=0.000000 | e_traj=0.288603 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16600: total=0.538299 | e_pde=0.090138 | e_term_zero=0.000000 | e_traj=0.288080 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16700: total=0.536432 | e_pde=0.089399 | e_term_zero=0.000000 | e_traj=0.287518 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16800: total=0.534887 | e_pde=0.088649 | e_term_zero=0.000002 | e_traj=0.287195 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 16900: total=0.532297 | e_pde=0.087637 | e_term_zero=0.000000 | e_traj=0.286402 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17000: total=0.543454 | e_pde=0.092185 | e_term_zero=0.000001 | e_traj=0.289626 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17100: total=0.528259 | e_pde=0.085802 | e_term_zero=0.000000 | e_traj=0.285428 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17200: total=0.526411 | e_pde=0.084931 | e_term_zero=0.000000 | e_traj=0.285015 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17300: total=0.524766 | e_pde=0.084235 | e_term_zero=0.000000 | e_traj=0.284565 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17400: total=0.522927 | e_pde=0.083454 | e_term_zero=0.000001 | e_traj=0.284066 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17500: total=0.520915 | e_pde=0.082529 | e_term_zero=0.000000 | e_traj=0.283592 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17600: total=0.519728 | e_pde=0.081970 | e_term_zero=0.000003 | e_traj=0.283326 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17700: total=0.517774 | e_pde=0.081320 | e_term_zero=0.000000 | e_traj=0.282611 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17800: total=0.515371 | e_pde=0.080184 | e_term_zero=0.000000 | e_traj=0.282077 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 17900: total=0.513580 | e_pde=0.079476 | e_term_zero=0.000001 | e_traj=0.281537 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18000: total=0.512279 | e_pde=0.078839 | e_term_zero=0.000000 | e_traj=0.281270 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18100: total=0.510755 | e_pde=0.078205 | e_term_zero=0.000001 | e_traj=0.280843 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18200: total=0.508943 | e_pde=0.077415 | e_term_zero=0.000000 | e_traj=0.280371 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18300: total=0.507744 | e_pde=0.076915 | e_term_zero=0.000000 | e_traj=0.280037 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18400: total=0.506173 | e_pde=0.076109 | e_term_zero=0.000000 | e_traj=0.279752 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18500: total=0.504774 | e_pde=0.075734 | e_term_zero=0.000000 | e_traj=0.279148 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18600: total=0.502714 | e_pde=0.074811 | e_term_zero=0.000000 | e_traj=0.278638 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18700: total=0.501679 | e_pde=0.074486 | e_term_zero=0.000000 | e_traj=0.278239 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18800: total=0.499796 | e_pde=0.073707 | e_term_zero=0.000000 | e_traj=0.277707 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 18900: total=0.498359 | e_pde=0.073110 | e_term_zero=0.000000 | e_traj=0.277303 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19000: total=0.496933 | e_pde=0.072578 | e_term_zero=0.000002 | e_traj=0.276841 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19100: total=0.495577 | e_pde=0.072079 | e_term_zero=0.000000 | e_traj=0.276394 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19200: total=0.493763 | e_pde=0.071428 | e_term_zero=0.000000 | e_traj=0.275779 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19300: total=0.492620 | e_pde=0.071164 | e_term_zero=0.000000 | e_traj=0.275241 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19400: total=0.490918 | e_pde=0.070515 | e_term_zero=0.000001 | e_traj=0.274703 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19500: total=0.489669 | e_pde=0.070225 | e_term_zero=0.000000 | e_traj=0.274118 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19600: total=0.488662 | e_pde=0.069676 | e_term_zero=0.000000 | e_traj=0.273970 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19700: total=0.486546 | e_pde=0.068758 | e_term_zero=0.000000 | e_traj=0.273414 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19800: total=0.485347 | e_pde=0.068323 | e_term_zero=0.000000 | e_traj=0.273013 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 19900: total=0.484223 | e_pde=0.067978 | e_term_zero=0.000001 | e_traj=0.272572 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20000: total=0.483393 | e_pde=0.067799 | e_term_zero=0.000000 | e_traj=0.272169 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20100: total=0.481688 | e_pde=0.067030 | e_term_zero=0.000001 | e_traj=0.271752 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20200: total=0.479961 | e_pde=0.066247 | e_term_zero=0.000001 | e_traj=0.271333 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20300: total=0.479095 | e_pde=0.066120 | e_term_zero=0.000001 | e_traj=0.270851 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20400: total=0.477447 | e_pde=0.065424 | e_term_zero=0.000000 | e_traj=0.270400 | w={e_pde:1.45, e_term_zero:0.135, e_traj:1.41}
# Epoch 20500: total=0.476547 | e_pde=0.065312 | e_term_zero=0.000000 | e_traj=0.269879 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 20600: total=0.475247 | e_pde=0.064636 | e_term_zero=0.000000 | e_traj=0.269382 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 20700: total=0.473818 | e_pde=0.064176 | e_term_zero=0.000001 | e_traj=0.268846 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 20800: total=0.473243 | e_pde=0.064311 | e_term_zero=0.000000 | e_traj=0.268301 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 20900: total=0.471081 | e_pde=0.063275 | e_term_zero=0.000000 | e_traj=0.267839 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21000: total=0.469472 | e_pde=0.062742 | e_term_zero=0.000000 | e_traj=0.267251 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21100: total=0.468676 | e_pde=0.062781 | e_term_zero=0.000000 | e_traj=0.266649 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21200: total=0.467532 | e_pde=0.062501 | e_term_zero=0.000000 | e_traj=0.266127 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21300: total=0.466924 | e_pde=0.062736 | e_term_zero=0.000000 | e_traj=0.265456 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21400: total=0.465093 | e_pde=0.062046 | e_term_zero=0.000003 | e_traj=0.264872 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21500: total=0.462866 | e_pde=0.061260 | e_term_zero=0.000000 | e_traj=0.264107 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21600: total=0.461073 | e_pde=0.060700 | e_term_zero=0.000000 | e_traj=0.263417 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21700: total=0.459691 | e_pde=0.060386 | e_term_zero=0.000002 | e_traj=0.262763 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21800: total=0.458623 | e_pde=0.060353 | e_term_zero=0.000000 | e_traj=0.262042 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 21900: total=0.457068 | e_pde=0.059971 | e_term_zero=0.000000 | e_traj=0.261336 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22000: total=0.455789 | e_pde=0.059900 | e_term_zero=0.000000 | e_traj=0.260505 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22100: total=0.455209 | e_pde=0.060044 | e_term_zero=0.000002 | e_traj=0.259947 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22200: total=0.452802 | e_pde=0.059271 | e_term_zero=0.000001 | e_traj=0.259041 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22300: total=0.451238 | e_pde=0.058887 | e_term_zero=0.000000 | e_traj=0.258331 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22400: total=0.450267 | e_pde=0.058993 | e_term_zero=0.000000 | e_traj=0.257535 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22500: total=0.447970 | e_pde=0.058163 | e_term_zero=0.000001 | e_traj=0.256766 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22600: total=0.446479 | e_pde=0.057956 | e_term_zero=0.000001 | e_traj=0.255926 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22700: total=0.444996 | e_pde=0.057781 | e_term_zero=0.000000 | e_traj=0.255058 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22800: total=0.444242 | e_pde=0.058099 | e_term_zero=0.000001 | e_traj=0.254198 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 22900: total=0.441770 | e_pde=0.057313 | e_term_zero=0.000000 | e_traj=0.253259 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23000: total=0.440260 | e_pde=0.057096 | e_term_zero=0.000000 | e_traj=0.252415 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23100: total=0.438762 | e_pde=0.057115 | e_term_zero=0.000000 | e_traj=0.251337 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23200: total=0.436815 | e_pde=0.056815 | e_term_zero=0.000000 | e_traj=0.250269 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23300: total=0.435191 | e_pde=0.056833 | e_term_zero=0.000000 | e_traj=0.249103 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23400: total=0.434498 | e_pde=0.057363 | e_term_zero=0.000001 | e_traj=0.248068 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23500: total=0.432503 | e_pde=0.057043 | e_term_zero=0.000003 | e_traj=0.246987 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23600: total=0.429757 | e_pde=0.056445 | e_term_zero=0.000000 | e_traj=0.245661 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23700: total=0.428352 | e_pde=0.056533 | e_term_zero=0.000000 | e_traj=0.244578 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23800: total=0.426387 | e_pde=0.056522 | e_term_zero=0.000001 | e_traj=0.243200 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 23900: total=0.423988 | e_pde=0.056240 | e_term_zero=0.000000 | e_traj=0.241795 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24000: total=0.422131 | e_pde=0.056304 | e_term_zero=0.000003 | e_traj=0.240416 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24100: total=0.420172 | e_pde=0.056382 | e_term_zero=0.000000 | e_traj=0.238951 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24200: total=0.418025 | e_pde=0.056350 | e_term_zero=0.000000 | e_traj=0.237467 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24300: total=0.416456 | e_pde=0.056794 | e_term_zero=0.000002 | e_traj=0.235900 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24400: total=0.413990 | e_pde=0.056368 | e_term_zero=0.000001 | e_traj=0.234595 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24500: total=0.412009 | e_pde=0.056330 | e_term_zero=0.000000 | e_traj=0.233234 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24600: total=0.419127 | e_pde=0.059203 | e_term_zero=0.000000 | e_traj=0.235307 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24700: total=0.408501 | e_pde=0.056097 | e_term_zero=0.000001 | e_traj=0.230994 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24800: total=0.406920 | e_pde=0.055903 | e_term_zero=0.000000 | e_traj=0.230077 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 24900: total=0.405819 | e_pde=0.056313 | e_term_zero=0.000000 | e_traj=0.228877 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25000: total=0.410138 | e_pde=0.058143 | e_term_zero=0.000000 | e_traj=0.230044 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25100: total=0.401498 | e_pde=0.055374 | e_term_zero=0.000000 | e_traj=0.226788 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25200: total=0.399869 | e_pde=0.055478 | e_term_zero=0.000000 | e_traj=0.225530 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25300: total=0.398324 | e_pde=0.055539 | e_term_zero=0.000000 | e_traj=0.224375 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25400: total=0.396369 | e_pde=0.055537 | e_term_zero=0.000001 | e_traj=0.222995 | w={e_pde:1.46, e_term_zero:0.129, e_traj:1.41}
# Epoch 25500: total=0.394077 | e_pde=0.055246 | e_term_zero=0.000000 | e_traj=0.221675 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 25600: total=0.394865 | e_pde=0.055396 | e_term_zero=0.000000 | e_traj=0.221415 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 25700: total=0.392939 | e_pde=0.055514 | e_term_zero=0.000001 | e_traj=0.219935 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 25800: total=0.390204 | e_pde=0.054793 | e_term_zero=0.000001 | e_traj=0.218749 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 25900: total=0.389096 | e_pde=0.055178 | e_term_zero=0.000004 | e_traj=0.217571 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26000: total=0.386905 | e_pde=0.054769 | e_term_zero=0.000000 | e_traj=0.216447 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26100: total=0.385655 | e_pde=0.055143 | e_term_zero=0.000004 | e_traj=0.215178 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26200: total=0.383265 | e_pde=0.054746 | e_term_zero=0.000001 | e_traj=0.213903 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26300: total=0.381520 | e_pde=0.054981 | e_term_zero=0.000001 | e_traj=0.212428 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26400: total=0.379687 | e_pde=0.055027 | e_term_zero=0.000000 | e_traj=0.211089 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26500: total=0.377557 | e_pde=0.054753 | e_term_zero=0.000001 | e_traj=0.209869 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26600: total=0.375955 | e_pde=0.055135 | e_term_zero=0.000002 | e_traj=0.208344 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26700: total=0.373651 | e_pde=0.054979 | e_term_zero=0.000002 | e_traj=0.206880 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26800: total=0.371495 | e_pde=0.054992 | e_term_zero=0.000001 | e_traj=0.205345 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 26900: total=0.369688 | e_pde=0.055133 | e_term_zero=0.000003 | e_traj=0.203925 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27000: total=0.369320 | e_pde=0.056024 | e_term_zero=0.000005 | e_traj=0.202746 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27100: total=0.364426 | e_pde=0.054924 | e_term_zero=0.000000 | e_traj=0.200429 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27200: total=0.362348 | e_pde=0.055146 | e_term_zero=0.000001 | e_traj=0.198733 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27300: total=0.360409 | e_pde=0.055383 | e_term_zero=0.000000 | e_traj=0.197121 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27400: total=0.360049 | e_pde=0.055917 | e_term_zero=0.000001 | e_traj=0.196316 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27500: total=0.358905 | e_pde=0.056735 | e_term_zero=0.000004 | e_traj=0.194665 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27600: total=0.355194 | e_pde=0.055904 | e_term_zero=0.000001 | e_traj=0.192905 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27700: total=0.352468 | e_pde=0.055463 | e_term_zero=0.000000 | e_traj=0.191437 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27800: total=0.355228 | e_pde=0.056898 | e_term_zero=0.000003 | e_traj=0.191903 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 27900: total=0.348414 | e_pde=0.055426 | e_term_zero=0.000002 | e_traj=0.188615 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28000: total=0.345805 | e_pde=0.055279 | e_term_zero=0.000002 | e_traj=0.186926 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28100: total=0.343439 | e_pde=0.055336 | e_term_zero=0.000002 | e_traj=0.185198 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28200: total=0.341284 | e_pde=0.055371 | e_term_zero=0.000000 | e_traj=0.183642 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28300: total=0.341634 | e_pde=0.055708 | e_term_zero=0.000000 | e_traj=0.183541 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28400: total=0.338526 | e_pde=0.055222 | e_term_zero=0.000001 | e_traj=0.181850 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28500: total=0.336633 | e_pde=0.055206 | e_term_zero=0.000001 | e_traj=0.180531 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28600: total=0.334038 | e_pde=0.054857 | e_term_zero=0.000002 | e_traj=0.179060 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28700: total=0.334065 | e_pde=0.055258 | e_term_zero=0.000002 | e_traj=0.178665 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28800: total=0.330959 | e_pde=0.054646 | e_term_zero=0.000000 | e_traj=0.177105 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 28900: total=0.328765 | e_pde=0.054463 | e_term_zero=0.000001 | e_traj=0.175747 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29000: total=0.327313 | e_pde=0.054583 | e_term_zero=0.000000 | e_traj=0.174599 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29100: total=0.326935 | e_pde=0.055555 | e_term_zero=0.000001 | e_traj=0.173330 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29200: total=0.324386 | e_pde=0.054997 | e_term_zero=0.000001 | e_traj=0.172106 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29300: total=0.322537 | e_pde=0.055027 | e_term_zero=0.000002 | e_traj=0.170771 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29400: total=0.319809 | e_pde=0.054292 | e_term_zero=0.000002 | e_traj=0.169604 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29500: total=0.319179 | e_pde=0.054976 | e_term_zero=0.000001 | e_traj=0.168455 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29600: total=0.315704 | e_pde=0.053978 | e_term_zero=0.000000 | e_traj=0.167033 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29700: total=0.314622 | e_pde=0.054587 | e_term_zero=0.000001 | e_traj=0.165641 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29800: total=0.312357 | e_pde=0.054283 | e_term_zero=0.000000 | e_traj=0.164358 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 29900: total=0.309908 | e_pde=0.054029 | e_term_zero=0.000000 | e_traj=0.162892 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30000: total=0.307814 | e_pde=0.053943 | e_term_zero=0.000000 | e_traj=0.161503 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30100: total=0.306321 | e_pde=0.054290 | e_term_zero=0.000000 | e_traj=0.160092 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30200: total=0.303536 | e_pde=0.053757 | e_term_zero=0.000000 | e_traj=0.158677 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30300: total=0.301917 | e_pde=0.053916 | e_term_zero=0.000008 | e_traj=0.157370 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30400: total=0.299525 | e_pde=0.053891 | e_term_zero=0.000003 | e_traj=0.155708 | w={e_pde:1.46, e_term_zero:0.12, e_traj:1.42}
# Epoch 30500: total=0.314023 | e_pde=0.060834 | e_term_zero=0.000017 | e_traj=0.158773 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 30600: total=0.296457 | e_pde=0.053331 | e_term_zero=0.000000 | e_traj=0.153414 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 30700: total=0.294496 | e_pde=0.053301 | e_term_zero=0.000004 | e_traj=0.152065 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 30800: total=0.292646 | e_pde=0.053170 | e_term_zero=0.000001 | e_traj=0.150901 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 30900: total=0.290631 | e_pde=0.053028 | e_term_zero=0.000001 | e_traj=0.149630 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31000: total=0.288120 | e_pde=0.052436 | e_term_zero=0.000000 | e_traj=0.148476 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31100: total=0.286360 | e_pde=0.052356 | e_term_zero=0.000001 | e_traj=0.147320 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31200: total=0.287582 | e_pde=0.053334 | e_term_zero=0.000000 | e_traj=0.147171 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31300: total=0.282499 | e_pde=0.052059 | e_term_zero=0.000000 | e_traj=0.144913 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31400: total=0.283708 | e_pde=0.052887 | e_term_zero=0.000001 | e_traj=0.144908 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31500: total=0.280129 | e_pde=0.052324 | e_term_zero=0.000005 | e_traj=0.142973 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31600: total=0.281084 | e_pde=0.052874 | e_term_zero=0.000010 | e_traj=0.143076 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31700: total=0.275561 | e_pde=0.051574 | e_term_zero=0.000002 | e_traj=0.140535 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31800: total=0.273207 | e_pde=0.051076 | e_term_zero=0.000002 | e_traj=0.139394 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 31900: total=0.290501 | e_pde=0.059496 | e_term_zero=0.000010 | e_traj=0.142866 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32000: total=0.270550 | e_pde=0.050994 | e_term_zero=0.000001 | e_traj=0.137610 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32100: total=0.268578 | e_pde=0.050551 | e_term_zero=0.000002 | e_traj=0.136680 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32200: total=0.267112 | e_pde=0.050386 | e_term_zero=0.000006 | e_traj=0.135820 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32300: total=0.265294 | e_pde=0.050095 | e_term_zero=0.000002 | e_traj=0.134842 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32400: total=0.263133 | e_pde=0.049462 | e_term_zero=0.000000 | e_traj=0.133975 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32500: total=0.261773 | e_pde=0.049535 | e_term_zero=0.000001 | e_traj=0.132944 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32600: total=0.261059 | e_pde=0.049925 | e_term_zero=0.000001 | e_traj=0.132040 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32700: total=0.264389 | e_pde=0.051482 | e_term_zero=0.000001 | e_traj=0.132775 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32800: total=0.257381 | e_pde=0.048803 | e_term_zero=0.000000 | e_traj=0.130612 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 32900: total=0.255909 | e_pde=0.048863 | e_term_zero=0.000004 | e_traj=0.129515 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33000: total=0.254734 | e_pde=0.048850 | e_term_zero=0.000001 | e_traj=0.128702 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33100: total=0.253370 | e_pde=0.048801 | e_term_zero=0.000001 | e_traj=0.127794 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33200: total=0.250772 | e_pde=0.047761 | e_term_zero=0.000003 | e_traj=0.127040 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33300: total=0.252212 | e_pde=0.049575 | e_term_zero=0.000002 | e_traj=0.126180 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33400: total=0.248616 | e_pde=0.047850 | e_term_zero=0.000006 | e_traj=0.125432 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33500: total=0.313889 | e_pde=0.086863 | e_term_zero=0.000010 | e_traj=0.131076 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33600: total=0.246483 | e_pde=0.047299 | e_term_zero=0.000000 | e_traj=0.124501 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33700: total=0.244601 | e_pde=0.046886 | e_term_zero=0.000000 | e_traj=0.123604 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33800: total=0.243831 | e_pde=0.047047 | e_term_zero=0.000001 | e_traj=0.122897 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 33900: total=0.241843 | e_pde=0.046362 | e_term_zero=0.000001 | e_traj=0.122205 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34000: total=0.240714 | e_pde=0.046200 | e_term_zero=0.000002 | e_traj=0.121578 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34100: total=0.239350 | e_pde=0.046052 | e_term_zero=0.000000 | e_traj=0.120772 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34200: total=0.245197 | e_pde=0.048062 | e_term_zero=0.000001 | e_traj=0.122809 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34300: total=0.240060 | e_pde=0.046103 | e_term_zero=0.000000 | e_traj=0.121219 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34400: total=0.238120 | e_pde=0.045717 | e_term_zero=0.000000 | e_traj=0.120254 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34500: total=0.237581 | e_pde=0.045903 | e_term_zero=0.000000 | e_traj=0.119682 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34600: total=0.236596 | e_pde=0.045776 | e_term_zero=0.000001 | e_traj=0.119121 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34700: total=0.235986 | e_pde=0.045759 | e_term_zero=0.000005 | e_traj=0.118709 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34800: total=0.234336 | e_pde=0.045014 | e_term_zero=0.000003 | e_traj=0.118318 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 34900: total=0.232380 | e_pde=0.044319 | e_term_zero=0.000000 | e_traj=0.117659 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35000: total=0.232886 | e_pde=0.045035 | e_term_zero=0.000001 | e_traj=0.117276 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35100: total=0.230560 | e_pde=0.043976 | e_term_zero=0.000001 | e_traj=0.116734 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35200: total=0.230121 | e_pde=0.044073 | e_term_zero=0.000001 | e_traj=0.116325 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35300: total=0.228779 | e_pde=0.043686 | e_term_zero=0.000000 | e_traj=0.115781 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35400: total=0.228940 | e_pde=0.044359 | e_term_zero=0.000000 | e_traj=0.115201 | w={e_pde:1.47, e_term_zero:0.11, e_traj:1.42}
# Epoch 35500: total=0.227062 | e_pde=0.043591 | e_term_zero=0.000000 | e_traj=0.114671 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 35600: total=0.227306 | e_pde=0.043706 | e_term_zero=0.000000 | e_traj=0.114172 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# ...
# Epoch 38000: total=0.200093 | e_pde=0.041175 | e_term_zero=0.000000 | e_traj=0.097716 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38100: total=0.209212 | e_pde=0.046011 | e_term_zero=0.000010 | e_traj=0.099116 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38200: total=0.197240 | e_pde=0.040728 | e_term_zero=0.000001 | e_traj=0.096179 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38300: total=0.197259 | e_pde=0.041438 | e_term_zero=0.000000 | e_traj=0.095460 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38400: total=0.198251 | e_pde=0.042264 | e_term_zero=0.000001 | e_traj=0.095302 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38500: total=0.194334 | e_pde=0.040633 | e_term_zero=0.000007 | e_traj=0.094240 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38600: total=0.193244 | e_pde=0.040625 | e_term_zero=0.000007 | e_traj=0.093485 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38700: total=0.193042 | e_pde=0.040961 | e_term_zero=0.000000 | e_traj=0.092997 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38800: total=0.192403 | e_pde=0.041331 | e_term_zero=0.000000 | e_traj=0.092168 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 38900: total=0.200817 | e_pde=0.045630 | e_term_zero=0.000029 | e_traj=0.093625 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39000: total=0.188950 | e_pde=0.040148 | e_term_zero=0.000000 | e_traj=0.090969 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39100: total=0.187789 | e_pde=0.039940 | e_term_zero=0.000000 | e_traj=0.090370 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39200: total=0.187604 | e_pde=0.040620 | e_term_zero=0.000001 | e_traj=0.089539 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39300: total=0.185542 | e_pde=0.039830 | e_term_zero=0.000000 | e_traj=0.088909 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39400: total=0.185070 | e_pde=0.040063 | e_term_zero=0.000001 | e_traj=0.088338 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39500: total=0.183591 | e_pde=0.039562 | e_term_zero=0.000006 | e_traj=0.087819 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39600: total=0.188845 | e_pde=0.042569 | e_term_zero=0.000004 | e_traj=0.088398 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39700: total=0.182285 | e_pde=0.039798 | e_term_zero=0.000002 | e_traj=0.086661 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39800: total=0.182028 | e_pde=0.040051 | e_term_zero=0.000002 | e_traj=0.086219 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 39900: total=0.181001 | e_pde=0.040267 | e_term_zero=0.000000 | e_traj=0.085277 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40000: total=0.178782 | e_pde=0.039285 | e_term_zero=0.000002 | e_traj=0.084735 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40100: total=0.177967 | e_pde=0.039243 | e_term_zero=0.000006 | e_traj=0.084207 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40200: total=0.177169 | e_pde=0.039278 | e_term_zero=0.000000 | e_traj=0.083612 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40300: total=0.176479 | e_pde=0.039161 | e_term_zero=0.000000 | e_traj=0.083249 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40400: total=0.176427 | e_pde=0.039571 | e_term_zero=0.000002 | e_traj=0.082790 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40500: total=0.174482 | e_pde=0.038868 | e_term_zero=0.000001 | e_traj=0.082152 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40600: total=0.174254 | e_pde=0.039185 | e_term_zero=0.000003 | e_traj=0.081652 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40700: total=0.172182 | e_pde=0.038428 | e_term_zero=0.000001 | e_traj=0.080981 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40800: total=0.171985 | e_pde=0.038640 | e_term_zero=0.000001 | e_traj=0.080624 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 40900: total=0.170544 | e_pde=0.038271 | e_term_zero=0.000003 | e_traj=0.079996 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41000: total=0.170434 | e_pde=0.038803 | e_term_zero=0.000001 | e_traj=0.079369 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41100: total=0.169331 | e_pde=0.038672 | e_term_zero=0.000000 | e_traj=0.078732 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41200: total=0.173052 | e_pde=0.040142 | e_term_zero=0.000000 | e_traj=0.079822 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41300: total=0.168453 | e_pde=0.038556 | e_term_zero=0.000000 | e_traj=0.078236 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41400: total=0.167160 | e_pde=0.038214 | e_term_zero=0.000001 | e_traj=0.077683 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41500: total=0.165663 | e_pde=0.037576 | e_term_zero=0.000000 | e_traj=0.077293 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41600: total=0.166650 | e_pde=0.038289 | e_term_zero=0.000007 | e_traj=0.077249 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41700: total=0.165206 | e_pde=0.038236 | e_term_zero=0.000005 | e_traj=0.076292 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41800: total=0.163572 | e_pde=0.037477 | e_term_zero=0.000002 | e_traj=0.075930 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 41900: total=0.163184 | e_pde=0.037583 | e_term_zero=0.000002 | e_traj=0.075549 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42000: total=0.162063 | e_pde=0.037097 | e_term_zero=0.000015 | e_traj=0.075265 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42100: total=0.161128 | e_pde=0.037135 | e_term_zero=0.000000 | e_traj=0.074571 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42200: total=0.160583 | e_pde=0.037258 | e_term_zero=0.000000 | e_traj=0.074062 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42300: total=0.160168 | e_pde=0.037353 | e_term_zero=0.000004 | e_traj=0.073673 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42400: total=0.158542 | e_pde=0.036668 | e_term_zero=0.000003 | e_traj=0.073241 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42500: total=0.158067 | e_pde=0.036806 | e_term_zero=0.000001 | e_traj=0.072765 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42600: total=0.158590 | e_pde=0.037021 | e_term_zero=0.000000 | e_traj=0.072910 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42700: total=0.157426 | e_pde=0.037153 | e_term_zero=0.000003 | e_traj=0.071958 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42800: total=0.155004 | e_pde=0.035888 | e_term_zero=0.000005 | e_traj=0.071567 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 42900: total=0.155097 | e_pde=0.036379 | e_term_zero=0.000011 | e_traj=0.071125 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43000: total=0.154042 | e_pde=0.036206 | e_term_zero=0.000001 | e_traj=0.070564 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43100: total=0.152934 | e_pde=0.035655 | e_term_zero=0.000006 | e_traj=0.070356 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43200: total=0.151900 | e_pde=0.035494 | e_term_zero=0.000000 | e_traj=0.069799 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43300: total=0.153755 | e_pde=0.037181 | e_term_zero=0.000001 | e_traj=0.069359 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43400: total=0.181727 | e_pde=0.052912 | e_term_zero=0.000189 | e_traj=0.072713 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43500: total=0.150795 | e_pde=0.035676 | e_term_zero=0.000010 | e_traj=0.068837 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43600: total=0.149695 | e_pde=0.035205 | e_term_zero=0.000010 | e_traj=0.068551 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43700: total=0.149116 | e_pde=0.035325 | e_term_zero=0.000002 | e_traj=0.068023 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43800: total=0.147910 | e_pde=0.034866 | e_term_zero=0.000000 | e_traj=0.067652 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 43900: total=0.147636 | e_pde=0.035121 | e_term_zero=0.000000 | e_traj=0.067197 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44000: total=0.147107 | e_pde=0.035204 | e_term_zero=0.000004 | e_traj=0.066740 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44100: total=0.146308 | e_pde=0.034698 | e_term_zero=0.000007 | e_traj=0.066702 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44200: total=0.146203 | e_pde=0.034530 | e_term_zero=0.000001 | e_traj=0.066802 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44300: total=0.145984 | e_pde=0.035231 | e_term_zero=0.000001 | e_traj=0.065926 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44400: total=0.144879 | e_pde=0.034852 | e_term_zero=0.000000 | e_traj=0.065542 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44500: total=0.144176 | e_pde=0.034537 | e_term_zero=0.000006 | e_traj=0.065375 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44600: total=0.143289 | e_pde=0.034350 | e_term_zero=0.000001 | e_traj=0.064947 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44700: total=0.172809 | e_pde=0.050495 | e_term_zero=0.000007 | e_traj=0.068972 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44800: total=0.143003 | e_pde=0.034055 | e_term_zero=0.000007 | e_traj=0.065050 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 44900: total=0.142171 | e_pde=0.034035 | e_term_zero=0.000009 | e_traj=0.064487 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45000: total=0.141167 | e_pde=0.033768 | e_term_zero=0.000004 | e_traj=0.064061 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45100: total=0.141133 | e_pde=0.033993 | e_term_zero=0.000004 | e_traj=0.063804 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45200: total=0.140697 | e_pde=0.033797 | e_term_zero=0.000003 | e_traj=0.063701 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45300: total=0.139182 | e_pde=0.033108 | e_term_zero=0.000006 | e_traj=0.063351 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45400: total=0.139460 | e_pde=0.032825 | e_term_zero=0.000008 | e_traj=0.063837 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45500: total=0.138864 | e_pde=0.033232 | e_term_zero=0.000010 | e_traj=0.062999 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45600: total=0.138660 | e_pde=0.032686 | e_term_zero=0.000011 | e_traj=0.063419 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45700: total=0.138330 | e_pde=0.032754 | e_term_zero=0.000007 | e_traj=0.063118 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45800: total=0.137611 | e_pde=0.032701 | e_term_zero=0.000022 | e_traj=0.062668 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 45900: total=0.137033 | e_pde=0.033001 | e_term_zero=0.000001 | e_traj=0.061955 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46000: total=0.138011 | e_pde=0.032883 | e_term_zero=0.000018 | e_traj=0.062761 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46100: total=0.137092 | e_pde=0.032609 | e_term_zero=0.000017 | e_traj=0.062400 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46200: total=0.134432 | e_pde=0.031946 | e_term_zero=0.000001 | e_traj=0.061222 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46300: total=0.134559 | e_pde=0.031999 | e_term_zero=0.000000 | e_traj=0.061256 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46400: total=0.134956 | e_pde=0.032491 | e_term_zero=0.000001 | e_traj=0.061026 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46500: total=0.134123 | e_pde=0.032429 | e_term_zero=0.000004 | e_traj=0.060507 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46600: total=0.133128 | e_pde=0.032008 | e_term_zero=0.000004 | e_traj=0.060244 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46700: total=0.132287 | e_pde=0.031401 | e_term_zero=0.000000 | e_traj=0.060281 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46800: total=0.132552 | e_pde=0.031507 | e_term_zero=0.000007 | e_traj=0.060357 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 46900: total=0.133617 | e_pde=0.031829 | e_term_zero=0.000008 | e_traj=0.060771 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47000: total=0.130540 | e_pde=0.031046 | e_term_zero=0.000001 | e_traj=0.059424 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47100: total=0.130621 | e_pde=0.031017 | e_term_zero=0.000001 | e_traj=0.059510 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47200: total=0.130713 | e_pde=0.031519 | e_term_zero=0.000003 | e_traj=0.059056 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47300: total=0.129271 | e_pde=0.030803 | e_term_zero=0.000001 | e_traj=0.058785 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47400: total=0.128688 | e_pde=0.030549 | e_term_zero=0.000002 | e_traj=0.058639 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47500: total=0.128457 | e_pde=0.030697 | e_term_zero=0.000005 | e_traj=0.058324 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47600: total=0.130275 | e_pde=0.030768 | e_term_zero=0.000014 | e_traj=0.059523 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47700: total=0.127694 | e_pde=0.030381 | e_term_zero=0.000003 | e_traj=0.058116 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47800: total=0.127817 | e_pde=0.030568 | e_term_zero=0.000001 | e_traj=0.058008 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 47900: total=0.128916 | e_pde=0.031196 | e_term_zero=0.000003 | e_traj=0.058131 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48000: total=0.127405 | e_pde=0.030529 | e_term_zero=0.000008 | e_traj=0.057760 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48100: total=0.127173 | e_pde=0.030888 | e_term_zero=0.000001 | e_traj=0.057227 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48200: total=0.126361 | e_pde=0.030047 | e_term_zero=0.000001 | e_traj=0.057526 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48300: total=0.124951 | e_pde=0.029496 | e_term_zero=0.000003 | e_traj=0.057107 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48400: total=0.125104 | e_pde=0.029965 | e_term_zero=0.000001 | e_traj=0.056730 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48500: total=0.124065 | e_pde=0.029247 | e_term_zero=0.000000 | e_traj=0.056743 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48600: total=0.125475 | e_pde=0.030595 | e_term_zero=0.000000 | e_traj=0.056340 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48700: total=0.124315 | e_pde=0.029588 | e_term_zero=0.000011 | e_traj=0.056566 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48800: total=0.125906 | e_pde=0.029827 | e_term_zero=0.000015 | e_traj=0.057433 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 48900: total=0.122274 | e_pde=0.028800 | e_term_zero=0.000002 | e_traj=0.055949 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49000: total=0.124414 | e_pde=0.030063 | e_term_zero=0.000006 | e_traj=0.056146 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49100: total=0.123269 | e_pde=0.028852 | e_term_zero=0.000016 | e_traj=0.056592 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49200: total=0.121204 | e_pde=0.028586 | e_term_zero=0.000000 | e_traj=0.055420 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49300: total=0.122968 | e_pde=0.029971 | e_term_zero=0.000006 | e_traj=0.055228 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49400: total=0.121264 | e_pde=0.028824 | e_term_zero=0.000003 | e_traj=0.055217 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49500: total=0.122405 | e_pde=0.029556 | e_term_zero=0.000009 | e_traj=0.055261 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49600: total=0.122053 | e_pde=0.028813 | e_term_zero=0.000017 | e_traj=0.055780 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49700: total=0.119953 | e_pde=0.028210 | e_term_zero=0.000016 | e_traj=0.054931 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49800: total=0.120815 | e_pde=0.029239 | e_term_zero=0.000001 | e_traj=0.054475 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}
# Epoch 49900: total=0.121522 | e_pde=0.028671 | e_term_zero=0.000020 | e_traj=0.055554 | w={e_pde:1.47, e_term_zero:0.1, e_traj:1.43}

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/pinn_LQR/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_history.pkl (deflated 62%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_config.json (deflated 74%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/d/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/d/0484d54260de310bf7a848ce13260504 (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/d/32273d0bbdaca8e19e0aad517180846b (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/d/e87bc091ee1128e4d4fee3ce35b653ce (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/d/017f5487c5fb891f57cdf87eb3d069c2 (deflated 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/d/8eb450c6af333eb4f7fdc2d9e82fbe13 (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_LQR/MT-PINN_LQR_params/_sharding (deflated 85%)

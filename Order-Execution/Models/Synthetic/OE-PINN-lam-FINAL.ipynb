# %% [markdown]
# **RAN ON GOOGLE COLAB**

# %%
# !pip install ml-collections
# Out:
# Collecting ml-collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml-collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: ml-collections
# Successfully installed ml-collections-1.1.0

# %%
# ====== Imports ======
import os, json, time, pickle, shutil
import numpy as np
import jax
import jax.numpy as jnp
from jax import jit, grad, value_and_grad, vmap
import flax
import flax.linen as nn
from flax.training import train_state
from flax.linen.initializers import glorot_normal, zeros, normal
import optax
import ml_collections
import orbax.checkpoint as ocp
jran = jax.random


# ====== NN definition ======
activation_fn = { "tanh": jnp.tanh, "sin": jnp.sin }

def _get_activation(s):
    if s in activation_fn:
        return activation_fn[s]
    raise NotImplementedError(f"Activation {s} not supported yet!")

def _weight_fact(init_fn, mean, stddev):
    def init(key, shape):
        key1, key2 = jran.split(key)
        w = init_fn(key1, shape)
        g = mean + normal(stddev)(key2, (shape[-1],))
        g = jnp.exp(g)
        v = w / g
        return g, v
    return init

class Dense(nn.Module):
    features: int
    kernel_init: callable = glorot_normal()
    bias_init: callable = zeros
    reparam: dict | None = None

    @nn.compact
    def __call__(self, x):
        if self.reparam is None:
            kernel = self.param("kernel", self.kernel_init, (x.shape[-1], self.features))
        elif self.reparam["type"] == "weight_fact":
            g, v = self.param(
                "kernel",
                _weight_fact(self.kernel_init, mean=self.reparam["mean"], stddev=self.reparam["stddev"]),
                (x.shape[-1], self.features),
            )
            kernel = g * v
        bias = self.param("bias", self.bias_init, (self.features,))
        return jnp.dot(x, kernel) + bias

class MLP(nn.Module):
    arch_name: str = "MLP"
    hidden_dim: tuple[int, ...] = (32, 16)
    out_dim: int = 1
    activation: str = "tanh"
    periodicity: dict | None = None
    fourier_emb: dict | None = None
    reparam: dict | None = None

    def setup(self):
        self.activation_fn = _get_activation(self.activation)

    @nn.compact
    def __call__(self, x):
        for h in self.hidden_dim:
            x = Dense(features=h, reparam=self.reparam)(x)
            x = self.activation_fn(x)
        x = Dense(features=self.out_dim, reparam=self.reparam)(x)
        return x

def ann_gen(config):
    reparam = None
    if getattr(config, "ann_reparam", False) == "weight_fact":
        reparam = ml_collections.ConfigDict({"type": "weight_fact", "mean": 0.5, "stddev": 0.1})
    if config.ann_str == "MLP":
        return MLP(
            arch_name=config.ann_str,
            hidden_dim=tuple(config.ann_hidden_dim),
            out_dim=config.ann_out_dim,
            activation=config.ann_activation_str,
            periodicity=config.ann_periodicity,
            fourier_emb=config.ann_fourier_emb,
            reparam=reparam,
        )
    raise NotImplementedError(f"Unknown arch {config.ann_str}")


# ====== Derivatives ======
def derivatives_2d(fn2d, x):
    def f(z): return fn2d(z)[0]
    dx = vmap(grad(f), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_x   = dx.T[1]
    return Gamma_tau, Gamma_x

def derivatives_3d(fn3d, x):
    def f(z): return fn3d(z)[0]
    def f_dx(z): return grad(f)(z)[2]
    dx  = vmap(grad(f), 0)(x)
    d2x = vmap(grad(f_dx), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_X   = dx.T[1]
    Gamma_S   = dx.T[2]
    Gamma_SS  = d2x.T[2]
    return Gamma_tau, Gamma_X, Gamma_S, Gamma_SS


# ====== Data samplers ======
def get_data_2d(n_pde=10000, n_bc=500, n_term=100, T=5.0, x_range=(-10.,10.), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde])
    # x=0 boundary along tau
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc])

    # terminal condition
    tau_term = np.zeros((n_term, 1))
    x_term = rng.uniform(x_range[0], x_range[1], size=(n_term, 1))
    x_term_cond = np.hstack([tau_term, x_term])

    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), jnp.array(x_term_cond), T

def get_data_3d(n_pde=10000, n_bc=1000, n_term=100, T=5.0, x_range=(-10.,10.), s_range=(10,100), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    S_pde = rng.uniform(s_range[0], s_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde, S_pde])
    # IC
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    S_bc   = rng.uniform(s_range[0], s_range[1], size=(n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc, S_bc])
    # Terminal 
    tau_term = np.zeros((n_term, 1))
    S_term   = rng.uniform(s_range[0], s_range[1], size=(n_term, 1))
    x_term   = rng.uniform(x_range[0], x_range[1], size=(n_term, 1))
    x_term_cond = np.hstack([tau_term, x_term, S_term])
    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), jnp.array(x_term_cond), T


# ====== Error terms ======
def error_2d(config, fn2d, data):
    x_tau_pde, x_bc_zero, x_term_cond, T = data
    Gamma_tau, Gamma_X = derivatives_2d(fn2d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    kappa = config.kappa
    # PDE residual
    e_pde = ( Gamma_tau - (kappa**2 * X_vals**2) + 0.25 * Gamma_X**2 )**2
    # IC
    e_bc_zero = fn2d(x_bc_zero).squeeze()**2
    # Symmetry
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1])
    e_symm = (fn2d(z).squeeze() - fn2d(z_flip).squeeze())**2

    # Terminal condition
    x = x_term_cond[:, 1]                           
    target = (x**2) * 1e2                           
    pred   = fn2d(x_term_cond).squeeze()             
    e_term = (pred - target)**2                      
    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_symm": jnp.mean(e_symm),
        "e_term": jnp.mean(e_term),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_symm": e_symm, "e_term": e_term}, metrics

def error_3d(config, fn3d, data):
    x_tau_pde, x_bc_zero, x_term_cond, T = data
    Gamma_tau, Gamma_X, _, Gamma_SS = derivatives_3d(fn3d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    S_vals   = x_tau_pde[:,2]

    kappa = config.kappa
    sigma = config.sigma
    lam   = config.lam

    # PDE residual
    e_pde = (
        Gamma_tau
        - 0.5 * sigma**2 * S_vals**2 * Gamma_SS
        - (kappa**2 * X_vals**2 + lam * S_vals * X_vals)
        + 0.25 * Gamma_X**2
    )**2
    # IC
    e_bc_zero = jnp.maximum(fn3d(x_bc_zero).squeeze() - 1e-6, 0.0)**2
    x = x_term_cond[:, 1]                           
    target = (x**2) * 1e2
    pred   = fn3d(x_term_cond).squeeze()
    e_term = (pred - target)**2
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1]).at[:, 2].set(-z[:, 2])
    e_symm = (fn3d(z).squeeze() - fn3d(z_flip).squeeze())**2

    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_term": jnp.mean(e_term),
        "e_symm": jnp.mean(e_symm),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_term": e_term, "e_symm": e_symm}, metrics

def error(config, fn, data):
    d = data[0].shape[1]   # 2 or 3 
    if d == 2:
        return error_2d(config, fn, data)
    elif d == 3:
        return error_3d(config, fn, data)
    else:
        raise ValueError(f"Unexpected input dimension d={d}")



# ====== 2D→3D parameter inflation ======
def inflate_2d_to_3d_params(params_2d, params_3d_init, first_dense="Dense_0"):
    """
    Take trained 2D params (inputs [tau, x]) and freshly inited 3D params ([tau, x, S]).
    Return params_3d with an added zero row for S in the first Dense kernel.
    """
    p2 = flax.core.unfreeze(params_2d)
    p3 = flax.core.unfreeze(params_3d_init)
    for mod, wdict in p2["params"].items():
        for name, arr in wdict.items():
            if (mod, name) == (first_dense, "kernel"):
                continue
            if arr.shape == p3["params"][mod][name].shape:
                p3["params"][mod][name] = arr
    k2 = p2["params"][first_dense]["kernel"]   
    H  = k2.shape[1]
    k3 = jnp.concatenate([k2, jnp.zeros((1, H))], axis=0)
    p3["params"][first_dense]["kernel"] = k3
    p3["params"][first_dense]["bias"]   = p2["params"][first_dense]["bias"]
    return flax.core.freeze(p3)


# ====== Loss assembly ======
def adj(loss, lw, m):  
    return lw * jnp.mean(m * loss)

ALL_COMPONENTS = ['e_pde', 'e_bc_zero', 'e_term', 'e_symm']

def make_loss_lb():
    def loss_fn(config, fn, data, l_ws, params_sa):
        err, metrics = error(config, fn, data)
        components = [k for k in ALL_COMPONENTS if k in err]
        loss_terms = {}
        for k in components:
            w_k = l_ws.get(k, 1.0)
            m_k = params_sa.get(k, jnp.ones_like(err[k]))
            loss_terms[k] = adj(err[k], w_k, m_k)
        return loss_terms, metrics
    return loss_fn

loss_fn_lb = { "MLP": make_loss_lb(), "PINN": make_loss_lb() }

def make_loss_fn(components_key):
    def loss_fn(config, fn, data, l_ws, params_sa):
        loss_terms, metrics = loss_fn_lb[components_key](config, fn, data, l_ws, params_sa)
        total = jnp.sum(jnp.array(list(loss_terms.values())))
        return total, metrics
    return loss_fn

loss_fn = { "MLP": make_loss_fn("MLP"), "PINN": make_loss_fn("PINN") }

def init_params_sa(loss_str, data):
    d = data[0].shape[1]
    if d == 2:
        x_tau_pde, x_bc_zero, x_term_cond, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_term": jnp.ones(len(x_term_cond)),
        }
    elif d == 3:
        x_tau_pde, x_bc_zero, x_term_cond, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_term": jnp.ones(len(x_term_cond)),
        }

# Initial static weights 
init_l_ws = {
    "PINN": {'e_pde': 1.0, 'e_bc_zero': 0.1, 'e_symm': 0.5, 'e_term': 1.0}
}


# ====== Rebalancer ======
class Rebalancer:
    
    def __init__(
        self, keys,
        ema_beta=0.95,
        power=0.2,
        w_clip=(0.5, 2.0),
        ema_floor=1e-4,
        allow_upweight_small=False,
        freeze_tol=1e-5,
        freeze_patience=10,
        base_weights=None,        
        static_keys=None,         
        relative_to_init=True,
        eps=1e-12,
    ):
        self.keys = list(keys)
        self.ema_beta = float(ema_beta)
        self.power = float(power)
        self.w_min, self.w_max = map(float, w_clip)
        self.ema_floor = float(ema_floor)
        self.allow_upweight_small = bool(allow_upweight_small)
        self.freeze_tol = float(freeze_tol)
        self.freeze_patience = int(freeze_patience)
        self.base_weights = dict(base_weights or {})
        self.static_keys = set(static_keys or ())
        self.relative_to_init = bool(relative_to_init)
        self.eps = float(eps)

        self.ema = {k: None for k in self.keys}
        self.init_ema = {k: None for k in self.keys}
        self.below_ctr = {k: 0 for k in self.keys}
        self.frozen = {k: False for k in self.keys}

    def _smooth_update(self, old, new):
        if old is None:
            return new
        return self.ema_beta * old + (1.0 - self.ema_beta) * new

    def step(self, metrics, weights):
        for k in self.keys:
            if k not in metrics:
                continue
            val = float(metrics[k])
            val = max(val, self.ema_floor) 
            self.ema[k] = self._smooth_update(self.ema[k], val)
            if self.init_ema[k] is None:
                self.init_ema[k] = self.ema[k]

            if self.ema[k] < self.freeze_tol:
                self.below_ctr[k] += 1
            else:
                self.below_ctr[k] = 0
            if self.freeze_patience > 0 and self.below_ctr[k] >= self.freeze_patience:
                self.frozen[k] = True

        present = [
            k for k in self.keys
            if (k in metrics and self.ema[k] is not None and not self.frozen[k] and k not in self.static_keys)
        ]
        if not present:
            new_w = dict(weights)
            for k in self.keys:
                if self.frozen[k]:
                    new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
            return new_w

        def rel_ema(k):
            if not self.relative_to_init:
                return max(self.ema[k], self.ema_floor)
            denom = max(self.init_ema[k] or self.ema_floor, self.ema_floor)
            return max(self.ema[k] / denom, self.ema_floor)

        rels = {k: rel_ema(k) for k in present}
        gmean = float(np.exp(np.mean([np.log(max(rels[k], self.eps)) for k in present])))

        new_w = dict(weights)
        for k in self.keys:
            if self.frozen[k]:
                new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
                continue
            if k in self.static_keys or k not in rels:
                new_w[k] = float(new_w.get(k, 1.0))
                continue

            ratio = max(rels[k] / gmean, self.eps)
            if not self.allow_upweight_small and ratio < 1.0:
                mult = 1.0  
            else:
                mult = ratio ** (-self.power)

            new_w[k] = float(np.clip(new_w.get(k, 1.0) * mult, self.w_min, self.w_max))

        mean_w = float(np.mean([new_w[k] for k in present])) if present else 1.0
        if mean_w > 0:
            for k in present:
                new_w[k] = new_w[k] / mean_w
        return new_w


# ====== Training ======
def calibration(config, data, params_init=None, l_ws=None, params_sa=None):
    ann = ann_gen(config)
    ofunc = loss_fn[config.loss_str]

    if l_ws is None:
        l_ws = dict(init_l_ws[config.loss_str])
    if params_sa is None:
        params_sa = init_params_sa(config.loss_str, data)

        rebal_cfg = getattr(config, "rebal", None)
    if rebal_cfg is None:
        rebal_cfg = ml_collections.ConfigDict({})

    rebal = Rebalancer(
        keys=[k for k in ALL_COMPONENTS if k in (params_sa.keys())],
        ema_beta=getattr(rebal_cfg, "ema_beta", 0.98),
        power=getattr(rebal_cfg, "power", 0.2),
        w_clip=tuple(getattr(rebal_cfg, "w_clip", (0.3, 3.0))),
        ema_floor=getattr(rebal_cfg, "ema_floor", 1e-3),
        allow_upweight_small=getattr(rebal_cfg, "allow_upweight_small", False),
        freeze_tol=getattr(rebal_cfg, "freeze_tol", 1e-4),
        freeze_patience=getattr(rebal_cfg, "freeze_patience", 10),
        base_weights=dict(getattr(rebal_cfg, "base_weights", {"e_bc_zero": 0.1})),
        static_keys=set(getattr(rebal_cfg, "static_keys", ())),
        relative_to_init=getattr(rebal_cfg, "relative_to_init", True),
    )


    key = jran.PRNGKey(config.seed)
    _, key_init = jran.split(key, 2)
    dummy = jnp.ones((1, config.ann_in_dim))
    params0 = ann.init(key_init, dummy) if params_init is None else params_init

    state = train_state.TrainState.create(
        apply_fn=ann.apply,
        params=params0,
        tx=optax.adamw(learning_rate=5e-4)
    )

    @jit
    def train_step(state, data, l_ws, params_sa):
        def wrapped_loss(params):
            def fn(x): return ann.apply(params, x)
            return ofunc(config, fn, data, l_ws, params_sa)
        (loss, metrics), grads = value_and_grad(wrapped_loss, has_aux=True)(state.params)
        state = state.apply_gradients(grads=grads)
        return state, loss, metrics

    hist = []
    for epoch in range(config.num_epochs):
        state, loss, metrics = train_step(state, data, l_ws, params_sa)

        if (epoch >= rebal_cfg.start_epoch) and ((epoch - rebal_cfg.start_epoch) % rebal_cfg.every == 0):
            l_ws = rebal.step(metrics, l_ws)

        if epoch % 100 == 0:
            w_str = "{"+", ".join(f"{k}:{l_ws.get(k,1.0):.3g}" for k in sorted(l_ws.keys()))+"}"
            keys = ['e_pde','e_bc_zero','e_term','e_symm']
            msg  = " | ".join(f"{k}={float(metrics[k]):.6f}" for k in keys if k in metrics)
            print(f"Epoch {epoch}: total={float(loss):.6f} | {msg} | w={w_str}")

        hist.append((int(epoch), float(loss), {k: float(metrics[k]) for k in metrics}))

    return (lambda x: ann.apply(state.params, x)), hist, state.params, ann


# ====== Curriculum runner ======
def save_params_overwrite(path, params):
    path = os.path.abspath(path)
    if os.path.exists(path):
        shutil.rmtree(path)
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    try:
        ckptr.save(path, params, force=True)  
    except TypeError:
        ckptr.save(path, params)            

def save_stage(run_dir, tag, *, params, config, history):
    """
    writes:
      - {run_dir}/{tag}_params/  
      - {run_dir}/{tag}_config.json
      - {run_dir}/{tag}_history.pkl
    """
    run_dir = os.path.abspath(run_dir)
    os.makedirs(run_dir, exist_ok=True)
    save_params_overwrite(os.path.join(run_dir, f"{tag}_params"), params)
    def _to_jsonable(obj):
        try:
            return obj.to_dict()
        except Exception:
            if isinstance(obj, (dict, list, str, int, float, bool)) or obj is None:
                return obj
            if hasattr(obj, "items"):
                return {k: _to_jsonable(v) for k, v in obj.items()}
            return str(obj)
    with open(os.path.join(run_dir, f"{tag}_config.json"), "w") as f:
        json.dump(_to_jsonable(config), f, indent=2)
    with open(os.path.join(run_dir, f"{tag}_history.pkl"), "wb") as f:
        pickle.dump(history, f)

def restore_params(run_dir, tag):
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    return ckptr.restore(os.path.abspath(os.path.join(run_dir, f"{tag}_params")))

def run_curriculum(config2d, config3d, lam_star, workdir=None):
    # ---- Phase A: 2D (lambda=0) ----
    config2d.dim = 2
    config2d.ann_in_dim = 2
    config2d.lam = 0.0
    alphas = config3d.alphas
    workdir = os.path.abspath(workdir or getattr(config3d, "workdir", "runs/pinn_oe"))
    os.makedirs(workdir, exist_ok=True)

    data2d = get_data_2d(
        n_pde=config2d.pts_num, n_bc=config2d.n_bc_zero, n_term = config2d.n_term_zero,
        T=config2d.T, x_range=config2d.x_range, seed=config2d.seed
    )
    _, hist2d, params_2d, _ = calibration(config2d, data2d)

    # save 2D stage
    save_stage(workdir, "2d_lam0", params=params_2d, config=config2d, history=hist2d)

    if alphas is None:
        return params_2d, {"2d": hist2d}

    # ---- Phase B: inflate to 3D, then curriculum over lambda ----
    config3d.dim = 3
    config3d.ann_in_dim = 3
    ann3d = ann_gen(config3d)
    params_3d_init = ann3d.init(jran.PRNGKey(1), jnp.ones((1,3)))
    params = inflate_2d_to_3d_params(params_2d, params_3d_init)

    data3d = get_data_3d(
        n_pde=config3d.pts_num, n_bc=config3d.n_bc_zero, n_term=config3d.n_term_zero,
        T=config3d.T, x_range=config3d.x_range, s_range=config3d.s_range, seed=config3d.seed
    )

    all_hist = {"2d": hist2d}
    start = time.time()
    for alpha in alphas:
        lam_stage = float(alpha * lam_star)
        print(f"\n=== 3D stage: alpha={alpha}, lambda={lam_stage} ===")
        config3d.lam = lam_stage
        _, hist, params, _ = calibration(config3d, data3d, params_init=params)
        all_hist[f"alpha_{alpha}"] = hist
        tag = f"alpha_{alpha}".replace('.', 'p') 
        save_stage(workdir, tag, params=params, config=config3d, history=hist)

    print(f"Training completed in {time.time() - start:.2f} s total.")
    return params, all_hist


# ====== Model builder ======
def build_model_fn(config, params):
    ann = ann_gen(config)
    return jax.jit(lambda x: ann.apply(params, x)) 

T=5.0
# ====== Default configs ======
def default_configs():
    config2d = ml_collections.ConfigDict({
        "seed": 43,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (500, 500, 500),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 2,
        "ann_in_dim": 2,
        "num_epochs": 30000,
        "pts_num": 30000,
        "x_range": (-10.0, 10.0),
        "T": T,
        "kappa": 0.1,
        "lam": 0.0,             # not used in 2D residual
        "n_bc_zero": 5000,    
        "n_term_zero": 5000,
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 5000,
            "ema_beta": 0.95,
            "power": 0.3,
            "w_clip": (0.1, 2.0),
        }),
    })

    config3d = ml_collections.ConfigDict({
        "seed": 43,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (500, 500, 500),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 3,
        "ann_in_dim": 3,
        "num_epochs": 5000,
        "pts_num": 30000,
        "x_range": (-10.0, 10.0),
        "s_range": (10.0, 100.0),
        "T": T,
        "kappa": 0.1,
        "sigma": 0.1,
        "lam": 0.1,             
        "n_bc_zero": 5000,      
        "n_term_zero": 5000,     
        "alphas": (0.25, 0.5, 0.75, 0.9, 1.0),
        "workdir": os.path.abspath("runs/pinn_oe"),
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 1000,
            "ema_beta": 0.95,
            "power": 0.3,
            "w_clip": (0.1, 2.0),
        }),
    })
    return config2d, config3d

config2d, config3d = default_configs()
final_params, all_hist = run_curriculum(config2d, config3d, lam_star=config3d.lam, workdir=config3d.workdir)
model_PINN = build_model_fn(config3d, final_params)
print("Done. Checkpoints in:", config3d.workdir)
# Out:
# Epoch 0: total=20401458.000000 | e_pde=0.221659 | e_bc_zero=0.003863 | e_term=20401458.000000 | e_symm=0.559300 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 100: total=20014684.000000 | e_pde=9.991587 | e_bc_zero=3084.725830 | e_term=20014366.000000 | e_symm=0.282889 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 200: total=19824072.000000 | e_pde=93.262283 | e_bc_zero=4622.951660 | e_term=19823516.000000 | e_symm=1.464308 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 300: total=19648372.000000 | e_pde=134.846771 | e_bc_zero=7940.327637 | e_term=19647444.000000 | e_symm=1.061868 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 400: total=19478902.000000 | e_pde=267.266541 | e_bc_zero=9109.353516 | e_term=19477724.000000 | e_symm=0.908597 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 500: total=19313382.000000 | e_pde=392.507080 | e_bc_zero=9318.698242 | e_term=19312058.000000 | e_symm=0.401422 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 600: total=29368526.000000 | e_pde=553.274353 | e_bc_zero=9825.374023 | e_term=19088006.000000 | e_symm=0.423746 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 700: total=29050690.000000 | e_pde=654.276550 | e_bc_zero=10381.682617 | e_term=18881252.000000 | e_symm=6.850834 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 800: total=28756236.000000 | e_pde=694.152832 | e_bc_zero=10772.517578 | e_term=18689774.000000 | e_symm=14.766632 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 900: total=28477376.000000 | e_pde=670.883850 | e_bc_zero=9647.194336 | e_term=18508654.000000 | e_symm=11.229541 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1000: total=28207746.000000 | e_pde=567.207153 | e_bc_zero=5894.087402 | e_term=18333874.000000 | e_symm=8.355816 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1100: total=27935962.000000 | e_pde=793.705261 | e_bc_zero=616.913574 | e_term=18157516.000000 | e_symm=8.835971 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1200: total=27679446.000000 | e_pde=890.939453 | e_bc_zero=431.123932 | e_term=17990704.000000 | e_symm=1.753606 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1300: total=27429310.000000 | e_pde=973.400940 | e_bc_zero=259.715698 | e_term=17828050.000000 | e_symm=1.832246 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1400: total=27185116.000000 | e_pde=1035.912354 | e_bc_zero=327.211914 | e_term=17669250.000000 | e_symm=12.594242 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1500: total=26944822.000000 | e_pde=1014.063538 | e_bc_zero=179.576187 | e_term=17513100.000000 | e_symm=1.493229 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1600: total=26710048.000000 | e_pde=1182.550781 | e_bc_zero=180.361267 | e_term=17360328.000000 | e_symm=1.826838 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1700: total=26478082.000000 | e_pde=1261.021851 | e_bc_zero=159.041092 | e_term=17209472.000000 | e_symm=8.680565 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1800: total=26250960.000000 | e_pde=2480.454102 | e_bc_zero=104.752258 | e_term=17060602.000000 | e_symm=62.681026 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1900: total=26023580.000000 | e_pde=1432.272339 | e_bc_zero=95.633560 | e_term=16913872.000000 | e_symm=27.078823 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2000: total=25801402.000000 | e_pde=1874.754395 | e_bc_zero=92.847488 | e_term=16769009.000000 | e_symm=36.727867 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2100: total=25581700.000000 | e_pde=1653.404297 | e_bc_zero=217.683487 | e_term=16626427.000000 | e_symm=4.703375 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2200: total=25366846.000000 | e_pde=3913.499268 | e_bc_zero=162.592270 | e_term=16484514.000000 | e_symm=11.099294 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2300: total=25152696.000000 | e_pde=5447.312012 | e_bc_zero=64.257828 | e_term=16343787.000000 | e_symm=22.723127 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2400: total=24934468.000000 | e_pde=2162.677979 | e_bc_zero=71.977646 | e_term=16205232.000000 | e_symm=5.277313 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2500: total=24726026.000000 | e_pde=3439.060059 | e_bc_zero=40.811283 | e_term=16068419.000000 | e_symm=107.242958 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2600: total=24518672.000000 | e_pde=3906.011475 | e_bc_zero=117.192261 | e_term=15933194.000000 | e_symm=49.224037 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2700: total=24312542.000000 | e_pde=4706.101562 | e_bc_zero=295.460205 | e_term=15798396.000000 | e_symm=37.714306 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2800: total=24102802.000000 | e_pde=2795.856934 | e_bc_zero=33.234940 | e_term=15664010.000000 | e_symm=22.282045 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 2900: total=23897648.000000 | e_pde=2147.192627 | e_bc_zero=12.434430 | e_term=15531316.000000 | e_symm=12.377645 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3000: total=23695604.000000 | e_pde=1140.401367 | e_bc_zero=44.072563 | e_term=15400996.000000 | e_symm=2.755940 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3100: total=23501332.000000 | e_pde=4062.923340 | e_bc_zero=110.950798 | e_term=15271782.000000 | e_symm=18.941174 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3200: total=23301656.000000 | e_pde=2669.795166 | e_bc_zero=100.764496 | e_term=15143392.000000 | e_symm=10.445581 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3300: total=23106500.000000 | e_pde=2796.587158 | e_bc_zero=155.787125 | e_term=15016406.000000 | e_symm=12.917699 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3400: total=22919852.000000 | e_pde=7899.931152 | e_bc_zero=45.637634 | e_term=14889912.000000 | e_symm=175.045700 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3500: total=22722240.000000 | e_pde=4733.193359 | e_bc_zero=256.918457 | e_term=14764674.000000 | e_symm=43.361851 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3600: total=22534038.000000 | e_pde=8013.046875 | e_bc_zero=172.035339 | e_term=14639086.000000 | e_symm=15.416693 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3700: total=22346716.000000 | e_pde=7808.128418 | e_bc_zero=636.956787 | e_term=14517472.000000 | e_symm=44.216618 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3800: total=22150270.000000 | e_pde=4053.054688 | e_bc_zero=243.789612 | e_term=14393532.000000 | e_symm=132.012466 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 3900: total=21982750.000000 | e_pde=18592.623047 | e_bc_zero=241.972488 | e_term=14270010.000000 | e_symm=319.510071 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4000: total=21783374.000000 | e_pde=8620.977539 | e_bc_zero=368.483368 | e_term=14150407.000000 | e_symm=255.465317 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4100: total=21590882.000000 | e_pde=3287.438477 | e_bc_zero=129.421066 | e_term=14030753.000000 | e_symm=40.166916 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4200: total=21418490.000000 | e_pde=14859.223633 | e_bc_zero=34.524929 | e_term=13907040.000000 | e_symm=230.215027 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4300: total=21227930.000000 | e_pde=7313.292969 | e_bc_zero=140.537460 | e_term=13790796.000000 | e_symm=63.155376 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4400: total=21043324.000000 | e_pde=8449.330078 | e_bc_zero=225.591492 | e_term=13669657.000000 | e_symm=62.446640 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4500: total=20856970.000000 | e_pde=4236.872070 | e_bc_zero=261.712494 | e_term=13552762.000000 | e_symm=10.740311 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4600: total=20674642.000000 | e_pde=3452.210938 | e_bc_zero=63.572086 | e_term=13435057.000000 | e_symm=4.989776 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4700: total=20507098.000000 | e_pde=8482.451172 | e_bc_zero=91.929497 | e_term=13321003.000000 | e_symm=235.583527 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4800: total=20319884.000000 | e_pde=2145.771973 | e_bc_zero=166.717026 | e_term=13205761.000000 | e_symm=2.634982 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 4900: total=20148322.000000 | e_pde=4646.649414 | e_bc_zero=126.311012 | e_term=13091746.000000 | e_symm=7.218361 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5000: total=20010862.000000 | e_pde=13016.130859 | e_bc_zero=113.088188 | e_term=12994013.000000 | e_symm=37.789200 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5100: total=19802354.000000 | e_pde=5806.833984 | e_bc_zero=229.651596 | e_term=12865659.000000 | e_symm=83.170334 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5200: total=19671192.000000 | e_pde=25095.757812 | e_bc_zero=686.674805 | e_term=12761073.000000 | e_symm=75.413315 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5300: total=19474086.000000 | e_pde=10945.047852 | e_bc_zero=189.438751 | e_term=12647125.000000 | e_symm=131.754990 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5400: total=19298528.000000 | e_pde=7932.077637 | e_bc_zero=440.176849 | e_term=12536052.000000 | e_symm=31.536060 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 5500: total=19169142.000000 | e_pde=30339.824219 | e_bc_zero=350.783508 | e_term=12429541.000000 | e_symm=53.045769 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 5600: total=22741880.000000 | e_pde=6817.538086 | e_bc_zero=629.786438 | e_term=12297697.000000 | e_symm=75.165642 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 5700: total=22517436.000000 | e_pde=9688.801758 | e_bc_zero=138.631348 | e_term=12174202.000000 | e_symm=46.288170 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 5800: total=22281674.000000 | e_pde=2712.395752 | e_bc_zero=86.762405 | e_term=12051860.000000 | e_symm=20.481340 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 5900: total=22066444.000000 | e_pde=4481.925781 | e_bc_zero=99.910225 | e_term=11934100.000000 | e_symm=45.960217 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6000: total=21843422.000000 | e_pde=3290.371826 | e_bc_zero=210.285416 | e_term=11814337.000000 | e_symm=6.761353 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6100: total=21628906.000000 | e_pde=2408.198730 | e_bc_zero=420.670074 | e_term=11698920.000000 | e_symm=16.836222 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6200: total=21446850.000000 | e_pde=22467.890625 | e_bc_zero=200.009048 | e_term=11585545.000000 | e_symm=14.299836 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6300: total=21232418.000000 | e_pde=11714.652344 | e_bc_zero=654.123718 | e_term=11477478.000000 | e_symm=50.258053 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6400: total=21041696.000000 | e_pde=22147.529297 | e_bc_zero=330.718903 | e_term=11366572.000000 | e_symm=73.646851 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6500: total=20835604.000000 | e_pde=10489.693359 | e_bc_zero=645.035828 | e_term=11263698.000000 | e_symm=120.607735 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6600: total=20738822.000000 | e_pde=80034.593750 | e_bc_zero=452.862823 | e_term=11159678.000000 | e_symm=97.304161 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6700: total=20459454.000000 | e_pde=16394.935547 | e_bc_zero=320.386780 | e_term=11055759.000000 | e_symm=413.582794 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6800: total=20288362.000000 | e_pde=38859.007812 | e_bc_zero=335.111633 | e_term=10946619.000000 | e_symm=54.550259 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 6900: total=20127710.000000 | e_pde=27636.003906 | e_bc_zero=2088.951416 | e_term=10867581.000000 | e_symm=975.517639 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7000: total=19884374.000000 | e_pde=11502.613281 | e_bc_zero=663.036560 | e_term=10748351.000000 | e_symm=118.734840 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7100: total=19712692.000000 | e_pde=19814.863281 | e_bc_zero=226.956238 | e_term=10649315.000000 | e_symm=195.870895 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7200: total=19510132.000000 | e_pde=16016.466797 | e_bc_zero=735.974365 | e_term=10542561.000000 | e_symm=27.915302 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7300: total=19344052.000000 | e_pde=26394.632812 | e_bc_zero=1129.338745 | e_term=10444959.000000 | e_symm=36.945904 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7400: total=19235768.000000 | e_pde=71288.968750 | e_bc_zero=630.151855 | e_term=10352961.000000 | e_symm=348.083130 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7500: total=18974210.000000 | e_pde=17357.214844 | e_bc_zero=736.635132 | e_term=10251612.000000 | e_symm=121.954750 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7600: total=18810374.000000 | e_pde=27390.775391 | e_bc_zero=650.472412 | e_term=10155565.000000 | e_symm=17.877739 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7700: total=18637698.000000 | e_pde=32225.873047 | e_bc_zero=168.863617 | e_term=10058574.000000 | e_symm=113.671318 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7800: total=18479858.000000 | e_pde=40559.652344 | e_bc_zero=1284.343994 | e_term=9966900.000000 | e_symm=52.477940 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 7900: total=18275008.000000 | e_pde=15856.205078 | e_bc_zero=593.674133 | e_term=9874521.000000 | e_symm=20.644457 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8000: total=18072936.000000 | e_pde=3075.581543 | e_bc_zero=198.190155 | e_term=9774744.000000 | e_symm=18.708212 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8100: total=17930298.000000 | e_pde=23608.839844 | e_bc_zero=292.833008 | e_term=9682306.000000 | e_symm=29.208029 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8200: total=17783776.000000 | e_pde=21244.712891 | e_bc_zero=590.048828 | e_term=9604756.000000 | e_symm=65.989716 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8300: total=17621126.000000 | e_pde=30027.775391 | e_bc_zero=1077.192749 | e_term=9510131.000000 | e_symm=250.885529 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8400: total=17468460.000000 | e_pde=39965.437500 | e_bc_zero=679.926880 | e_term=9420264.000000 | e_symm=32.532604 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8500: total=17262000.000000 | e_pde=18765.058594 | e_bc_zero=235.236069 | e_term=9324368.000000 | e_symm=59.458675 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8600: total=17182818.000000 | e_pde=58635.636719 | e_bc_zero=930.580872 | e_term=9251791.000000 | e_symm=174.217148 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8700: total=16922900.000000 | e_pde=5810.633301 | e_bc_zero=540.646606 | e_term=9150484.000000 | e_symm=170.598480 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8800: total=16756850.000000 | e_pde=3982.346191 | e_bc_zero=213.218491 | e_term=9062057.000000 | e_symm=139.377777 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 8900: total=16652384.000000 | e_pde=40129.535156 | e_bc_zero=295.403870 | e_term=8978696.000000 | e_symm=54.388283 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9000: total=16493363.000000 | e_pde=32816.664062 | e_bc_zero=517.096008 | e_term=8898085.000000 | e_symm=44.048199 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9100: total=16366393.000000 | e_pde=49692.980469 | e_bc_zero=792.209778 | e_term=8816812.000000 | e_symm=88.284996 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9200: total=16219296.000000 | e_pde=47456.324219 | e_bc_zero=552.190491 | e_term=8738633.000000 | e_symm=989.537476 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9300: total=15992528.000000 | e_pde=7956.916992 | e_bc_zero=237.097092 | e_term=8645656.000000 | e_symm=26.528522 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9400: total=15837535.000000 | e_pde=6021.136719 | e_bc_zero=200.538895 | e_term=8563252.000000 | e_symm=21.607542 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9500: total=15761559.000000 | e_pde=38256.117188 | e_bc_zero=1000.813782 | e_term=8498051.000000 | e_symm=209.485886 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9600: total=15760099.000000 | e_pde=133063.625000 | e_bc_zero=848.651978 | e_term=8426469.000000 | e_symm=1270.605469 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9700: total=15488508.000000 | e_pde=72105.914062 | e_bc_zero=1148.830322 | e_term=8325216.500000 | e_symm=38.610355 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9800: total=15281551.000000 | e_pde=16682.734375 | e_bc_zero=1555.372925 | e_term=8254268.000000 | e_symm=486.652557 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 9900: total=15088620.000000 | e_pde=3984.413330 | e_bc_zero=173.221451 | e_term=8159603.500000 | e_symm=81.682274 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10000: total=15299347.000000 | e_pde=244103.625000 | e_bc_zero=346.102631 | e_term=8094830.500000 | e_symm=954.497070 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10100: total=14796757.000000 | e_pde=6026.838379 | e_bc_zero=316.106476 | e_term=8000170.000000 | e_symm=111.141266 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10200: total=14858155.000000 | e_pde=148441.921875 | e_bc_zero=380.969177 | e_term=7927522.500000 | e_symm=119.856720 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10300: total=14619758.000000 | e_pde=81676.898438 | e_bc_zero=396.536560 | e_term=7848100.500000 | e_symm=362.639832 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10400: total=14641650.000000 | e_pde=186446.468750 | e_bc_zero=928.354065 | e_term=7781865.500000 | e_symm=836.616760 | w={e_bc_zero:0.185, e_pde:1.37, e_symm:0.593, e_term:1.85}
# Epoch 10500: total=14248663.000000 | e_pde=15598.164062 | e_bc_zero=683.611755 | e_term=7696537.000000 | e_symm=36.139576 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 10600: total=16772324.000000 | e_pde=16993.101562 | e_bc_zero=132.309631 | e_term=7601202.000000 | e_symm=30.511236 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 10700: total=16665631.000000 | e_pde=58159.765625 | e_bc_zero=120.259796 | e_term=7531087.500000 | e_symm=268.049866 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 10800: total=16396043.000000 | e_pde=24598.011719 | e_bc_zero=49.721310 | e_term=7426479.500000 | e_symm=19.977400 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 10900: total=16255018.000000 | e_pde=51789.523438 | e_bc_zero=128.522491 | e_term=7348161.500000 | e_symm=101.012466 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11000: total=16053797.000000 | e_pde=32954.296875 | e_bc_zero=804.340759 | e_term=7266707.500000 | e_symm=80.589424 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11100: total=15884209.000000 | e_pde=52054.164062 | e_bc_zero=181.606659 | e_term=7179770.000000 | e_symm=92.781952 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11200: total=15768657.000000 | e_pde=46776.191406 | e_bc_zero=450.814453 | e_term=7130014.500000 | e_symm=494.760834 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11300: total=15670926.000000 | e_pde=88473.023438 | e_bc_zero=678.652527 | e_term=7063754.000000 | e_symm=253.852234 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11400: total=15598248.000000 | e_pde=213645.406250 | e_bc_zero=570.438660 | e_term=6964921.000000 | e_symm=285.196167 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11500: total=15248023.000000 | e_pde=73159.664062 | e_bc_zero=432.964691 | e_term=6879954.500000 | e_symm=234.338272 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11600: total=14995910.000000 | e_pde=12129.467773 | e_bc_zero=158.616089 | e_term=6797743.000000 | e_symm=13.549675 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11700: total=14899471.000000 | e_pde=42977.253906 | e_bc_zero=900.730652 | e_term=6737626.500000 | e_symm=300.397980 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11800: total=14786947.000000 | e_pde=94361.476562 | e_bc_zero=668.278137 | e_term=6659595.500000 | e_symm=97.769333 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 11900: total=14710583.000000 | e_pde=152910.390625 | e_bc_zero=941.636963 | e_term=6594102.000000 | e_symm=155.472275 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12000: total=14352789.000000 | e_pde=4469.983398 | e_bc_zero=151.863251 | e_term=6509967.500000 | e_symm=22.082905 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12100: total=14193028.000000 | e_pde=4363.960449 | e_bc_zero=19.333553 | e_term=6437549.500000 | e_symm=12.984913 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12200: total=14050210.000000 | e_pde=14319.508789 | e_bc_zero=23.783998 | e_term=6367505.500000 | e_symm=31.306993 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12300: total=13879727.000000 | e_pde=1475.333374 | e_bc_zero=9.068117 | e_term=6296911.500000 | e_symm=31.397125 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12400: total=13730176.000000 | e_pde=3280.032471 | e_bc_zero=4.548227 | e_term=6228108.000000 | e_symm=20.901367 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12500: total=13578151.000000 | e_pde=1113.213379 | e_bc_zero=4.434560 | e_term=6160268.500000 | e_symm=26.135096 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12600: total=13606614.000000 | e_pde=110423.937500 | e_bc_zero=10.225302 | e_term=6115554.500000 | e_symm=619.423828 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12700: total=13385410.000000 | e_pde=31202.548828 | e_bc_zero=1030.215820 | e_term=6056835.000000 | e_symm=269.211731 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12800: total=13241520.000000 | e_pde=59994.316406 | e_bc_zero=724.441040 | e_term=5976464.500000 | e_symm=80.446014 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 12900: total=13015955.000000 | e_pde=3879.913574 | e_bc_zero=115.964294 | e_term=5903711.500000 | e_symm=40.491848 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13000: total=12872306.000000 | e_pde=3172.604492 | e_bc_zero=25.155067 | e_term=5838915.500000 | e_symm=35.703907 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13100: total=12733287.000000 | e_pde=4134.853027 | e_bc_zero=18.224890 | e_term=5775333.000000 | e_symm=32.448795 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13200: total=187670032.000000 | e_pde=134393328.000000 | e_bc_zero=137742.062500 | e_term=14376873.000000 | e_symm=256326.296875 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13300: total=21273936.000000 | e_pde=923057.250000 | e_bc_zero=2154292.500000 | e_term=8949000.000000 | e_symm=13686.131836 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13400: total=20587928.000000 | e_pde=653049.562500 | e_bc_zero=2045456.375000 | e_term=8791898.000000 | e_symm=7274.622070 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13500: total=20454294.000000 | e_pde=586506.750000 | e_bc_zero=1985504.875000 | e_term=8772455.000000 | e_symm=6304.776367 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13600: total=20377094.000000 | e_pde=549742.125000 | e_bc_zero=1951189.000000 | e_term=8760273.000000 | e_symm=5930.604492 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13700: total=20319440.000000 | e_pde=526946.500000 | e_bc_zero=1886915.125000 | e_term=8752627.000000 | e_symm=5441.396973 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13800: total=20268360.000000 | e_pde=501122.531250 | e_bc_zero=1867376.625000 | e_term=8745053.000000 | e_symm=5119.166992 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 13900: total=20228224.000000 | e_pde=482307.343750 | e_bc_zero=1828014.500000 | e_term=8740726.000000 | e_symm=4863.841797 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14000: total=20190742.000000 | e_pde=463560.000000 | e_bc_zero=1798817.750000 | e_term=8736550.000000 | e_symm=4621.369629 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14100: total=20156044.000000 | e_pde=445301.218750 | e_bc_zero=1777939.375000 | e_term=8732547.000000 | e_symm=4373.126953 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14200: total=20114506.000000 | e_pde=431247.625000 | e_bc_zero=1717702.500000 | e_term=8727195.000000 | e_symm=3964.615479 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14300: total=20071042.000000 | e_pde=407116.562500 | e_bc_zero=1699401.125000 | e_term=8722095.000000 | e_symm=3472.314697 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14400: total=20029014.000000 | e_pde=385867.875000 | e_bc_zero=1668625.750000 | e_term=8717400.000000 | e_symm=2850.603027 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14500: total=19998552.000000 | e_pde=370146.281250 | e_bc_zero=1660303.375000 | e_term=8712766.000000 | e_symm=2408.062256 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14600: total=19968356.000000 | e_pde=354035.843750 | e_bc_zero=1657114.250000 | e_term=8707893.000000 | e_symm=2241.520020 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14700: total=19934418.000000 | e_pde=344717.718750 | e_bc_zero=1602637.125000 | e_term=8702850.000000 | e_symm=2209.938721 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14800: total=19898130.000000 | e_pde=329958.093750 | e_bc_zero=1576645.125000 | e_term=8696748.000000 | e_symm=2220.760986 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 14900: total=19845220.000000 | e_pde=310562.375000 | e_bc_zero=1503151.125000 | e_term=8690291.000000 | e_symm=2250.318848 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15000: total=19795346.000000 | e_pde=290237.468750 | e_bc_zero=1425851.625000 | e_term=8686095.000000 | e_symm=2203.458252 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15100: total=19735444.000000 | e_pde=264927.625000 | e_bc_zero=1330737.125000 | e_term=8681760.000000 | e_symm=2115.033447 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15200: total=19692990.000000 | e_pde=250102.343750 | e_bc_zero=1259342.250000 | e_term=8677468.000000 | e_symm=1952.947510 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15300: total=19655204.000000 | e_pde=239781.734375 | e_bc_zero=1190055.750000 | e_term=8672703.000000 | e_symm=1843.553101 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15400: total=19590388.000000 | e_pde=235235.015625 | e_bc_zero=967801.750000 | e_term=8667912.000000 | e_symm=1839.680054 | w={e_bc_zero:0.22, e_pde:1.16, e_symm:0.416, e_term:2.2}
# Epoch 15500: total=19492280.000000 | e_pde=224006.671875 | e_bc_zero=630928.500000 | e_term=8662971.000000 | e_symm=1954.780273 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 15600: total=21971006.000000 | e_pde=214465.468750 | e_bc_zero=564563.312500 | e_term=8655709.000000 | e_symm=2490.532227 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 15700: total=21933958.000000 | e_pde=203581.015625 | e_bc_zero=532440.500000 | e_term=8648875.000000 | e_symm=2630.165527 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 15800: total=21881956.000000 | e_pde=187302.218750 | e_bc_zero=495704.625000 | e_term=8638798.000000 | e_symm=2550.800293 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 15900: total=21851028.000000 | e_pde=177832.421875 | e_bc_zero=466892.375000 | e_term=8633493.000000 | e_symm=2377.092529 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16000: total=21827324.000000 | e_pde=171564.906250 | e_bc_zero=444557.718750 | e_term=8629041.000000 | e_symm=2336.134277 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16100: total=21805564.000000 | e_pde=165385.656250 | e_bc_zero=428464.968750 | e_term=8624641.000000 | e_symm=2316.101562 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16200: total=21733166.000000 | e_pde=163476.562500 | e_bc_zero=405971.062500 | e_term=8598890.000000 | e_symm=2287.037842 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16300: total=21678346.000000 | e_pde=147815.812500 | e_bc_zero=394873.718750 | e_term=8584606.000000 | e_symm=2173.538086 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16400: total=21657544.000000 | e_pde=142760.828125 | e_bc_zero=383624.375000 | e_term=8579596.000000 | e_symm=2125.892090 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16500: total=21639998.000000 | e_pde=140085.515625 | e_bc_zero=370649.187500 | e_term=8575096.000000 | e_symm=2116.481934 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16600: total=21621036.000000 | e_pde=135445.859375 | e_bc_zero=361585.906250 | e_term=8570408.000000 | e_symm=2102.656738 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16700: total=21604080.000000 | e_pde=131060.000000 | e_bc_zero=355466.781250 | e_term=8566095.000000 | e_symm=2079.777100 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16800: total=21587294.000000 | e_pde=128320.296875 | e_bc_zero=344613.093750 | e_term=8561691.000000 | e_symm=2098.875732 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 16900: total=21572260.000000 | e_pde=126047.890625 | e_bc_zero=334747.781250 | e_term=8557695.000000 | e_symm=2036.776855 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17000: total=21557792.000000 | e_pde=124014.093750 | e_bc_zero=326560.000000 | e_term=8553640.000000 | e_symm=1978.784302 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17100: total=21542988.000000 | e_pde=121500.531250 | e_bc_zero=318003.718750 | e_term=8549685.000000 | e_symm=1986.522949 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17200: total=21527968.000000 | e_pde=118055.726562 | e_bc_zero=310654.718750 | e_term=8545893.000000 | e_symm=2008.136597 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17300: total=21513348.000000 | e_pde=114696.882812 | e_bc_zero=306072.437500 | e_term=8541923.000000 | e_symm=1999.240601 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17400: total=21501694.000000 | e_pde=112072.335938 | e_bc_zero=301148.187500 | e_term=8538878.000000 | e_symm=1987.203857 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17500: total=21487944.000000 | e_pde=110767.562500 | e_bc_zero=294359.218750 | e_term=8534653.000000 | e_symm=1981.329712 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17600: total=21475438.000000 | e_pde=108081.679688 | e_bc_zero=288088.875000 | e_term=8531438.000000 | e_symm=1985.866821 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17700: total=21463882.000000 | e_pde=106147.960938 | e_bc_zero=284747.937500 | e_term=8527972.000000 | e_symm=1980.455444 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17800: total=21453130.000000 | e_pde=103166.820312 | e_bc_zero=282020.843750 | e_term=8525191.000000 | e_symm=1993.281616 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 17900: total=21443254.000000 | e_pde=101630.843750 | e_bc_zero=280134.687500 | e_term=8522073.000000 | e_symm=1992.972534 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18000: total=21432986.000000 | e_pde=98990.843750 | e_bc_zero=278355.812500 | e_term=8519242.000000 | e_symm=1995.605225 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18100: total=21422426.000000 | e_pde=97149.390625 | e_bc_zero=276638.062500 | e_term=8515957.000000 | e_symm=2003.993896 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18200: total=21412954.000000 | e_pde=95911.125000 | e_bc_zero=274539.750000 | e_term=8512902.000000 | e_symm=2000.867920 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18300: total=21403142.000000 | e_pde=94532.593750 | e_bc_zero=271562.125000 | e_term=8509866.000000 | e_symm=2005.305786 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18400: total=21391832.000000 | e_pde=93667.710938 | e_bc_zero=266232.093750 | e_term=8506276.000000 | e_symm=2002.349609 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18500: total=21381026.000000 | e_pde=93105.671875 | e_bc_zero=260938.906250 | e_term=8502759.000000 | e_symm=2016.104004 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18600: total=21368492.000000 | e_pde=91958.664062 | e_bc_zero=258294.984375 | e_term=8498500.000000 | e_symm=2006.597778 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18700: total=21357402.000000 | e_pde=90755.132812 | e_bc_zero=255552.968750 | e_term=8494854.000000 | e_symm=1995.938110 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18800: total=21343234.000000 | e_pde=88643.421875 | e_bc_zero=246644.734375 | e_term=8491027.000000 | e_symm=2005.695435 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 18900: total=21299540.000000 | e_pde=85409.664062 | e_bc_zero=234158.531250 | e_term=8476228.000000 | e_symm=1931.023315 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19000: total=21268640.000000 | e_pde=83641.078125 | e_bc_zero=231005.156250 | e_term=8464922.000000 | e_symm=1898.407104 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19100: total=21238348.000000 | e_pde=80299.398438 | e_bc_zero=228214.625000 | e_term=8454471.000000 | e_symm=1823.255371 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19200: total=21225824.000000 | e_pde=78821.656250 | e_bc_zero=219076.609375 | e_term=8451066.000000 | e_symm=1838.240723 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19300: total=21218322.000000 | e_pde=81801.171875 | e_bc_zero=216812.125000 | e_term=8447086.000000 | e_symm=1768.515503 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19400: total=21171354.000000 | e_pde=94528.578125 | e_bc_zero=215862.375000 | e_term=8423108.000000 | e_symm=1892.150879 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19500: total=21107722.000000 | e_pde=67250.789062 | e_bc_zero=215159.859375 | e_term=8408931.000000 | e_symm=1822.150879 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19600: total=21087340.000000 | e_pde=62293.382812 | e_bc_zero=214681.828125 | e_term=8402858.000000 | e_symm=1810.003174 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19700: total=21129014.000000 | e_pde=90055.734375 | e_bc_zero=213654.171875 | e_term=8408213.000000 | e_symm=2025.212769 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19800: total=21059554.000000 | e_pde=57964.207031 | e_bc_zero=213798.937500 | e_term=8393603.000000 | e_symm=1813.422119 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 19900: total=21049136.000000 | e_pde=57789.707031 | e_bc_zero=213344.015625 | e_term=8389549.000000 | e_symm=1814.802246 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20000: total=21036018.000000 | e_pde=54605.093750 | e_bc_zero=212878.265625 | e_term=8385654.000000 | e_symm=1836.179199 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20100: total=21027086.000000 | e_pde=54333.265625 | e_bc_zero=212326.234375 | e_term=8382242.500000 | e_symm=1888.057007 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20200: total=21013672.000000 | e_pde=52082.027344 | e_bc_zero=211839.078125 | e_term=8377850.000000 | e_symm=1858.651245 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20300: total=21007834.000000 | e_pde=54062.765625 | e_bc_zero=211429.078125 | e_term=8374734.000000 | e_symm=1917.406982 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20400: total=21013250.000000 | e_pde=69738.976562 | e_bc_zero=210747.640625 | e_term=8370523.000000 | e_symm=1844.978638 | w={e_bc_zero:0.275, e_pde:1.03, e_symm:0.202, e_term:2.49}
# Epoch 20500: total=21080302.000000 | e_pde=125440.500000 | e_bc_zero=210271.437500 | e_term=8374598.000000 | e_symm=476.158081 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 20600: total=21867426.000000 | e_pde=109744.375000 | e_bc_zero=204701.359375 | e_term=8323242.000000 | e_symm=501.309174 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 20700: total=21635482.000000 | e_pde=87246.039062 | e_bc_zero=204037.859375 | e_term=8242154.500000 | e_symm=556.830261 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 20800: total=21568414.000000 | e_pde=84863.632812 | e_bc_zero=204162.187500 | e_term=8217235.000000 | e_symm=537.055176 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 20900: total=21524666.000000 | e_pde=79492.078125 | e_bc_zero=203871.765625 | e_term=8202355.500000 | e_symm=542.479248 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21000: total=21488776.000000 | e_pde=73290.414062 | e_bc_zero=203873.796875 | e_term=8190737.500000 | e_symm=563.936035 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21100: total=21444922.000000 | e_pde=64948.250000 | e_bc_zero=203802.953125 | e_term=8176819.000000 | e_symm=554.958923 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21200: total=21412946.000000 | e_pde=78849.117188 | e_bc_zero=203781.000000 | e_term=8159728.000000 | e_symm=557.012817 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21300: total=21354562.000000 | e_pde=74404.578125 | e_bc_zero=203401.968750 | e_term=8138924.000000 | e_symm=559.575745 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21400: total=21281310.000000 | e_pde=65275.949219 | e_bc_zero=203181.234375 | e_term=8114022.500000 | e_symm=522.463135 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21500: total=21095452.000000 | e_pde=61682.089844 | e_bc_zero=202159.734375 | e_term=8044104.500000 | e_symm=535.369751 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21600: total=20999972.000000 | e_pde=57661.476562 | e_bc_zero=202948.796875 | e_term=8008765.000000 | e_symm=445.281281 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21700: total=20950516.000000 | e_pde=49344.398438 | e_bc_zero=203251.328125 | e_term=7992637.000000 | e_symm=447.235046 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21800: total=20928948.000000 | e_pde=49140.128906 | e_bc_zero=203500.328125 | e_term=7984396.500000 | e_symm=485.313171 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 21900: total=20908150.000000 | e_pde=47102.855469 | e_bc_zero=203184.250000 | e_term=7977167.000000 | e_symm=506.413177 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22000: total=20885896.000000 | e_pde=44012.664062 | e_bc_zero=202967.437500 | e_term=7969733.000000 | e_symm=477.547180 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22100: total=20864360.000000 | e_pde=44839.117188 | e_bc_zero=202674.015625 | e_term=7961224.000000 | e_symm=492.696930 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22200: total=20839330.000000 | e_pde=41770.703125 | e_bc_zero=202269.109375 | e_term=7952744.000000 | e_symm=438.433380 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22300: total=20819334.000000 | e_pde=43574.464844 | e_bc_zero=201721.781250 | e_term=7944523.000000 | e_symm=415.115784 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22400: total=20700758.000000 | e_pde=40695.152344 | e_bc_zero=201378.218750 | e_term=7900075.500000 | e_symm=461.034515 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22500: total=20677586.000000 | e_pde=41535.109375 | e_bc_zero=201494.500000 | e_term=7890881.500000 | e_symm=392.154083 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22600: total=20656416.000000 | e_pde=38253.992188 | e_bc_zero=201389.156250 | e_term=7883909.500000 | e_symm=455.342957 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22700: total=20640056.000000 | e_pde=39605.980469 | e_bc_zero=200853.406250 | e_term=7877234.500000 | e_symm=503.451141 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22800: total=20626080.000000 | e_pde=42710.304688 | e_bc_zero=200611.109375 | e_term=7870827.500000 | e_symm=515.561584 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 22900: total=20575754.000000 | e_pde=35073.953125 | e_bc_zero=200444.890625 | e_term=7854199.500000 | e_symm=410.789734 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23000: total=20519814.000000 | e_pde=35922.460938 | e_bc_zero=200770.718750 | e_term=7832399.000000 | e_symm=418.363953 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23100: total=20492278.000000 | e_pde=35773.031250 | e_bc_zero=200566.812500 | e_term=7821910.000000 | e_symm=492.087738 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23200: total=20474620.000000 | e_pde=38774.925781 | e_bc_zero=200178.843750 | e_term=7814153.500000 | e_symm=348.857391 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23300: total=20436262.000000 | e_pde=33388.351562 | e_bc_zero=200391.218750 | e_term=7801271.500000 | e_symm=491.006042 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23400: total=20418834.000000 | e_pde=32109.796875 | e_bc_zero=200012.250000 | e_term=7795082.500000 | e_symm=482.123505 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23500: total=20402806.000000 | e_pde=31628.652344 | e_bc_zero=199765.828125 | e_term=7789137.500000 | e_symm=393.324738 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23600: total=20385150.000000 | e_pde=28901.171875 | e_bc_zero=199857.562500 | e_term=7783297.500000 | e_symm=416.401917 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23700: total=20367320.000000 | e_pde=26400.822266 | e_bc_zero=199427.812500 | e_term=7777384.000000 | e_symm=395.751678 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23800: total=20351804.000000 | e_pde=26036.302734 | e_bc_zero=198949.828125 | e_term=7771622.500000 | e_symm=430.855865 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 23900: total=20338690.000000 | e_pde=27343.421875 | e_bc_zero=198736.671875 | e_term=7766170.000000 | e_symm=375.629272 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24000: total=20321222.000000 | e_pde=24830.218750 | e_bc_zero=198378.750000 | e_term=7760383.000000 | e_symm=508.089050 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24100: total=20308504.000000 | e_pde=26763.968750 | e_bc_zero=198047.937500 | e_term=7754876.500000 | e_symm=531.884338 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24200: total=20294480.000000 | e_pde=27214.500000 | e_bc_zero=197533.953125 | e_term=7749410.500000 | e_symm=516.477722 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24300: total=20278638.000000 | e_pde=26031.412109 | e_bc_zero=197625.812500 | e_term=7743737.000000 | e_symm=399.237396 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24400: total=20258422.000000 | e_pde=22988.181641 | e_bc_zero=197482.765625 | e_term=7737055.500000 | e_symm=444.101562 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24500: total=20241606.000000 | e_pde=23891.257812 | e_bc_zero=196984.828125 | e_term=7730358.500000 | e_symm=439.837006 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24600: total=20223072.000000 | e_pde=21958.087891 | e_bc_zero=196356.250000 | e_term=7724002.500000 | e_symm=496.624115 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24700: total=20208550.000000 | e_pde=23458.544922 | e_bc_zero=196252.625000 | e_term=7717922.000000 | e_symm=559.347595 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24800: total=20192832.000000 | e_pde=22014.234375 | e_bc_zero=195726.906250 | e_term=7712472.000000 | e_symm=436.379211 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 24900: total=20177666.000000 | e_pde=22702.849609 | e_bc_zero=195636.781250 | e_term=7706421.500000 | e_symm=519.669312 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25000: total=20171558.000000 | e_pde=32222.056641 | e_bc_zero=194208.859375 | e_term=7700967.000000 | e_symm=580.097961 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25100: total=20142330.000000 | e_pde=18539.123047 | e_bc_zero=194875.109375 | e_term=7694416.000000 | e_symm=498.998474 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25200: total=20128302.000000 | e_pde=19892.417969 | e_bc_zero=194440.859375 | e_term=7688626.000000 | e_symm=454.756012 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25300: total=20111186.000000 | e_pde=17673.382812 | e_bc_zero=194106.593750 | e_term=7682873.500000 | e_symm=505.235199 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25400: total=20097386.000000 | e_pde=19133.000000 | e_bc_zero=193678.296875 | e_term=7677129.500000 | e_symm=544.674072 | w={e_bc_zero:0.358, e_pde:0.905, e_symm:0.13, e_term:2.61}
# Epoch 25500: total=20308046.000000 | e_pde=232402.734375 | e_bc_zero=193152.109375 | e_term=7683960.500000 | e_symm=1053.088989 | w={e_bc_zero:0.473, e_pde:0.753, e_symm:0.132, e_term:2.64}
# Epoch 25600: total=20188694.000000 | e_pde=57580.910156 | e_bc_zero=185528.609375 | e_term=7593082.500000 | e_symm=437.214813 | w={e_bc_zero:0.473, e_pde:0.753, e_symm:0.132, e_term:2.64}
# Epoch 25700: total=20088718.000000 | e_pde=44833.019531 | e_bc_zero=183570.421875 | e_term=7559220.000000 | e_symm=436.042633 | w={e_bc_zero:0.473, e_pde:0.753, e_symm:0.132, e_term:2.64}
# Epoch 25800: total=20047974.000000 | e_pde=38781.398438 | e_bc_zero=182405.046875 | e_term=7545730.500000 | e_symm=434.184967 | w={e_bc_zero:0.473, e_pde:0.753, e_symm:0.132, e_term:2.64}
# Epoch 25900: total=20015410.000000 | e_pde=39215.132812 | e_bc_zero=181086.859375 | e_term=7533516.000000 | e_symm=416.903229 | w={e_bc_zero:0.473, e_pde:0.753, e_symm:0.132, e_term:2.64}
# ...
# Epoch 1400: total=3357420.750000 | e_pde=321056.093750 | e_bc_zero=90909.117188 | e_term=1848877.875000 | e_symm=6597.282715 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1500: total=1812461.125000 | e_pde=42929.472656 | e_bc_zero=12223.859375 | e_term=1131687.750000 | e_symm=4520.203613 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 1600: total=1571343.500000 | e_pde=42294.472656 | e_bc_zero=4723.483398 | e_term=973543.500000 | e_symm=4874.433105 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 1700: total=1364619.250000 | e_pde=20797.923828 | e_bc_zero=2777.142578 | e_term=861246.250000 | e_symm=4579.847656 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 1800: total=4142188.250000 | e_pde=211257.281250 | e_bc_zero=105890.867188 | e_term=2460629.250000 | e_symm=7527.002930 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 1900: total=2619550.000000 | e_pde=62564.082031 | e_bc_zero=15168.185547 | e_term=1631576.000000 | e_symm=5245.209473 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2000: total=2230394.500000 | e_pde=41171.933594 | e_bc_zero=6530.993652 | e_term=1401567.125000 | e_symm=5014.561035 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2100: total=2052623.250000 | e_pde=55036.437500 | e_bc_zero=3709.931885 | e_term=1273028.750000 | e_symm=4672.522949 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2200: total=1912024.625000 | e_pde=54566.554688 | e_bc_zero=3298.313232 | e_term=1182432.250000 | e_symm=4625.142578 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2300: total=1770009.250000 | e_pde=37093.667969 | e_bc_zero=2515.130859 | e_term=1107939.250000 | e_symm=4379.650879 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2400: total=1726537.125000 | e_pde=39882.882812 | e_bc_zero=6474.560059 | e_term=1076426.375000 | e_symm=4725.571289 | w={e_bc_zero:0.153, e_pde:1.53, e_symm:0.771, e_term:1.54}
# Epoch 2500: total=1627606.500000 | e_pde=45756.335938 | e_bc_zero=2377.371826 | e_term=1006998.062500 | e_symm=4488.850098 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 2600: total=1536586.375000 | e_pde=32785.023438 | e_bc_zero=2036.414185 | e_term=953737.812500 | e_symm=4499.805176 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 2700: total=1504476.500000 | e_pde=34253.179688 | e_bc_zero=1519.632568 | e_term=931804.625000 | e_symm=4317.261230 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 2800: total=1446323.750000 | e_pde=28612.767578 | e_bc_zero=832.242188 | e_term=900057.062500 | e_symm=4133.286133 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 2900: total=1392465.500000 | e_pde=25977.462891 | e_bc_zero=1399.218262 | e_term=867920.437500 | e_symm=4154.754395 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3000: total=1336240.750000 | e_pde=22069.798828 | e_bc_zero=985.614746 | e_term=835743.187500 | e_symm=3884.398193 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3100: total=1318261.250000 | e_pde=29926.914062 | e_bc_zero=834.556030 | e_term=816509.750000 | e_symm=3973.479492 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3200: total=6279027.500000 | e_pde=201690.406250 | e_bc_zero=229635.015625 | e_term=3808739.750000 | e_symm=19756.810547 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3300: total=4055249.500000 | e_pde=104982.562500 | e_bc_zero=51381.554688 | e_term=2495344.250000 | e_symm=10200.881836 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3400: total=2894348.250000 | e_pde=60082.355469 | e_bc_zero=16529.347656 | e_term=1797048.250000 | e_symm=8070.947266 | w={e_bc_zero:0.155, e_pde:1.51, e_symm:0.778, e_term:1.56}
# Epoch 3500: total=8978567.000000 | e_pde=234566.093750 | e_bc_zero=1096222.750000 | e_term=5426984.500000 | e_symm=18734.509766 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 3600: total=7184943.000000 | e_pde=138755.140625 | e_bc_zero=616440.625000 | e_term=4377061.500000 | e_symm=10727.509766 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 3700: total=5926779.500000 | e_pde=112773.476562 | e_bc_zero=335760.687500 | e_term=3622601.000000 | e_symm=10316.778320 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 3800: total=5213760.000000 | e_pde=99715.609375 | e_bc_zero=185504.437500 | e_term=3193055.500000 | e_symm=9672.859375 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 3900: total=4693564.500000 | e_pde=74118.132812 | e_bc_zero=111952.406250 | e_term=2892706.500000 | e_symm=9761.856445 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4000: total=4470550.500000 | e_pde=117569.437500 | e_bc_zero=51073.105469 | e_term=2712571.000000 | e_symm=10441.296875 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4100: total=4213708.500000 | e_pde=50421.269531 | e_bc_zero=38927.718750 | e_term=2616073.500000 | e_symm=9823.578125 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4200: total=4044508.000000 | e_pde=50339.796875 | e_bc_zero=28066.898438 | e_term=2509636.250000 | e_symm=9623.793945 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4300: total=3924119.750000 | e_pde=76160.484375 | e_bc_zero=26409.412109 | e_term=2408285.000000 | e_symm=9596.763672 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4400: total=3758854.000000 | e_pde=42395.425781 | e_bc_zero=21808.570312 | e_term=2336778.250000 | e_symm=9248.930664 | w={e_bc_zero:0.101, e_pde:1.53, e_symm:0.788, e_term:1.58}
# Epoch 4500: total=7461749.500000 | e_pde=1019900.875000 | e_bc_zero=155645.859375 | e_term=3711438.750000 | e_symm=38207.761719 | w={e_bc_zero:0.103, e_pde:1.46, e_symm:0.811, e_term:1.62}
# Epoch 4600: total=4272347.500000 | e_pde=116064.171875 | e_bc_zero=215492.500000 | e_term=2510310.250000 | e_symm=9867.431641 | w={e_bc_zero:0.103, e_pde:1.46, e_symm:0.811, e_term:1.62}
# Epoch 4700: total=3887716.250000 | e_pde=93974.351562 | e_bc_zero=99194.015625 | e_term=2300717.500000 | e_symm=9466.728516 | w={e_bc_zero:0.103, e_pde:1.46, e_symm:0.811, e_term:1.62}
# Epoch 4800: total=3629770.250000 | e_pde=83643.429688 | e_bc_zero=49536.625000 | e_term=2154149.000000 | e_symm=9530.740234 | w={e_bc_zero:0.103, e_pde:1.46, e_symm:0.811, e_term:1.62}
# Epoch 4900: total=3474043.000000 | e_pde=57246.589844 | e_bc_zero=30852.761719 | e_term=2083256.125000 | e_symm=9331.425781 | w={e_bc_zero:0.103, e_pde:1.46, e_symm:0.811, e_term:1.62}
#
# === 3D stage: alpha=1.0, lambda=0.1 ===
# Epoch 0: total=2071402.625000 | e_pde=54483.183594 | e_bc_zero=15319.556641 | e_term=2010761.000000 | e_symm=9253.017578 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 100: total=2509365.500000 | e_pde=245683.468750 | e_bc_zero=168221.171875 | e_term=2244054.250000 | e_symm=5611.607422 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 200: total=1609048.500000 | e_pde=116758.171875 | e_bc_zero=36339.433594 | e_term=1486231.125000 | e_symm=4850.413086 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 300: total=1330832.125000 | e_pde=71089.898438 | e_bc_zero=9836.146484 | e_term=1256743.125000 | e_symm=4030.944092 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 400: total=1096942.750000 | e_pde=53618.675781 | e_bc_zero=6525.710449 | e_term=1040619.625000 | e_symm=4103.727539 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:1}
# Epoch 500: total=968929.125000 | e_pde=35379.445312 | e_bc_zero=4738.529297 | e_term=931205.187500 | e_symm=3741.243408 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 600: total=1370083.125000 | e_pde=33400.531250 | e_bc_zero=3916.617188 | e_term=855120.437500 | e_symm=3282.883057 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 700: total=1291849.375000 | e_pde=32556.330078 | e_bc_zero=2405.240234 | e_term=805492.000000 | e_symm=2826.323486 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 800: total=1199762.875000 | e_pde=25104.671875 | e_bc_zero=2063.638428 | e_term=753256.687500 | e_symm=2556.305420 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 900: total=1128185.375000 | e_pde=31641.779297 | e_bc_zero=2471.571045 | e_term=700265.062500 | e_symm=2333.086670 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1000: total=2889746.250000 | e_pde=277748.531250 | e_bc_zero=251287.906250 | e_term=1571464.500000 | e_symm=7986.078125 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1100: total=1042316.000000 | e_pde=37601.570312 | e_bc_zero=4104.346680 | e_term=637662.875000 | e_symm=3661.059814 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1200: total=9647038.000000 | e_pde=340158.968750 | e_bc_zero=2474932.000000 | e_term=5670855.500000 | e_symm=24134.410156 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1300: total=3854458.250000 | e_pde=171086.265625 | e_bc_zero=120499.078125 | e_term=2319159.500000 | e_symm=6204.363770 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1400: total=2719794.500000 | e_pde=91345.375000 | e_bc_zero=34840.867188 | e_term=1670009.875000 | e_symm=6054.220703 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:1.54}
# Epoch 1500: total=2238020.500000 | e_pde=72663.656250 | e_bc_zero=20490.564453 | e_term=1377312.500000 | e_symm=5376.264160 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 1600: total=1968852.500000 | e_pde=62326.000000 | e_bc_zero=16131.996094 | e_term=1212067.875000 | e_symm=4925.320801 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 1700: total=1873186.250000 | e_pde=118439.078125 | e_bc_zero=10426.654297 | e_term=1094696.000000 | e_symm=4316.069336 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 1800: total=1598078.375000 | e_pde=51762.843750 | e_bc_zero=7776.135742 | e_term=982957.875000 | e_symm=4391.480957 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 1900: total=1486378.500000 | e_pde=42235.562500 | e_bc_zero=6297.674805 | e_term=920175.375000 | e_symm=4239.650391 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2000: total=1414782.875000 | e_pde=37054.601562 | e_bc_zero=4302.968262 | e_term=879197.687500 | e_symm=3967.333496 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2100: total=1377094.250000 | e_pde=47312.578125 | e_bc_zero=3224.859619 | e_term=844714.250000 | e_symm=3683.681885 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2200: total=1326597.250000 | e_pde=64813.812500 | e_bc_zero=2575.283203 | e_term=794573.062500 | e_symm=3512.039795 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2300: total=1284035.125000 | e_pde=86530.585938 | e_bc_zero=2909.491455 | e_term=745184.375000 | e_symm=3517.386963 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2400: total=1164393.375000 | e_pde=38518.511719 | e_bc_zero=2163.332031 | e_term=715692.125000 | e_symm=3298.334961 | w={e_bc_zero:0.15, e_pde:1.54, e_symm:0.77, e_term:1.54}
# Epoch 2500: total=1133888.500000 | e_pde=38874.613281 | e_bc_zero=2017.762573 | e_term=695706.875000 | e_symm=2969.876953 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 2600: total=1105071.375000 | e_pde=46413.250000 | e_bc_zero=1767.025146 | e_term=668464.812500 | e_symm=3208.123779 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 2700: total=1018920.062500 | e_pde=31807.796875 | e_bc_zero=2158.578369 | e_term=627254.687500 | e_symm=2993.904297 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 2800: total=974070.375000 | e_pde=36630.976562 | e_bc_zero=1761.954712 | e_term=593360.812500 | e_symm=3058.569092 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 2900: total=11617800.000000 | e_pde=99638.937500 | e_bc_zero=4285777.500000 | e_term=7017347.500000 | e_symm=17414.365234 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3000: total=8920623.000000 | e_pde=173659.609375 | e_bc_zero=2127573.500000 | e_term=5403743.500000 | e_symm=9754.423828 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3100: total=7201406.000000 | e_pde=157536.718750 | e_bc_zero=1426368.125000 | e_term=4372920.000000 | e_symm=7460.394043 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3200: total=6046488.500000 | e_pde=133388.437500 | e_bc_zero=1046834.250000 | e_term=3684481.750000 | e_symm=7016.379883 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3300: total=5474521.000000 | e_pde=111071.351562 | e_bc_zero=833930.937500 | e_term=3356484.750000 | e_symm=6334.945801 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3400: total=4894439.500000 | e_pde=106785.187500 | e_bc_zero=602670.000000 | e_term=3006749.750000 | e_symm=6089.367188 | w={e_bc_zero:0.147, e_pde:1.54, e_symm:0.771, e_term:1.54}
# Epoch 3500: total=4491298.500000 | e_pde=106932.960938 | e_bc_zero=500777.093750 | e_term=2755099.000000 | e_symm=5662.134766 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 3600: total=4207536.000000 | e_pde=77630.468750 | e_bc_zero=393471.625000 | e_term=2590772.750000 | e_symm=5278.517090 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 3700: total=3988757.500000 | e_pde=79351.429688 | e_bc_zero=328094.687500 | e_term=2453201.750000 | e_symm=5048.983398 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 3800: total=3839128.500000 | e_pde=79958.906250 | e_bc_zero=276588.250000 | e_term=2360063.000000 | e_symm=5010.133789 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 3900: total=3591166.750000 | e_pde=53659.929688 | e_bc_zero=208166.750000 | e_term=2231904.000000 | e_symm=4907.576660 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4000: total=3433776.000000 | e_pde=54854.597656 | e_bc_zero=186251.343750 | e_term=2131354.000000 | e_symm=4732.907715 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4100: total=3308750.250000 | e_pde=46240.195312 | e_bc_zero=136695.234375 | e_term=2063058.875000 | e_symm=4706.149414 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4200: total=3191483.000000 | e_pde=46265.285156 | e_bc_zero=122701.742188 | e_term=1988958.750000 | e_symm=4366.999023 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4300: total=2939197.500000 | e_pde=48131.371094 | e_bc_zero=73715.968750 | e_term=1828474.625000 | e_symm=4600.988770 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4400: total=2742568.250000 | e_pde=36342.593750 | e_bc_zero=57504.121094 | e_term=1715328.125000 | e_symm=4516.531738 | w={e_bc_zero:0.101, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4500: total=2545124.750000 | e_pde=46002.128906 | e_bc_zero=37834.078125 | e_term=1580388.250000 | e_symm=4587.364258 | w={e_bc_zero:0.1, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4600: total=2318065.750000 | e_pde=52649.937500 | e_bc_zero=44377.644531 | e_term=1427399.375000 | e_symm=4599.885742 | w={e_bc_zero:0.1, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4700: total=2177647.250000 | e_pde=52834.207031 | e_bc_zero=41601.433594 | e_term=1337459.625000 | e_symm=4543.059082 | w={e_bc_zero:0.1, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4800: total=2031264.625000 | e_pde=36793.296875 | e_bc_zero=38008.757812 | e_term=1259908.250000 | e_symm=4576.910645 | w={e_bc_zero:0.1, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Epoch 4900: total=1942123.875000 | e_pde=54771.589844 | e_bc_zero=21651.703125 | e_term=1185677.000000 | e_symm=5009.562012 | w={e_bc_zero:0.1, e_pde:1.56, e_symm:0.78, e_term:1.56}
# Training completed in 200.15 s total.
# Done. Checkpoints in: /content/runs/pinn_oe

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/pinn_oe/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/24038bb191ad7856d1e76a991ad35ae9 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/82b029e07d48961736d72355cfdd648b (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/dd7aacbf3e1b52554d94c4ca88161ea4 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/8ec505291b173913a7f875af1243de92 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/28bb6685d29a599d573b36211f5ec6e5 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_config.json (deflated 54%)
#   adding: content/runs/pinn_oe/alpha_1p0_config.json (deflated 54%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/e85d253b869691c1b2f6f08b77df0288 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/03812a1476aef83551345b4244bad51e (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/abbf60ae58569fd31ee962822ba443a3 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/6d9c473fce12e91bd3c3de55faacc2d4 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/5d6af299c3da789cdddaf9ac659572dc (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/1b0d7d6bd4136cccf53c0340e148fb34 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/7b260be8849a9ee8498d76110d1cd2e3 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/4cae24403fad98bd977026badbd2c85c (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/b47231e7200b3cbe4d8d0b20528eb709 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/d/da18ef2859c41d5f399b36f808124785 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_config.json (deflated 51%)
#   adding: content/runs/pinn_oe/alpha_0p5_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/alpha_0p5_config.json (deflated 53%)
#   adding: content/runs/pinn_oe/alpha_0p25_config.json (deflated 54%)
#   adding: content/runs/pinn_oe/alpha_0p9_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/alpha_1p0_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/alpha_0p9_config.json (deflated 54%)
#   adding: content/runs/pinn_oe/alpha_0p25_history.pkl (deflated 59%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/7cdcd158640b083a79e3a0bfe6788621 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/7a290df041392120ed8af82921b1e8cd (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/f377a8d68086d5e598e51bfcdd85e77c (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/4d670fc38d2c49a864e6c1fd6db58d91 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/a58b1db7d7169cea1321c2dee0efc6cd (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/2d_lam0_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/8aa45f5b37705d8d933f4022a50f53b8 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/5fbe2a8deea89830115558f16b776994 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/de4ded22f3ba120fa81c0117db92f46f (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/8ea7f0aeac32ef3d81874cde712e0d89 (deflated 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/498afc1c81457113d30c0df3ca067554 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/2d_lam0_history.pkl (deflated 62%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/process_0 (deflated 84%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/aa1c907f6157300ae514f0457b438f47 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/e5347c23a16d255c43f1bb3fe45c002e (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/231caa07a9a18c41c341cd4f86a085bc (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/6d9cabcb4df93c31a97b3cc46419819e (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/cff83a85ea32414f2a1103b6b6949cdf (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_sharding (deflated 85%)

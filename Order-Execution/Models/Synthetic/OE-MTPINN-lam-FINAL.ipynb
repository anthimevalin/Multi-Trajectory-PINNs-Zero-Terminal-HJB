# %% [markdown]
# **RUN ON GOOGLE COLAB**

# %%
# !pip install ml-collections
# Out:
# Collecting ml-collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml-collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: ml-collections
# Successfully installed ml-collections-1.1.0

# %%
# ====== Imports ======
import os, json, time, pickle, shutil
import numpy as np
import jax
import jax.numpy as jnp
from jax import jit, grad, value_and_grad, vmap
import flax
import flax.linen as nn
from flax.training import train_state
from flax.linen.initializers import glorot_normal, zeros, normal
import optax
import ml_collections
import orbax.checkpoint as ocp

jran = jax.random


# ====== NN definition ======
activation_fn = { "tanh": jnp.tanh, "sin": jnp.sin }

def _get_activation(s):
    if s in activation_fn:
        return activation_fn[s]
    raise NotImplementedError(f"Activation {s} not supported yet!")

def _weight_fact(init_fn, mean, stddev):
    def init(key, shape):
        key1, key2 = jran.split(key)
        w = init_fn(key1, shape)
        g = mean + normal(stddev)(key2, (shape[-1],))
        g = jnp.exp(g)
        v = w / g
        return g, v
    return init

class Dense(nn.Module):
    features: int
    kernel_init: callable = glorot_normal()
    bias_init: callable = zeros
    reparam: dict | None = None

    @nn.compact
    def __call__(self, x):
        if self.reparam is None:
            kernel = self.param("kernel", self.kernel_init, (x.shape[-1], self.features))
        elif self.reparam["type"] == "weight_fact":
            g, v = self.param(
                "kernel",
                _weight_fact(self.kernel_init, mean=self.reparam["mean"], stddev=self.reparam["stddev"]),
                (x.shape[-1], self.features),
            )
            kernel = g * v
        bias = self.param("bias", self.bias_init, (self.features,))
        return jnp.dot(x, kernel) + bias

class MLP(nn.Module):
    arch_name: str = "MLP"
    hidden_dim: tuple[int, ...] = (32, 16)
    out_dim: int = 1
    activation: str = "tanh"
    periodicity: dict | None = None
    fourier_emb: dict | None = None
    reparam: dict | None = None

    def setup(self):
        self.activation_fn = _get_activation(self.activation)

    @nn.compact
    def __call__(self, x):
        for h in self.hidden_dim:
            x = Dense(features=h, reparam=self.reparam)(x)
            x = self.activation_fn(x)
        x = Dense(features=self.out_dim, reparam=self.reparam)(x)
        return x

def ann_gen(config):
    reparam = None
    if getattr(config, "ann_reparam", False) == "weight_fact":
        reparam = ml_collections.ConfigDict({"type": "weight_fact", "mean": 0.5, "stddev": 0.1})
    if config.ann_str == "MLP":
        return MLP(
            arch_name=config.ann_str,
            hidden_dim=tuple(config.ann_hidden_dim),
            out_dim=config.ann_out_dim,
            activation=config.ann_activation_str,
            periodicity=config.ann_periodicity,
            fourier_emb=config.ann_fourier_emb,
            reparam=reparam,
        )
    raise NotImplementedError(f"Unknown arch {config.ann_str}")


# ====== Derivatives ======
def derivatives_2d(fn2d, x):
    def f(z): return fn2d(z)[0]
    dx = vmap(grad(f), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_x   = dx.T[1]
    return Gamma_tau, Gamma_x

def derivatives_3d(fn3d, x):
    def f(z): return fn3d(z)[0]
    def f_dx(z): return grad(f)(z)[2]
    dx  = vmap(grad(f), 0)(x)
    d2x = vmap(grad(f_dx), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_X   = dx.T[1]
    Gamma_S   = dx.T[2]
    Gamma_SS  = d2x.T[2]
    return Gamma_tau, Gamma_X, Gamma_S, Gamma_SS


# ====== Data samplers ======
def get_data_2d(n_pde=10000, n_bc=500, T=5.0, x_range=(-10.,10.), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde])
    # x=0 boundary along tau
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc])
    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), T

def get_data_3d(n_pde=10000, n_bc=1000, n_term=100, T=5.0, x_range=(-10.,10.), s_range=(10,100), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    S_pde = rng.uniform(s_range[0], s_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde, S_pde])
    # IC
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    S_bc   = rng.uniform(s_range[0], s_range[1], size=(n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc, S_bc])
    # Terminal at tau=0, x=0: V=0
    tau_term = np.zeros((n_term, 1))
    S_term   = rng.uniform(s_range[0], s_range[1], size=(n_term, 1))
    x_term   = np.zeros((n_term, 1))
    x_term_zero = np.hstack([tau_term, x_term, S_term])
    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), jnp.array(x_term_zero), T


# ====== Error terms ======
def error_2d(config, fn2d, data):
    x_tau_pde, x_bc_zero, T = data
    Gamma_tau, Gamma_X = derivatives_2d(fn2d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    kappa = config.kappa
    # PDE residual
    e_pde = ( Gamma_tau - (kappa**2 * X_vals**2) + 0.25 * Gamma_X**2 )**2
    # IC 
    e_bc_zero = fn2d(x_bc_zero).squeeze()**2
    # Symmetry 
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1])
    e_symm = (fn2d(z).squeeze() - fn2d(z_flip).squeeze())**2
    # Multi-trajectory penalty
    def single_path_penalty_2d(fn2d, *, X0, T=1.0, Ndt=200):
        X0 = jnp.atleast_1d(X0); dt = T / Ndt
        def f(z): return fn2d(z)[0]
        def step(carry, _):
            x_curr, t_curr = carry
            tau = T - t_curr
            z = jnp.stack([tau, x_curr], axis=1)
            dX = vmap(grad(f))(z)[:,1]
            v = 0.5 * dX
            return (x_curr - dt*v, t_curr + dt), None
        (x_T, _), _ = jax.lax.scan(step, (X0, jnp.zeros_like(X0)), None, length=Ndt)
        return jnp.mean(x_T**2)

    def multi_T_traj_penalty_2d(fn2d, *, X0, T_list, Ndt=200):
        T_list = jnp.atleast_1d(jnp.array(T_list))
        penalties = jax.vmap(lambda Ti: single_path_penalty_2d(fn2d, X0=X0, T=Ti, Ndt=Ndt))(T_list)
        return jnp.mean(penalties)

    Ndt     = config.traj_Ndt
    n_X     = config.n_X
    T_list  = config.T_list
    X0_vals = jnp.linspace(config.x_range[0], config.x_range[1], n_X)
    e_traj  = multi_T_traj_penalty_2d(fn2d, X0=X0_vals, T_list=T_list, Ndt=Ndt)

    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_symm": jnp.mean(e_symm),
        "e_traj": jnp.mean(e_traj),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_symm": e_symm, "e_traj": e_traj}, metrics

def error_3d(config, fn3d, data):
    x_tau_pde, x_bc_zero, x_term_zero, T = data
    Gamma_tau, Gamma_X, _, Gamma_SS = derivatives_3d(fn3d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    S_vals   = x_tau_pde[:,2]

    kappa = config.kappa
    sigma = config.sigma
    lam   = config.lam

    # PDE residual
    e_pde = (
        Gamma_tau
        - 0.5 * sigma**2 * S_vals**2 * Gamma_SS
        - (kappa**2 * X_vals**2 + lam * S_vals * X_vals)
        + 0.25 * Gamma_X**2
    )**2
    # IC
    e_bc_zero = jnp.maximum(fn3d(x_bc_zero).squeeze() - 1e-6, 0.0)**2
    # Terminal
    e_term = fn3d(x_term_zero).squeeze()**2
    # Symmetry
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1]).at[:, 2].set(-z[:, 2])
    e_symm = (fn3d(z).squeeze() - fn3d(z_flip).squeeze())**2
    # Multi-trajectory
    def single_path_penalty_3d(fn3d, *, X0, S0, T=1.0, Ndt=200):
        X0 = jnp.atleast_1d(X0); S0 = jnp.atleast_1d(S0)
        dt = T / Ndt
        def f(z): return fn3d(z)[0]
        def step(carry, _):
            x_curr, t_curr = carry
            tau = T - t_curr
            z = jnp.stack([tau, x_curr, S0], axis=1)
            dX = vmap(grad(f))(z)[:,1]
            v = 0.5 * dX
            return (x_curr - dt*v, t_curr + dt), None
        (x_T, _), _ = jax.lax.scan(step, (X0, jnp.zeros_like(X0)), None, length=Ndt)
        return jnp.mean(x_T**2)

    def multi_T_traj_penalty_3d(fn3d, *, X0, S0, T_list, Ndt=200):
        T_list = jnp.atleast_1d(jnp.array(T_list))
        penalties = jax.vmap(lambda Ti: single_path_penalty_3d(fn3d, X0=X0, S0=S0, T=Ti, Ndt=Ndt))(T_list)
        return jnp.mean(penalties)

    T_list  = config.T_list
    Ndt     = config.traj_Ndt
    n_X     = config.n_X
    X0_vals = jnp.linspace(config.x_range[0], config.x_range[1], n_X)
    n_S     = config.n_S
    S0_vals = jnp.linspace(config.s_range[0], config.s_range[1], n_S)
    S0_grid, X0_grid = jnp.meshgrid(S0_vals, X0_vals)
    e_traj  = multi_T_traj_penalty_3d(fn3d, X0=X0_grid.flatten(), S0=S0_grid.flatten(), T_list=T_list, Ndt=Ndt)

    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_term": jnp.mean(e_term),
        "e_symm": jnp.mean(e_symm),
        "e_traj": jnp.mean(e_traj),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_term": e_term, "e_symm": e_symm, "e_traj": e_traj}, metrics

def error(config, fn, data):
    return error_2d(config, fn, data) if len(data) == 3 else error_3d(config, fn, data)


# ====== 2D -> 3D parameter inflation ======
def inflate_2d_to_3d_params(params_2d, params_3d_init, first_dense="Dense_0"):
    """
    Take trained 2D params (inputs [tau, x]) and freshly inited 3D params (tau, x, S]).
    Return params_3d with an added zero row for S in the first Dense kernel.
    """
    p2 = flax.core.unfreeze(params_2d)
    p3 = flax.core.unfreeze(params_3d_init)
    for mod, wdict in p2["params"].items():
        for name, arr in wdict.items():
            if (mod, name) == (first_dense, "kernel"):
                continue
            if arr.shape == p3["params"][mod][name].shape:
                p3["params"][mod][name] = arr
    k2 = p2["params"][first_dense]["kernel"]   
    H  = k2.shape[1]
    k3 = jnp.concatenate([k2, jnp.zeros((1, H))], axis=0)
    p3["params"][first_dense]["kernel"] = k3
    p3["params"][first_dense]["bias"]   = p2["params"][first_dense]["bias"]
    return flax.core.freeze(p3)


# ====== Loss assembly ======
def adj(loss, lw, m):  
    return lw * jnp.mean(m * loss)

ALL_COMPONENTS = ['e_pde', 'e_bc_zero', 'e_term', 'e_symm', 'e_traj']

def make_loss_lb():
    def loss_fn(config, fn, data, l_ws, params_sa):
        err, metrics = error(config, fn, data)
        components = [k for k in ALL_COMPONENTS if k in err]
        loss_terms = {}
        for k in components:
            w_k = l_ws.get(k, 1.0)
            m_k = params_sa.get(k, jnp.ones_like(err[k]))
            loss_terms[k] = adj(err[k], w_k, m_k)
        return loss_terms, metrics
    return loss_fn

loss_fn_lb = { "MLP": make_loss_lb(), "PINN": make_loss_lb() }

def make_loss_fn(components_key):
    def loss_fn(config, fn, data, l_ws, params_sa):
        loss_terms, metrics = loss_fn_lb[components_key](config, fn, data, l_ws, params_sa)
        total = jnp.sum(jnp.array(list(loss_terms.values())))
        return total, metrics
    return loss_fn

loss_fn = { "MLP": make_loss_fn("MLP"), "PINN": make_loss_fn("PINN") }


def init_params_sa(loss_str, data):
    if len(data) == 3:
        x_tau_pde, x_bc_zero, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_traj": jnp.ones(1),
        }
    elif len(data) == 4:
        x_tau_pde, x_bc_zero, x_term_zero, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_term": jnp.ones(len(x_term_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_traj": jnp.ones(1),
        }
    else:
        raise ValueError("Unexpected data tuple length in init_params_sa.")

# Initial static weights 
init_l_ws = {
    "PINN": { 'e_pde': 1.0, 'e_bc_zero': 0.1, 'e_term': 0.1, 'e_symm': 0.5, 'e_traj': 1.0 }
}


# ====== Rebalancer ======
class Rebalancer:
    def __init__(
        self, keys,
        ema_beta=0.95,
        power=0.2,
        w_clip=(0.5, 2.0),
        ema_floor=1e-4,
        allow_upweight_small=False,
        freeze_tol=1e-5,
        freeze_patience=10,
        base_weights=None,      
        static_keys=None,         
        relative_to_init=True,
        eps=1e-12,
    ):
        self.keys = list(keys)
        self.ema_beta = float(ema_beta)
        self.power = float(power)
        self.w_min, self.w_max = map(float, w_clip)
        self.ema_floor = float(ema_floor)
        self.allow_upweight_small = bool(allow_upweight_small)
        self.freeze_tol = float(freeze_tol)
        self.freeze_patience = int(freeze_patience)
        self.base_weights = dict(base_weights or {})
        self.static_keys = set(static_keys or ())
        self.relative_to_init = bool(relative_to_init)
        self.eps = float(eps)

        self.ema = {k: None for k in self.keys}
        self.init_ema = {k: None for k in self.keys}
        self.below_ctr = {k: 0 for k in self.keys}
        self.frozen = {k: False for k in self.keys}

    def _smooth_update(self, old, new):
        if old is None:
            return new
        return self.ema_beta * old + (1.0 - self.ema_beta) * new

    def step(self, metrics, weights):
        for k in self.keys:
            if k not in metrics:
                continue
            val = float(metrics[k])
            val = max(val, self.ema_floor) 
            self.ema[k] = self._smooth_update(self.ema[k], val)
            if self.init_ema[k] is None:
                self.init_ema[k] = self.ema[k]

            if self.ema[k] < self.freeze_tol:
                self.below_ctr[k] += 1
            else:
                self.below_ctr[k] = 0
            if self.freeze_patience > 0 and self.below_ctr[k] >= self.freeze_patience:
                self.frozen[k] = True

        present = [
            k for k in self.keys
            if (k in metrics and self.ema[k] is not None and not self.frozen[k] and k not in self.static_keys)
        ]
        if not present:
            new_w = dict(weights)
            for k in self.keys:
                if self.frozen[k]:
                    new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
            return new_w

        def rel_ema(k):
            if not self.relative_to_init:
                return max(self.ema[k], self.ema_floor)
            denom = max(self.init_ema[k] or self.ema_floor, self.ema_floor)
            return max(self.ema[k] / denom, self.ema_floor)

        rels = {k: rel_ema(k) for k in present}
        gmean = float(np.exp(np.mean([np.log(max(rels[k], self.eps)) for k in present])))

        new_w = dict(weights)
        for k in self.keys:
            if self.frozen[k]:
                new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
                continue
            if k in self.static_keys or k not in rels:
                new_w[k] = float(new_w.get(k, 1.0))
                continue

            ratio = max(rels[k] / gmean, self.eps)
            if not self.allow_upweight_small and ratio < 1.0:
                mult = 1.0 
            else:
                mult = ratio ** (-self.power)

            new_w[k] = float(np.clip(new_w.get(k, 1.0) * mult, self.w_min, self.w_max))

        mean_w = float(np.mean([new_w[k] for k in present])) if present else 1.0
        if mean_w > 0:
            for k in present:
                new_w[k] = new_w[k] / mean_w
        return new_w


# ====== Training ======
def calibration(config, data, params_init=None, l_ws=None, params_sa=None):
    ann = ann_gen(config)
    ofunc = loss_fn[config.loss_str]

    if l_ws is None:
        l_ws = dict(init_l_ws[config.loss_str])
    if params_sa is None:
        params_sa = init_params_sa(config.loss_str, data)

        rebal_cfg = getattr(config, "rebal", None)
    if rebal_cfg is None:
        rebal_cfg = ml_collections.ConfigDict({})

    rebal = Rebalancer(
        keys=[k for k in ALL_COMPONENTS if k in (params_sa.keys())],
        ema_beta=getattr(rebal_cfg, "ema_beta", 0.98),
        power=getattr(rebal_cfg, "power", 0.2),
        w_clip=tuple(getattr(rebal_cfg, "w_clip", (0.3, 3.0))),
        ema_floor=getattr(rebal_cfg, "ema_floor", 1e-3),
        allow_upweight_small=getattr(rebal_cfg, "allow_upweight_small", False),
        freeze_tol=getattr(rebal_cfg, "freeze_tol", 1e-4),
        freeze_patience=getattr(rebal_cfg, "freeze_patience", 10),
        base_weights=dict(getattr(rebal_cfg, "base_weights", {"e_bc_zero": 0.1})),
        static_keys=set(getattr(rebal_cfg, "static_keys", ())),
        relative_to_init=getattr(rebal_cfg, "relative_to_init", True),
    )


    key = jran.PRNGKey(config.seed)
    _, key_init = jran.split(key, 2)
    dummy = jnp.ones((1, config.ann_in_dim))
    params0 = ann.init(key_init, dummy) if params_init is None else params_init

    state = train_state.TrainState.create(
        apply_fn=ann.apply,
        params=params0,
        tx=optax.adamw(learning_rate=5e-4)
    )

    @jit
    def train_step(state, data, l_ws, params_sa):
        def wrapped_loss(params):
            def fn(x): return ann.apply(params, x)
            return ofunc(config, fn, data, l_ws, params_sa)
        (loss, metrics), grads = value_and_grad(wrapped_loss, has_aux=True)(state.params)
        state = state.apply_gradients(grads=grads)
        return state, loss, metrics

    hist = []
    for epoch in range(config.num_epochs):
        state, loss, metrics = train_step(state, data, l_ws, params_sa)

        if (epoch >= rebal_cfg.start_epoch) and ((epoch - rebal_cfg.start_epoch) % rebal_cfg.every == 0):
            l_ws = rebal.step(metrics, l_ws)

        if epoch % 100 == 0:
            w_str = "{"+", ".join(f"{k}:{l_ws.get(k,1.0):.3g}" for k in sorted(l_ws.keys()))+"}"
            keys = ['e_pde','e_bc_zero','e_term','e_symm','e_traj']
            msg  = " | ".join(f"{k}={float(metrics[k]):.6f}" for k in keys if k in metrics)
            print(f"Epoch {epoch}: total={float(loss):.6f} | {msg} | w={w_str}")

        hist.append((int(epoch), float(loss), {k: float(metrics[k]) for k in metrics}))

    return (lambda x: ann.apply(state.params, x)), hist, state.params, ann


# ====== Curriculum runner ======
def save_params_overwrite(path, params):
    path = os.path.abspath(path)
    if os.path.exists(path):
        shutil.rmtree(path)
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    try:
        ckptr.save(path, params, force=True)  
    except TypeError:
        ckptr.save(path, params)            

def save_stage(run_dir, tag, *, params, config, history):
    """
    writes:
      - {run_dir}/{tag}_params/  
      - {run_dir}/{tag}_config.json
      - {run_dir}/{tag}_history.pkl
    """
    run_dir = os.path.abspath(run_dir)
    os.makedirs(run_dir, exist_ok=True)
    save_params_overwrite(os.path.join(run_dir, f"{tag}_params"), params)
    def _to_jsonable(obj):
        try:
            return obj.to_dict()
        except Exception:
            if isinstance(obj, (dict, list, str, int, float, bool)) or obj is None:
                return obj
            if hasattr(obj, "items"):
                return {k: _to_jsonable(v) for k, v in obj.items()}
            return str(obj)
    with open(os.path.join(run_dir, f"{tag}_config.json"), "w") as f:
        json.dump(_to_jsonable(config), f, indent=2)
    with open(os.path.join(run_dir, f"{tag}_history.pkl"), "wb") as f:
        pickle.dump(history, f)

def restore_params(run_dir, tag):
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    return ckptr.restore(os.path.abspath(os.path.join(run_dir, f"{tag}_params")))

def run_curriculum(config2d, config3d, lam_star, workdir=None):
    # ---- Phase A: 2D (lambda=0) ----
    config2d.dim = 2
    config2d.ann_in_dim = 2
    config2d.lam = 0.0
    alphas = config3d.alphas
    workdir = os.path.abspath(workdir or getattr(config3d, "workdir", "runs/pinn_oe"))
    os.makedirs(workdir, exist_ok=True)

    data2d = get_data_2d(
        n_pde=config2d.pts_num, n_bc=config2d.n_term_zero,
        T=config2d.T, x_range=config2d.x_range, seed=config2d.seed
    )
    _, hist2d, params_2d, _ = calibration(config2d, data2d)

    # save 2D stage
    save_stage(workdir, "2d_lam0", params=params_2d, config=config2d, history=hist2d)

    if alphas is None:
        return params_2d, {"2d": hist2d}

    # ---- Phase B: inflate to 3D, then curriculum over lambda ----
    config3d.dim = 3
    config3d.ann_in_dim = 3
    ann3d = ann_gen(config3d)
    params_3d_init = ann3d.init(jran.PRNGKey(1), jnp.ones((1,3)))
    params = inflate_2d_to_3d_params(params_2d, params_3d_init)

    data3d = get_data_3d(
        n_pde=config3d.pts_num, n_bc=config3d.n_bc_zero, n_term=config3d.n_term_zero,
        T=config3d.T, x_range=config3d.x_range, s_range=config3d.s_range, seed=config3d.seed
    )

    all_hist = {"2d": hist2d}
    start = time.time()
    for alpha in alphas:
        lam_stage = float(alpha * lam_star)
        print(f"\n=== 3D stage: alpha={alpha}, lambda={lam_stage} ===")
        config3d.lam = lam_stage
        _, hist, params, _ = calibration(config3d, data3d, params_init=params)
        all_hist[f"alpha_{alpha}"] = hist
        tag = f"alpha_{alpha}".replace('.', 'p') 
        save_stage(workdir, tag, params=params, config=config3d, history=hist)

    print(f"Training completed in {time.time() - start:.2f} s total.")
    return params, all_hist


# ====== Model builder ======
def build_model_fn(config, params):
    ann = ann_gen(config)
    return jax.jit(lambda x: ann.apply(params, x))  # x: (N, in_dim)

T=5.0
# ====== Default configs ======
def default_configs():
    config2d = ml_collections.ConfigDict({
        "seed": 42,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (32, 32, 32),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 2,
        "ann_in_dim": 2,
        "num_epochs": 30000,
        "pts_num": 30000,
        "x_range": (-10.0, 10.0),
        "T": T,
        "T_list": [T/50, T/10, T/5, 2*T/5, 3*T/5, 4*T/5, T],
        "traj_Ndt": 200,
        "n_X": 41,
        "kappa": 0.1,
        "lam": 0.1,             # not used in 2D residual
        "n_term_zero": 2000,    
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 5000,
            "ema_beta": 0.9,
            "power": 0.1,
            "w_clip": (0.1, 2.0),
        }),
    })

    config3d = ml_collections.ConfigDict({
        "seed": 43,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (32, 32, 32),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 3,
        "ann_in_dim": 3,
        "num_epochs": 5000,
        "pts_num": 30000,
        "x_range": (-10.0, 10.0),
        "s_range": (10.0, 100.0),
        "T": T,
        "T_list": [T/50, T/10, T/5, 2*T/5, 3*T/5, 4*T/5, T],
        "traj_Ndt":200,
        "n_X": 41,
        "n_S": 20,
        "kappa": 0.1,
        "sigma": 0.1,
        "lam": 0.1,             
        "n_bc_zero": 2000,     
        "n_term_zero": 200,     
        "alphas": (0.25, 0.5, 0.75, 0.9, 1.0),
        "workdir": os.path.abspath("runs/pinn_oe"),
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 1000,
            "ema_beta": 0.95,
            "power": 0.3,
            "w_clip": (0.1, 2.0),
        }),
    })
    return config2d, config3d


config2d, config3d = default_configs()
final_params, all_hist = run_curriculum(config2d, config3d, lam_star=config3d.lam, workdir=config3d.workdir)
model_PINN = build_model_fn(config3d, final_params)
print("Done. Checkpoints in:", config3d.workdir)
# Out:
# Epoch 0: total=37.300133 | e_pde=0.181200 | e_bc_zero=0.637321 | e_symm=3.149879 | e_traj=35.480263 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 100: total=33.621399 | e_pde=0.274856 | e_bc_zero=1.528412 | e_symm=0.025902 | e_traj=33.180752 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 200: total=28.988827 | e_pde=0.866315 | e_bc_zero=9.493636 | e_symm=0.022098 | e_traj=27.162098 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 300: total=23.698265 | e_pde=1.107100 | e_bc_zero=9.070860 | e_symm=0.022508 | e_traj=21.672825 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 400: total=21.271814 | e_pde=0.705578 | e_bc_zero=7.265550 | e_symm=0.009307 | e_traj=19.835028 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 500: total=19.731903 | e_pde=0.426975 | e_bc_zero=7.128941 | e_symm=0.007912 | e_traj=18.588078 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 600: total=27.536921 | e_pde=0.354678 | e_bc_zero=5.616374 | e_symm=0.013992 | e_traj=16.975687 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 700: total=25.864620 | e_pde=0.344811 | e_bc_zero=3.803835 | e_symm=0.021396 | e_traj=16.076111 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 800: total=24.700470 | e_pde=0.344701 | e_bc_zero=3.028008 | e_symm=0.018560 | e_traj=15.398523 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 900: total=23.725533 | e_pde=0.359379 | e_bc_zero=2.498765 | e_symm=0.018935 | e_traj=14.802873 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1000: total=22.957697 | e_pde=0.352974 | e_bc_zero=2.089948 | e_symm=0.023432 | e_traj=14.348817 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1100: total=22.350542 | e_pde=0.345234 | e_bc_zero=1.813724 | e_symm=0.051696 | e_traj=13.975398 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1200: total=21.763432 | e_pde=0.326128 | e_bc_zero=1.599717 | e_symm=0.016567 | e_traj=13.651847 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1300: total=21.272879 | e_pde=0.306040 | e_bc_zero=1.430972 | e_symm=0.017926 | e_traj=13.369271 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1400: total=20.820328 | e_pde=0.276282 | e_bc_zero=1.152242 | e_symm=0.009237 | e_traj=13.137088 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1500: total=20.417522 | e_pde=0.257478 | e_bc_zero=1.195925 | e_symm=0.009876 | e_traj=12.889380 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1600: total=20.046864 | e_pde=0.248390 | e_bc_zero=1.067772 | e_symm=0.013898 | e_traj=12.668344 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1700: total=19.702072 | e_pde=0.237567 | e_bc_zero=0.871600 | e_symm=0.016681 | e_traj=12.473279 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1800: total=19.374216 | e_pde=0.230421 | e_bc_zero=0.857727 | e_symm=0.021127 | e_traj=12.266482 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 1900: total=19.059095 | e_pde=0.225395 | e_bc_zero=0.935611 | e_symm=0.017984 | e_traj=12.060464 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2000: total=18.757952 | e_pde=0.221662 | e_bc_zero=0.767881 | e_symm=0.022441 | e_traj=11.882998 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2100: total=18.450535 | e_pde=0.225199 | e_bc_zero=0.743121 | e_symm=0.022404 | e_traj=11.682135 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2200: total=18.137030 | e_pde=0.237893 | e_bc_zero=0.652934 | e_symm=0.030866 | e_traj=11.470450 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2300: total=17.835737 | e_pde=0.241958 | e_bc_zero=0.752664 | e_symm=0.028466 | e_traj=11.261771 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2400: total=17.522371 | e_pde=0.241788 | e_bc_zero=0.650698 | e_symm=0.025507 | e_traj=11.069930 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2500: total=17.235464 | e_pde=0.241996 | e_bc_zero=0.640500 | e_symm=0.017045 | e_traj=10.888483 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2600: total=16.965387 | e_pde=0.249396 | e_bc_zero=0.542207 | e_symm=0.019244 | e_traj=10.714263 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2700: total=16.699202 | e_pde=0.254138 | e_bc_zero=0.527620 | e_symm=0.014896 | e_traj=10.540133 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2800: total=16.464849 | e_pde=0.248273 | e_bc_zero=0.551866 | e_symm=0.015928 | e_traj=10.390728 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 2900: total=16.249172 | e_pde=0.261396 | e_bc_zero=0.536030 | e_symm=0.019212 | e_traj=10.237358 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3000: total=16.070707 | e_pde=0.232772 | e_bc_zero=0.466279 | e_symm=0.049982 | e_traj=10.141568 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3100: total=15.813504 | e_pde=0.236262 | e_bc_zero=0.407112 | e_symm=0.013475 | e_traj=9.995067 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3200: total=15.612087 | e_pde=0.224326 | e_bc_zero=0.393740 | e_symm=0.013927 | e_traj=9.877193 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3300: total=15.419609 | e_pde=0.208463 | e_bc_zero=0.377990 | e_symm=0.009460 | e_traj=9.771753 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3400: total=15.237042 | e_pde=0.206598 | e_bc_zero=0.320577 | e_symm=0.008203 | e_traj=9.661320 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3500: total=15.071346 | e_pde=0.198510 | e_bc_zero=0.304473 | e_symm=0.018354 | e_traj=9.558241 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3600: total=14.932247 | e_pde=0.194782 | e_bc_zero=0.295354 | e_symm=0.054686 | e_traj=9.454300 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3700: total=14.735305 | e_pde=0.189996 | e_bc_zero=0.324579 | e_symm=0.020790 | e_traj=9.345099 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3800: total=14.566747 | e_pde=0.182580 | e_bc_zero=0.343639 | e_symm=0.013585 | e_traj=9.244649 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 3900: total=14.402932 | e_pde=0.177159 | e_bc_zero=0.266410 | e_symm=0.007404 | e_traj=9.154404 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4000: total=14.261950 | e_pde=0.179139 | e_bc_zero=0.253722 | e_symm=0.010742 | e_traj=9.060386 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4100: total=14.106985 | e_pde=0.179114 | e_bc_zero=0.241712 | e_symm=0.006716 | e_traj=8.962897 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4200: total=13.959058 | e_pde=0.169962 | e_bc_zero=0.256863 | e_symm=0.008210 | e_traj=8.873633 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4300: total=13.827405 | e_pde=0.163226 | e_bc_zero=0.246712 | e_symm=0.019824 | e_traj=8.790004 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4400: total=13.726097 | e_pde=0.147351 | e_bc_zero=0.221673 | e_symm=0.024039 | e_traj=8.740425 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4500: total=13.541389 | e_pde=0.156990 | e_bc_zero=0.245890 | e_symm=0.007534 | e_traj=8.616556 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4600: total=13.529704 | e_pde=0.148709 | e_bc_zero=0.246974 | e_symm=0.135803 | e_traj=8.552999 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4700: total=13.287779 | e_pde=0.143012 | e_bc_zero=0.223728 | e_symm=0.007446 | e_traj=8.467948 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4800: total=13.165164 | e_pde=0.142960 | e_bc_zero=0.180993 | e_symm=0.019339 | e_traj=8.386627 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 4900: total=13.054914 | e_pde=0.146076 | e_bc_zero=0.229572 | e_symm=0.017684 | e_traj=8.307819 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5000: total=12.956755 | e_pde=0.135828 | e_bc_zero=0.193642 | e_symm=0.058272 | e_traj=8.237562 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5100: total=12.798020 | e_pde=0.134084 | e_bc_zero=0.202779 | e_symm=0.006630 | e_traj=8.161036 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5200: total=12.683748 | e_pde=0.127154 | e_bc_zero=0.189992 | e_symm=0.008067 | e_traj=8.094250 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5300: total=12.575073 | e_pde=0.124326 | e_bc_zero=0.161662 | e_symm=0.007742 | e_traj=8.029434 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5400: total=12.501333 | e_pde=0.123272 | e_bc_zero=0.151615 | e_symm=0.051123 | e_traj=7.961871 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.769, e_term:0.1, e_traj:1.54}
# Epoch 5500: total=12.362185 | e_pde=0.119548 | e_bc_zero=0.164093 | e_symm=0.009607 | e_traj=7.894660 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 5600: total=12.266405 | e_pde=0.117942 | e_bc_zero=0.148949 | e_symm=0.006677 | e_traj=7.825542 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 5700: total=12.162316 | e_pde=0.119828 | e_bc_zero=0.146859 | e_symm=0.008683 | e_traj=7.755309 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 5800: total=12.093599 | e_pde=0.116618 | e_bc_zero=0.177035 | e_symm=0.041615 | e_traj=7.694558 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 5900: total=12.018582 | e_pde=0.111060 | e_bc_zero=0.155042 | e_symm=0.058577 | e_traj=7.645205 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6000: total=11.908122 | e_pde=0.104520 | e_bc_zero=0.120942 | e_symm=0.049352 | e_traj=7.588038 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6100: total=11.661901 | e_pde=0.102402 | e_bc_zero=0.159493 | e_symm=0.012825 | e_traj=7.444614 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6200: total=11.603690 | e_pde=0.097421 | e_bc_zero=0.149003 | e_symm=0.072637 | e_traj=7.383179 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6300: total=11.601008 | e_pde=0.094793 | e_bc_zero=0.164512 | e_symm=0.199241 | e_traj=7.319687 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6400: total=11.343264 | e_pde=0.098354 | e_bc_zero=0.172225 | e_symm=0.012519 | e_traj=7.240726 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6500: total=11.256393 | e_pde=0.095979 | e_bc_zero=0.142354 | e_symm=0.030723 | e_traj=7.180669 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6600: total=11.139380 | e_pde=0.092005 | e_bc_zero=0.140401 | e_symm=0.007779 | e_traj=7.120275 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6700: total=11.069333 | e_pde=0.097169 | e_bc_zero=0.121915 | e_symm=0.025173 | e_traj=7.062863 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6800: total=10.979515 | e_pde=0.099606 | e_bc_zero=0.140872 | e_symm=0.028493 | e_traj=6.998585 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 6900: total=10.883086 | e_pde=0.097646 | e_bc_zero=0.136268 | e_symm=0.022956 | e_traj=6.941164 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7000: total=10.884216 | e_pde=0.106973 | e_bc_zero=0.104093 | e_symm=0.108208 | e_traj=6.893481 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7100: total=10.704814 | e_pde=0.096775 | e_bc_zero=0.132344 | e_symm=0.009905 | e_traj=6.833194 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7200: total=10.620351 | e_pde=0.098228 | e_bc_zero=0.131951 | e_symm=0.010586 | e_traj=6.776620 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7300: total=10.560155 | e_pde=0.097549 | e_bc_zero=0.122955 | e_symm=0.034375 | e_traj=6.727323 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7400: total=10.474297 | e_pde=0.105344 | e_bc_zero=0.127819 | e_symm=0.019569 | e_traj=6.670660 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7500: total=10.397868 | e_pde=0.094779 | e_bc_zero=0.124221 | e_symm=0.016246 | e_traj=6.633628 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7600: total=10.324808 | e_pde=0.111768 | e_bc_zero=0.147470 | e_symm=0.015672 | e_traj=6.567179 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7700: total=10.224877 | e_pde=0.093550 | e_bc_zero=0.112771 | e_symm=0.010677 | e_traj=6.526483 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7800: total=10.189322 | e_pde=0.094049 | e_bc_zero=0.091633 | e_symm=0.054334 | e_traj=6.483355 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 7900: total=10.077168 | e_pde=0.095274 | e_bc_zero=0.107533 | e_symm=0.012000 | e_traj=6.428753 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8000: total=10.030039 | e_pde=0.093517 | e_bc_zero=0.129292 | e_symm=0.045468 | e_traj=6.381136 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8100: total=9.925564 | e_pde=0.092693 | e_bc_zero=0.110561 | e_symm=0.011421 | e_traj=6.332918 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8200: total=9.868191 | e_pde=0.097439 | e_bc_zero=0.109313 | e_symm=0.015162 | e_traj=6.289202 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8300: total=9.864326 | e_pde=0.103096 | e_bc_zero=0.077857 | e_symm=0.097970 | e_traj=6.243087 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8400: total=9.716575 | e_pde=0.098880 | e_bc_zero=0.107129 | e_symm=0.016924 | e_traj=6.188696 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8500: total=9.646144 | e_pde=0.100189 | e_bc_zero=0.088972 | e_symm=0.011163 | e_traj=6.146348 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8600: total=9.601439 | e_pde=0.101333 | e_bc_zero=0.101161 | e_symm=0.038809 | e_traj=6.101248 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8700: total=9.522584 | e_pde=0.102212 | e_bc_zero=0.089181 | e_symm=0.017119 | e_traj=6.061149 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8800: total=9.463213 | e_pde=0.102888 | e_bc_zero=0.096868 | e_symm=0.029706 | e_traj=6.014923 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 8900: total=9.383187 | e_pde=0.102120 | e_bc_zero=0.089208 | e_symm=0.013118 | e_traj=5.972746 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9000: total=9.337978 | e_pde=0.102048 | e_bc_zero=0.101888 | e_symm=0.030726 | e_traj=5.933469 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9100: total=9.291305 | e_pde=0.103282 | e_bc_zero=0.081862 | e_symm=0.052803 | e_traj=5.892987 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9200: total=9.207621 | e_pde=0.098208 | e_bc_zero=0.092215 | e_symm=0.034326 | e_traj=5.851880 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9300: total=9.145924 | e_pde=0.096280 | e_bc_zero=0.084801 | e_symm=0.029383 | e_traj=5.816957 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9400: total=9.131444 | e_pde=0.100184 | e_bc_zero=0.081548 | e_symm=0.084130 | e_traj=5.776810 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9500: total=9.006507 | e_pde=0.095934 | e_bc_zero=0.083743 | e_symm=0.009885 | e_traj=5.736593 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9600: total=8.957523 | e_pde=0.094762 | e_bc_zero=0.080950 | e_symm=0.021787 | e_traj=5.700345 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9700: total=8.933127 | e_pde=0.101350 | e_bc_zero=0.068598 | e_symm=0.045445 | e_traj=5.667417 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9800: total=8.886475 | e_pde=0.101186 | e_bc_zero=0.093148 | e_symm=0.064203 | e_traj=5.625536 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 9900: total=8.798585 | e_pde=0.097676 | e_bc_zero=0.085202 | e_symm=0.024795 | e_traj=5.592351 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10000: total=8.726557 | e_pde=0.093339 | e_bc_zero=0.088696 | e_symm=0.012481 | e_traj=5.555699 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10100: total=8.753397 | e_pde=0.106496 | e_bc_zero=0.060376 | e_symm=0.088838 | e_traj=5.524902 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10200: total=8.618790 | e_pde=0.090770 | e_bc_zero=0.077672 | e_symm=0.012626 | e_traj=5.489351 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10300: total=8.566801 | e_pde=0.091091 | e_bc_zero=0.082639 | e_symm=0.010418 | e_traj=5.455885 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10400: total=8.517676 | e_pde=0.089147 | e_bc_zero=0.080442 | e_symm=0.014230 | e_traj=5.424272 | w={e_bc_zero:0.154, e_pde:1.54, e_symm:0.765, e_term:0.1, e_traj:1.54}
# Epoch 10500: total=8.471858 | e_pde=0.094522 | e_bc_zero=0.073612 | e_symm=0.012571 | e_traj=5.390664 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 10600: total=8.459219 | e_pde=0.086318 | e_bc_zero=0.062379 | e_symm=0.027916 | e_traj=5.365760 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 10700: total=8.414588 | e_pde=0.091536 | e_bc_zero=0.069477 | e_symm=0.029271 | e_traj=5.330302 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 10800: total=8.354345 | e_pde=0.086734 | e_bc_zero=0.071480 | e_symm=0.020287 | e_traj=5.300313 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 10900: total=8.332146 | e_pde=0.087196 | e_bc_zero=0.073761 | e_symm=0.048115 | e_traj=5.271699 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11000: total=8.257831 | e_pde=0.084102 | e_bc_zero=0.065513 | e_symm=0.014368 | e_traj=5.243996 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11100: total=8.205095 | e_pde=0.080576 | e_bc_zero=0.070526 | e_symm=0.012493 | e_traj=5.213822 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11200: total=8.158958 | e_pde=0.079887 | e_bc_zero=0.055108 | e_symm=0.011946 | e_traj=5.186476 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11300: total=8.122489 | e_pde=0.076962 | e_bc_zero=0.056030 | e_symm=0.023367 | e_traj=5.160151 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11400: total=8.110907 | e_pde=0.089613 | e_bc_zero=0.073555 | e_symm=0.044104 | e_traj=5.128147 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11500: total=8.020834 | e_pde=0.073354 | e_bc_zero=0.052962 | e_symm=0.012770 | e_traj=5.103475 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11600: total=7.988199 | e_pde=0.076398 | e_bc_zero=0.053675 | e_symm=0.021567 | e_traj=5.074961 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11700: total=7.932553 | e_pde=0.069354 | e_bc_zero=0.047804 | e_symm=0.012495 | e_traj=5.051019 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11800: total=7.946490 | e_pde=0.071201 | e_bc_zero=0.053176 | e_symm=0.078853 | e_traj=5.025305 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 11900: total=7.999523 | e_pde=0.086588 | e_bc_zero=0.031469 | e_symm=0.163024 | e_traj=5.005366 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12000: total=7.826248 | e_pde=0.076401 | e_bc_zero=0.048546 | e_symm=0.015426 | e_traj=4.973705 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12100: total=7.788149 | e_pde=0.070402 | e_bc_zero=0.059090 | e_symm=0.026545 | e_traj=4.948585 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12200: total=7.741882 | e_pde=0.069181 | e_bc_zero=0.052639 | e_symm=0.018312 | e_traj=4.924535 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12300: total=7.800401 | e_pde=0.075655 | e_bc_zero=0.040485 | e_symm=0.120588 | e_traj=4.907278 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12400: total=7.678674 | e_pde=0.070656 | e_bc_zero=0.052149 | e_symm=0.020752 | e_traj=4.881034 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12500: total=7.641094 | e_pde=0.065603 | e_bc_zero=0.050849 | e_symm=0.020789 | e_traj=4.861890 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12600: total=7.666943 | e_pde=0.085294 | e_bc_zero=0.047685 | e_symm=0.064145 | e_traj=4.838102 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12700: total=7.594546 | e_pde=0.072639 | e_bc_zero=0.056166 | e_symm=0.029238 | e_traj=4.820094 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12800: total=7.551045 | e_pde=0.067725 | e_bc_zero=0.041267 | e_symm=0.023013 | e_traj=4.801394 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 12900: total=7.504538 | e_pde=0.063302 | e_bc_zero=0.039349 | e_symm=0.014400 | e_traj=4.780122 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13000: total=7.509788 | e_pde=0.078504 | e_bc_zero=0.038780 | e_symm=0.040113 | e_traj=4.755840 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13100: total=7.436200 | e_pde=0.061026 | e_bc_zero=0.037484 | e_symm=0.014238 | e_traj=4.738459 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13200: total=7.419900 | e_pde=0.060548 | e_bc_zero=0.043328 | e_symm=0.032372 | e_traj=4.718970 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13300: total=7.380732 | e_pde=0.061196 | e_bc_zero=0.041032 | e_symm=0.018648 | e_traj=4.699904 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13400: total=7.382321 | e_pde=0.081642 | e_bc_zero=0.058694 | e_symm=0.020361 | e_traj=4.677886 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13500: total=7.475871 | e_pde=0.104301 | e_bc_zero=0.024876 | e_symm=0.124985 | e_traj=4.668125 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13600: total=7.339797 | e_pde=0.074158 | e_bc_zero=0.030719 | e_symm=0.043758 | e_traj=4.649256 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13700: total=7.269069 | e_pde=0.063468 | e_bc_zero=0.042634 | e_symm=0.017244 | e_traj=4.625926 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13800: total=7.240601 | e_pde=0.058836 | e_bc_zero=0.030759 | e_symm=0.016936 | e_traj=4.613481 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 13900: total=7.255837 | e_pde=0.074396 | e_bc_zero=0.043213 | e_symm=0.040944 | e_traj=4.594830 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14000: total=7.259391 | e_pde=0.069292 | e_bc_zero=0.021427 | e_symm=0.078790 | e_traj=4.585964 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14100: total=7.190269 | e_pde=0.061315 | e_bc_zero=0.032338 | e_symm=0.030152 | e_traj=4.571846 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14200: total=7.189350 | e_pde=0.086596 | e_bc_zero=0.042456 | e_symm=0.018611 | e_traj=4.550583 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14300: total=7.127139 | e_pde=0.060061 | e_bc_zero=0.028758 | e_symm=0.016722 | e_traj=4.539167 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14400: total=7.107103 | e_pde=0.059378 | e_bc_zero=0.026667 | e_symm=0.023059 | e_traj=4.524010 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14500: total=7.085663 | e_pde=0.056485 | e_bc_zero=0.027037 | e_symm=0.025306 | e_traj=4.511902 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14600: total=7.141821 | e_pde=0.075507 | e_bc_zero=0.031914 | e_symm=0.093982 | e_traj=4.495243 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14700: total=7.077204 | e_pde=0.078402 | e_bc_zero=0.039850 | e_symm=0.031172 | e_traj=4.480373 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14800: total=7.201793 | e_pde=0.086052 | e_bc_zero=0.030255 | e_symm=0.204921 | e_traj=4.469582 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 14900: total=7.055256 | e_pde=0.065290 | e_bc_zero=0.024723 | e_symm=0.075820 | e_traj=4.459036 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15000: total=7.011238 | e_pde=0.072450 | e_bc_zero=0.032643 | e_symm=0.030860 | e_traj=4.444526 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15100: total=6.987443 | e_pde=0.074732 | e_bc_zero=0.042331 | e_symm=0.019079 | e_traj=4.431627 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15200: total=6.958964 | e_pde=0.058119 | e_bc_zero=0.028924 | e_symm=0.038019 | e_traj=4.421926 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15300: total=7.040356 | e_pde=0.077902 | e_bc_zero=0.015692 | e_symm=0.124489 | e_traj=4.413968 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15400: total=6.916133 | e_pde=0.062516 | e_bc_zero=0.028666 | e_symm=0.019834 | e_traj=4.398714 | w={e_bc_zero:0.155, e_pde:1.55, e_symm:0.754, e_term:0.1, e_traj:1.55}
# Epoch 15500: total=6.926358 | e_pde=0.075326 | e_bc_zero=0.030233 | e_symm=0.030425 | e_traj=4.387198 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 15600: total=7.010293 | e_pde=0.102075 | e_bc_zero=0.041488 | e_symm=0.042804 | e_traj=4.373579 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 15700: total=6.925841 | e_pde=0.063523 | e_bc_zero=0.024660 | e_symm=0.029825 | e_traj=4.365674 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 15800: total=7.001954 | e_pde=0.089919 | e_bc_zero=0.018401 | e_symm=0.094229 | e_traj=4.358647 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 15900: total=6.942516 | e_pde=0.067386 | e_bc_zero=0.028424 | e_symm=0.085157 | e_traj=4.346268 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16000: total=7.032619 | e_pde=0.108577 | e_bc_zero=0.037581 | e_symm=0.146197 | e_traj=4.333457 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16100: total=6.869817 | e_pde=0.075010 | e_bc_zero=0.026627 | e_symm=0.016900 | e_traj=4.324072 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16200: total=6.863090 | e_pde=0.076524 | e_bc_zero=0.033192 | e_symm=0.023676 | e_traj=4.314415 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16300: total=6.833852 | e_pde=0.059884 | e_bc_zero=0.021738 | e_symm=0.035484 | e_traj=4.307912 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16400: total=6.887034 | e_pde=0.070014 | e_bc_zero=0.015503 | e_symm=0.105064 | e_traj=4.300010 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16500: total=6.786342 | e_pde=0.057882 | e_bc_zero=0.022756 | e_symm=0.018755 | e_traj=4.287138 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16600: total=6.801602 | e_pde=0.076679 | e_bc_zero=0.024310 | e_symm=0.019386 | e_traj=4.277686 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16700: total=6.768157 | e_pde=0.062773 | e_bc_zero=0.024633 | e_symm=0.017934 | e_traj=4.270771 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16800: total=6.744102 | e_pde=0.055158 | e_bc_zero=0.021547 | e_symm=0.018420 | e_traj=4.263026 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 16900: total=6.733856 | e_pde=0.056764 | e_bc_zero=0.019290 | e_symm=0.024090 | e_traj=4.252419 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17000: total=6.725076 | e_pde=0.061804 | e_bc_zero=0.021909 | e_symm=0.019454 | e_traj=4.243648 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17100: total=6.712661 | e_pde=0.057829 | e_bc_zero=0.022371 | e_symm=0.030684 | e_traj=4.234357 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17200: total=6.743451 | e_pde=0.084918 | e_bc_zero=0.009973 | e_symm=0.027218 | e_traj=4.229892 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17300: total=7.268850 | e_pde=0.124323 | e_bc_zero=0.022050 | e_symm=0.679981 | e_traj=4.221328 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17400: total=6.771427 | e_pde=0.079165 | e_bc_zero=0.016797 | e_symm=0.111931 | e_traj=4.213313 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17500: total=6.713579 | e_pde=0.081979 | e_bc_zero=0.014052 | e_symm=0.037374 | e_traj=4.208500 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17600: total=6.684308 | e_pde=0.061770 | e_bc_zero=0.018058 | e_symm=0.062448 | e_traj=4.197797 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17700: total=6.735073 | e_pde=0.071237 | e_bc_zero=0.012472 | e_symm=0.122095 | e_traj=4.193586 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17800: total=6.696218 | e_pde=0.076037 | e_bc_zero=0.015430 | e_symm=0.078180 | e_traj=4.184082 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 17900: total=6.672558 | e_pde=0.075767 | e_bc_zero=0.027961 | e_symm=0.064014 | e_traj=4.174536 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18000: total=6.624710 | e_pde=0.066138 | e_bc_zero=0.024361 | e_symm=0.033762 | e_traj=4.167955 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18100: total=6.601365 | e_pde=0.056930 | e_bc_zero=0.022851 | e_symm=0.033276 | e_traj=4.162557 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18200: total=6.620689 | e_pde=0.072121 | e_bc_zero=0.012851 | e_symm=0.036887 | e_traj=4.159081 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18300: total=6.561896 | e_pde=0.050881 | e_bc_zero=0.015674 | e_symm=0.019973 | e_traj=4.150209 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18400: total=6.564340 | e_pde=0.051223 | e_bc_zero=0.013456 | e_symm=0.036375 | e_traj=4.143988 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18500: total=6.602980 | e_pde=0.073125 | e_bc_zero=0.023515 | e_symm=0.059535 | e_traj=4.135055 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18600: total=6.582870 | e_pde=0.078654 | e_bc_zero=0.023350 | e_symm=0.029734 | e_traj=4.130567 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18700: total=6.615025 | e_pde=0.107141 | e_bc_zero=0.014394 | e_symm=0.018586 | e_traj=4.128828 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18800: total=6.647247 | e_pde=0.089601 | e_bc_zero=0.012248 | e_symm=0.118029 | e_traj=4.120771 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 18900: total=6.542300 | e_pde=0.057642 | e_bc_zero=0.012045 | e_symm=0.058197 | e_traj=4.113360 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19000: total=6.800693 | e_pde=0.096256 | e_bc_zero=0.011832 | e_symm=0.338766 | e_traj=4.109447 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19100: total=6.577949 | e_pde=0.078791 | e_bc_zero=0.019337 | e_symm=0.090178 | e_traj=4.099412 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19200: total=6.473532 | e_pde=0.048916 | e_bc_zero=0.012139 | e_symm=0.022983 | e_traj=4.094399 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19300: total=6.689158 | e_pde=0.156100 | e_bc_zero=0.006022 | e_symm=0.093995 | e_traj=4.093034 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19400: total=6.645396 | e_pde=0.150746 | e_bc_zero=0.007220 | e_symm=0.054274 | e_traj=4.088749 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19500: total=6.557327 | e_pde=0.107796 | e_bc_zero=0.008280 | e_symm=0.041823 | e_traj=4.080884 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19600: total=6.460495 | e_pde=0.056744 | e_bc_zero=0.020795 | e_symm=0.036161 | e_traj=4.071177 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19700: total=6.485804 | e_pde=0.067892 | e_bc_zero=0.010366 | e_symm=0.053095 | e_traj=4.069400 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19800: total=6.480162 | e_pde=0.088732 | e_bc_zero=0.023614 | e_symm=0.021269 | e_traj=4.058493 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 19900: total=6.434307 | e_pde=0.057005 | e_bc_zero=0.013556 | e_symm=0.029160 | e_traj=4.058103 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20000: total=6.430524 | e_pde=0.057690 | e_bc_zero=0.012855 | e_symm=0.036348 | e_traj=4.051700 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20100: total=6.450833 | e_pde=0.059140 | e_bc_zero=0.016272 | e_symm=0.070163 | e_traj=4.047133 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20200: total=6.539679 | e_pde=0.117250 | e_bc_zero=0.019374 | e_symm=0.079180 | e_traj=4.041527 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20300: total=7.045469 | e_pde=0.390075 | e_bc_zero=0.024236 | e_symm=0.179821 | e_traj=4.045821 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20400: total=6.415497 | e_pde=0.066837 | e_bc_zero=0.011803 | e_symm=0.032132 | e_traj=4.034984 | w={e_bc_zero:0.156, e_pde:1.56, e_symm:0.728, e_term:0.1, e_traj:1.56}
# Epoch 20500: total=6.481466 | e_pde=0.102307 | e_bc_zero=0.009517 | e_symm=0.057912 | e_traj=4.030033 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 20600: total=6.620914 | e_pde=0.079552 | e_bc_zero=0.020579 | e_symm=0.207786 | e_traj=4.021996 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 20700: total=6.504396 | e_pde=0.089532 | e_bc_zero=0.006624 | e_symm=0.019256 | e_traj=4.021358 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 20800: total=6.476480 | e_pde=0.066758 | e_bc_zero=0.013803 | e_symm=0.046078 | e_traj=4.014102 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 20900: total=6.457728 | e_pde=0.064611 | e_bc_zero=0.015394 | e_symm=0.034828 | e_traj=4.009090 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21000: total=6.485660 | e_pde=0.070478 | e_bc_zero=0.021682 | e_symm=0.073298 | e_traj=4.003605 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21100: total=6.506971 | e_pde=0.074609 | e_bc_zero=0.014733 | e_symm=0.103619 | e_traj=4.000520 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21200: total=6.458653 | e_pde=0.078034 | e_bc_zero=0.008228 | e_symm=0.030638 | e_traj=3.998786 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21300: total=6.571794 | e_pde=0.080440 | e_bc_zero=0.011529 | e_symm=0.205791 | e_traj=3.991765 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21400: total=6.410124 | e_pde=0.055162 | e_bc_zero=0.016933 | e_symm=0.038307 | e_traj=3.986724 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21500: total=6.544491 | e_pde=0.149491 | e_bc_zero=0.049127 | e_symm=0.029641 | e_traj=3.978041 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21600: total=6.371826 | e_pde=0.047214 | e_bc_zero=0.013273 | e_symm=0.019447 | e_traj=3.978958 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21700: total=6.377696 | e_pde=0.051792 | e_bc_zero=0.018755 | e_symm=0.030573 | e_traj=3.972725 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21800: total=6.388765 | e_pde=0.059182 | e_bc_zero=0.012627 | e_symm=0.042222 | e_traj=3.967907 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 21900: total=6.409981 | e_pde=0.052259 | e_bc_zero=0.013020 | e_symm=0.096582 | e_traj=3.964659 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22000: total=6.341405 | e_pde=0.047533 | e_bc_zero=0.018265 | e_symm=0.019102 | e_traj=3.959020 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22100: total=6.483949 | e_pde=0.106895 | e_bc_zero=0.013279 | e_symm=0.101326 | e_traj=3.954791 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22200: total=6.782144 | e_pde=0.151447 | e_bc_zero=0.009954 | e_symm=0.434073 | e_traj=3.955167 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22300: total=6.353465 | e_pde=0.056605 | e_bc_zero=0.013932 | e_symm=0.042149 | e_traj=3.948027 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22400: total=6.472337 | e_pde=0.098177 | e_bc_zero=0.037846 | e_symm=0.130421 | e_traj=3.941082 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22500: total=6.324636 | e_pde=0.052920 | e_bc_zero=0.016723 | e_symm=0.031210 | e_traj=3.937915 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22600: total=6.299022 | e_pde=0.045242 | e_bc_zero=0.010766 | e_symm=0.019199 | e_traj=3.935173 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22700: total=6.369264 | e_pde=0.082693 | e_bc_zero=0.021332 | e_symm=0.050906 | e_traj=3.927409 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22800: total=6.317402 | e_pde=0.063827 | e_bc_zero=0.022956 | e_symm=0.026443 | e_traj=3.923871 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 22900: total=6.283145 | e_pde=0.047514 | e_bc_zero=0.010347 | e_symm=0.021914 | e_traj=3.921710 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23000: total=6.350029 | e_pde=0.096739 | e_bc_zero=0.030668 | e_symm=0.019471 | e_traj=3.913876 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23100: total=6.317133 | e_pde=0.078180 | e_bc_zero=0.015419 | e_symm=0.023709 | e_traj=3.911286 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23200: total=6.288607 | e_pde=0.049354 | e_bc_zero=0.017441 | e_symm=0.052405 | e_traj=3.909398 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23300: total=6.526182 | e_pde=0.112163 | e_bc_zero=0.010657 | e_symm=0.258176 | e_traj=3.908524 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23400: total=6.280126 | e_pde=0.061321 | e_bc_zero=0.009937 | e_symm=0.027876 | e_traj=3.903446 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23500: total=6.281473 | e_pde=0.063706 | e_bc_zero=0.007858 | e_symm=0.032663 | e_traj=3.900046 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23600: total=6.243799 | e_pde=0.049209 | e_bc_zero=0.015751 | e_symm=0.019948 | e_traj=3.895405 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23700: total=6.485568 | e_pde=0.083880 | e_bc_zero=0.011861 | e_symm=0.300646 | e_traj=3.892546 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23800: total=6.531148 | e_pde=0.078186 | e_bc_zero=0.021516 | e_symm=0.388835 | e_traj=3.887906 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 23900: total=6.237325 | e_pde=0.054634 | e_bc_zero=0.017135 | e_symm=0.026703 | e_traj=3.882812 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24000: total=6.484437 | e_pde=0.081785 | e_bc_zero=0.011833 | e_symm=0.330183 | e_traj=3.881120 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24100: total=6.415285 | e_pde=0.065947 | e_bc_zero=0.016983 | e_symm=0.274836 | e_traj=3.876640 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24200: total=6.248151 | e_pde=0.051949 | e_bc_zero=0.010780 | e_symm=0.071750 | e_traj=3.873457 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24300: total=6.281207 | e_pde=0.057727 | e_bc_zero=0.014329 | e_symm=0.115287 | e_traj=3.869384 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24400: total=6.205403 | e_pde=0.049078 | e_bc_zero=0.012332 | e_symm=0.032277 | e_traj=3.866211 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24500: total=6.560130 | e_pde=0.082681 | e_bc_zero=0.010331 | e_symm=0.477808 | e_traj=3.864307 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24600: total=6.241627 | e_pde=0.064518 | e_bc_zero=0.016746 | e_symm=0.068175 | e_traj=3.857709 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24700: total=6.193156 | e_pde=0.052470 | e_bc_zero=0.010296 | e_symm=0.028759 | e_traj=3.856791 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24800: total=6.185741 | e_pde=0.055241 | e_bc_zero=0.008919 | e_symm=0.021045 | e_traj=3.852806 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 24900: total=6.207501 | e_pde=0.066192 | e_bc_zero=0.017160 | e_symm=0.041486 | e_traj=3.845951 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25000: total=6.629021 | e_pde=0.225783 | e_bc_zero=0.011736 | e_symm=0.288261 | e_traj=3.846889 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25100: total=6.350353 | e_pde=0.111709 | e_bc_zero=0.007760 | e_symm=0.149189 | e_traj=3.845156 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25200: total=6.191026 | e_pde=0.053676 | e_bc_zero=0.009759 | e_symm=0.066281 | e_traj=3.838020 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25300: total=6.181692 | e_pde=0.068307 | e_bc_zero=0.010053 | e_symm=0.023688 | e_traj=3.835916 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25400: total=6.193094 | e_pde=0.081589 | e_bc_zero=0.018447 | e_symm=0.025206 | e_traj=3.828359 | w={e_bc_zero:0.158, e_pde:1.58, e_symm:0.685, e_term:0.1, e_traj:1.58}
# Epoch 25500: total=6.146076 | e_pde=0.052845 | e_bc_zero=0.011814 | e_symm=0.025690 | e_traj=3.827775 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 25600: total=6.240413 | e_pde=0.061451 | e_bc_zero=0.022343 | e_symm=0.025243 | e_traj=3.822695 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 25700: total=6.285892 | e_pde=0.070275 | e_bc_zero=0.009063 | e_symm=0.080688 | e_traj=3.821553 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 25800: total=6.238704 | e_pde=0.068363 | e_bc_zero=0.009762 | e_symm=0.024586 | e_traj=3.816235 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 25900: total=6.264482 | e_pde=0.057647 | e_bc_zero=0.011527 | e_symm=0.100022 | e_traj=3.812881 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26000: total=6.215270 | e_pde=0.058552 | e_bc_zero=0.010902 | e_symm=0.026883 | e_traj=3.810387 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26100: total=6.234726 | e_pde=0.072797 | e_bc_zero=0.029236 | e_symm=0.032739 | e_traj=3.804128 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26200: total=6.189112 | e_pde=0.047012 | e_bc_zero=0.012970 | e_symm=0.033618 | e_traj=3.802710 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26300: total=6.477280 | e_pde=0.163870 | e_bc_zero=0.011676 | e_symm=0.188552 | e_traj=3.804317 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26400: total=6.225036 | e_pde=0.055572 | e_bc_zero=0.011808 | e_symm=0.084576 | e_traj=3.796438 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26500: total=6.180052 | e_pde=0.054812 | e_bc_zero=0.015923 | e_symm=0.024016 | e_traj=3.792775 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26600: total=6.170833 | e_pde=0.050168 | e_bc_zero=0.010303 | e_symm=0.026799 | e_traj=3.791119 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26700: total=6.187883 | e_pde=0.061123 | e_bc_zero=0.008403 | e_symm=0.033652 | e_traj=3.788275 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26800: total=6.313609 | e_pde=0.087927 | e_bc_zero=0.009284 | e_symm=0.170788 | e_traj=3.785367 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 26900: total=6.360465 | e_pde=0.145244 | e_bc_zero=0.031059 | e_symm=0.117128 | e_traj=3.776461 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 27000: total=6.202370 | e_pde=0.076379 | e_bc_zero=0.023970 | e_symm=0.047978 | e_traj=3.774812 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 27100: total=6.144158 | e_pde=0.043726 | e_bc_zero=0.014656 | e_symm=0.041671 | e_traj=3.774557 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 27200: total=6.265027 | e_pde=0.119534 | e_bc_zero=0.023937 | e_symm=0.054163 | e_traj=3.768323 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# Epoch 27300: total=6.545707 | e_pde=0.250479 | e_bc_zero=0.009290 | e_symm=0.159981 | e_traj=3.772029 | w={e_bc_zero:0.16, e_pde:1.6, e_symm:0.637, e_term:0.1, e_traj:1.6}
# ...
# Epoch 1900: total=15.261740 | e_pde=2.706924 | e_bc_zero=0.000006 | e_term=1.047009 | e_symm=3.315219 | e_traj=3.776410 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2000: total=15.516694 | e_pde=2.579666 | e_bc_zero=0.000008 | e_term=0.822871 | e_symm=3.904713 | e_traj=3.767945 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2100: total=14.394377 | e_pde=2.620263 | e_bc_zero=0.006258 | e_term=1.532123 | e_symm=2.479785 | e_traj=3.764804 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2200: total=12.943668 | e_pde=2.402250 | e_bc_zero=0.001507 | e_term=0.736621 | e_symm=1.532689 | e_traj=3.755386 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2300: total=13.080440 | e_pde=2.378077 | e_bc_zero=0.001613 | e_term=0.664233 | e_symm=1.760310 | e_traj=3.746380 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2400: total=15.368121 | e_pde=2.528072 | e_bc_zero=0.012340 | e_term=2.050519 | e_symm=3.652972 | e_traj=3.741129 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.93, e_term:0.186, e_traj:1.85}
# Epoch 2500: total=13.269621 | e_pde=2.421328 | e_bc_zero=0.000018 | e_term=0.754251 | e_symm=1.874121 | e_traj=3.739217 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 2600: total=15.612978 | e_pde=2.667897 | e_bc_zero=0.005562 | e_term=1.381216 | e_symm=3.801862 | e_traj=3.733077 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 2700: total=16.301476 | e_pde=2.838449 | e_bc_zero=0.027114 | e_term=3.476798 | e_symm=3.788228 | e_traj=3.726432 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 2800: total=14.028820 | e_pde=2.318272 | e_bc_zero=0.000044 | e_term=1.060819 | e_symm=2.873503 | e_traj=3.730911 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 2900: total=12.709106 | e_pde=2.218320 | e_bc_zero=0.000230 | e_term=0.621047 | e_symm=1.764974 | e_traj=3.723907 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3000: total=14.937473 | e_pde=2.248259 | e_bc_zero=0.021293 | e_term=3.016074 | e_symm=3.627813 | e_traj=3.709712 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3100: total=12.616078 | e_pde=2.062319 | e_bc_zero=0.012017 | e_term=2.004194 | e_symm=1.716027 | e_traj=3.713511 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3200: total=12.028840 | e_pde=2.114921 | e_bc_zero=0.003170 | e_term=0.924397 | e_symm=1.181553 | e_traj=3.724486 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3300: total=14.564774 | e_pde=2.146557 | e_bc_zero=0.022792 | e_term=3.169060 | e_symm=3.410137 | e_traj=3.704879 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3400: total=17.272818 | e_pde=2.153881 | e_bc_zero=0.000061 | e_term=1.293647 | e_symm=6.664879 | e_traj=3.704776 | w={e_bc_zero:0.187, e_pde:1.86, e_symm:0.937, e_term:0.187, e_traj:1.83}
# Epoch 3500: total=12.526059 | e_pde=1.994878 | e_bc_zero=0.000247 | e_term=0.619831 | e_symm=2.053648 | e_traj=3.702835 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 3600: total=13.840406 | e_pde=2.010491 | e_bc_zero=0.000666 | e_term=0.638248 | e_symm=3.459627 | e_traj=3.699469 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 3700: total=12.446334 | e_pde=2.049401 | e_bc_zero=0.005737 | e_term=1.311899 | e_symm=1.796442 | e_traj=3.688271 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 3800: total=12.044750 | e_pde=1.921831 | e_bc_zero=0.000303 | e_term=0.583503 | e_symm=1.762264 | e_traj=3.692530 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 3900: total=11.468035 | e_pde=1.897991 | e_bc_zero=0.001403 | e_term=0.777719 | e_symm=1.161801 | e_traj=3.692151 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4000: total=12.629066 | e_pde=2.018893 | e_bc_zero=0.008257 | e_term=1.654364 | e_symm=1.979352 | e_traj=3.688796 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4100: total=12.190260 | e_pde=1.888179 | e_bc_zero=0.008216 | e_term=1.710370 | e_symm=1.784769 | e_traj=3.676895 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4200: total=11.521464 | e_pde=1.818109 | e_bc_zero=0.002564 | e_term=0.956425 | e_symm=1.370165 | e_traj=3.676058 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4300: total=11.598951 | e_pde=1.872343 | e_bc_zero=0.001532 | e_term=0.770548 | e_symm=1.381737 | e_traj=3.676555 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4400: total=16.139420 | e_pde=2.398525 | e_bc_zero=0.000032 | e_term=3.280558 | e_symm=4.657606 | e_traj=3.666510 | w={e_bc_zero:0.19, e_pde:1.86, e_symm:0.947, e_term:0.19, e_traj:1.81}
# Epoch 4500: total=13.505527 | e_pde=1.803858 | e_bc_zero=0.000158 | e_term=0.802011 | e_symm=3.538963 | e_traj=3.668602 | w={e_bc_zero:0.193, e_pde:1.88, e_symm:0.954, e_term:0.193, e_traj:1.78}
# Epoch 4600: total=13.637360 | e_pde=1.761172 | e_bc_zero=0.007642 | e_term=1.619859 | e_symm=3.665902 | e_traj=3.656869 | w={e_bc_zero:0.193, e_pde:1.88, e_symm:0.954, e_term:0.193, e_traj:1.78}
# Epoch 4700: total=11.580031 | e_pde=1.952281 | e_bc_zero=0.000243 | e_term=0.574623 | e_symm=1.345775 | e_traj=3.656233 | w={e_bc_zero:0.193, e_pde:1.88, e_symm:0.954, e_term:0.193, e_traj:1.78}
# Epoch 4800: total=15.144372 | e_pde=2.762130 | e_bc_zero=0.000370 | e_term=0.632571 | e_symm=3.447050 | e_traj=3.672035 | w={e_bc_zero:0.193, e_pde:1.88, e_symm:0.954, e_term:0.193, e_traj:1.78}
# Epoch 4900: total=11.022783 | e_pde=1.691483 | e_bc_zero=0.002651 | e_term=0.932370 | e_symm=1.215221 | e_traj=3.649379 | w={e_bc_zero:0.193, e_pde:1.88, e_symm:0.954, e_term:0.193, e_traj:1.78}
#
# === 3D stage: alpha=1.0, lambda=0.1 ===
# Epoch 0: total=20.704605 | e_pde=16.196198 | e_bc_zero=0.000230 | e_term=0.616846 | e_symm=1.558841 | e_traj=3.667280 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 100: total=9.214477 | e_pde=4.566541 | e_bc_zero=0.004678 | e_term=1.547091 | e_symm=1.657927 | e_traj=3.663796 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 200: total=8.997461 | e_pde=4.381225 | e_bc_zero=0.006044 | e_term=1.600175 | e_symm=1.597493 | e_traj=3.656868 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 300: total=8.916149 | e_pde=4.345814 | e_bc_zero=0.002089 | e_term=1.131893 | e_symm=1.599788 | e_traj=3.657043 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 400: total=8.900867 | e_pde=4.218400 | e_bc_zero=0.010527 | e_term=2.081836 | e_symm=1.638645 | e_traj=3.653907 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:1}
# Epoch 500: total=8.979456 | e_pde=4.209580 | e_bc_zero=0.006143 | e_term=1.713222 | e_symm=1.896458 | e_traj=3.649710 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 600: total=16.889006 | e_pde=4.225487 | e_bc_zero=0.000410 | e_term=1.091640 | e_symm=2.264208 | e_traj=3.653268 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 700: total=18.241743 | e_pde=4.073472 | e_bc_zero=0.001384 | e_term=0.974239 | e_symm=4.043890 | e_traj=3.657561 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 800: total=15.709316 | e_pde=3.871495 | e_bc_zero=0.005180 | e_term=1.560947 | e_symm=1.620349 | e_traj=3.644749 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 900: total=16.082565 | e_pde=3.895380 | e_bc_zero=0.004747 | e_term=1.507855 | e_symm=1.968307 | e_traj=3.653791 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1000: total=16.655674 | e_pde=4.082354 | e_bc_zero=0.013298 | e_term=2.251837 | e_symm=2.070871 | e_traj=3.649761 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1100: total=15.945889 | e_pde=3.866029 | e_bc_zero=0.000508 | e_term=0.997918 | e_symm=2.009800 | e_traj=3.640008 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1200: total=16.382015 | e_pde=3.638735 | e_bc_zero=0.016694 | e_term=2.561976 | e_symm=2.647963 | e_traj=3.625705 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1300: total=17.074223 | e_pde=3.681443 | e_bc_zero=0.035230 | e_term=4.780169 | e_symm=2.848186 | e_traj=3.633005 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1400: total=15.322826 | e_pde=3.487491 | e_bc_zero=0.015267 | e_term=2.309766 | e_symm=1.886948 | e_traj=3.610858 | w={e_bc_zero:0.185, e_pde:1.85, e_symm:0.926, e_term:0.185, e_traj:1.85}
# Epoch 1500: total=15.187402 | e_pde=3.538158 | e_bc_zero=0.001289 | e_term=1.045368 | e_symm=1.883271 | e_traj=3.616738 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 1600: total=18.317284 | e_pde=3.742326 | e_bc_zero=0.000056 | e_term=1.568242 | e_symm=4.754439 | e_traj=3.617099 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 1700: total=15.760431 | e_pde=3.298783 | e_bc_zero=0.011677 | e_term=2.098839 | e_symm=2.783597 | e_traj=3.610339 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 1800: total=18.654530 | e_pde=3.741428 | e_bc_zero=0.033603 | e_term=4.163342 | e_symm=4.642269 | e_traj=3.592486 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 1900: total=15.306276 | e_pde=3.420249 | e_bc_zero=0.005743 | e_term=1.496412 | e_symm=2.175204 | e_traj=3.608342 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2000: total=14.431793 | e_pde=3.223132 | e_bc_zero=0.009458 | e_term=2.012699 | e_symm=1.547023 | e_traj=3.595025 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2100: total=14.045990 | e_pde=3.094285 | e_bc_zero=0.006677 | e_term=1.672636 | e_symm=1.476168 | e_traj=3.585442 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2200: total=15.369678 | e_pde=3.184378 | e_bc_zero=0.015865 | e_term=2.763898 | e_symm=2.504352 | e_traj=3.586184 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2300: total=14.127800 | e_pde=2.980405 | e_bc_zero=0.010800 | e_term=2.300281 | e_symm=1.689829 | e_traj=3.573551 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2400: total=14.721217 | e_pde=3.116480 | e_bc_zero=0.005513 | e_term=1.478484 | e_symm=2.231062 | e_traj=3.570407 | w={e_bc_zero:0.186, e_pde:1.85, e_symm:0.925, e_term:0.186, e_traj:1.85}
# Epoch 2500: total=18.688095 | e_pde=3.422795 | e_bc_zero=0.030542 | e_term=4.097679 | e_symm=5.383125 | e_traj=3.566471 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 2600: total=13.611597 | e_pde=2.885923 | e_bc_zero=0.007973 | e_term=1.742088 | e_symm=1.430321 | e_traj=3.560988 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 2700: total=13.879086 | e_pde=3.088472 | e_bc_zero=0.003175 | e_term=1.244225 | e_symm=1.404758 | e_traj=3.565269 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 2800: total=13.997960 | e_pde=2.855344 | e_bc_zero=0.009527 | e_term=1.921911 | e_symm=1.902399 | e_traj=3.548056 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 2900: total=14.448135 | e_pde=2.885803 | e_bc_zero=0.010215 | e_term=2.117871 | e_symm=2.266011 | e_traj=3.560488 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3000: total=16.046083 | e_pde=2.731493 | e_bc_zero=0.013257 | e_term=2.032313 | e_symm=4.366117 | e_traj=3.545417 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3100: total=15.762587 | e_pde=3.405345 | e_bc_zero=0.000552 | e_term=1.048738 | e_symm=2.883752 | e_traj=3.550849 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3200: total=20.605425 | e_pde=2.745000 | e_bc_zero=0.046036 | e_term=5.227301 | e_symm=8.667732 | e_traj=3.536604 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3300: total=15.489603 | e_pde=2.657164 | e_bc_zero=0.015787 | e_term=2.403384 | e_symm=3.858436 | e_traj=3.533709 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3400: total=17.411682 | e_pde=2.936239 | e_bc_zero=0.000000 | e_term=1.829614 | e_symm=5.497756 | e_traj=3.537886 | w={e_bc_zero:0.181, e_pde:1.86, e_symm:0.918, e_term:0.186, e_traj:1.86}
# Epoch 3500: total=15.308734 | e_pde=2.601548 | e_bc_zero=0.025785 | e_term=3.489937 | e_symm=3.549294 | e_traj=3.534890 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 3600: total=16.136719 | e_pde=2.873680 | e_bc_zero=0.025410 | e_term=3.548494 | e_symm=3.867649 | e_traj=3.531575 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 3700: total=14.786488 | e_pde=2.622377 | e_bc_zero=0.005806 | e_term=1.635982 | e_symm=3.317864 | e_traj=3.521356 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 3800: total=13.934241 | e_pde=2.659148 | e_bc_zero=0.013553 | e_term=2.253052 | e_symm=2.180046 | e_traj=3.521944 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 3900: total=12.538200 | e_pde=2.444841 | e_bc_zero=0.003378 | e_term=1.236127 | e_symm=1.294667 | e_traj=3.523882 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4000: total=16.225460 | e_pde=3.009421 | e_bc_zero=0.021694 | e_term=3.207045 | e_symm=3.812169 | e_traj=3.504943 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4100: total=17.216465 | e_pde=3.754807 | e_bc_zero=0.004225 | e_term=1.441132 | e_symm=3.703398 | e_traj=3.521979 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4200: total=13.967930 | e_pde=2.378856 | e_bc_zero=0.001761 | e_term=1.243242 | e_symm=3.026614 | e_traj=3.508352 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4300: total=15.338408 | e_pde=3.325546 | e_bc_zero=0.005513 | e_term=1.554315 | e_symm=2.538840 | e_traj=3.503005 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4400: total=12.766502 | e_pde=2.359601 | e_bc_zero=0.007695 | e_term=1.706141 | e_symm=1.652634 | e_traj=3.508953 | w={e_bc_zero:0.172, e_pde:1.87, e_symm:0.913, e_term:0.187, e_traj:1.86}
# Epoch 4500: total=13.935511 | e_pde=2.582887 | e_bc_zero=0.000018 | e_term=1.485287 | e_symm=2.522419 | e_traj=3.509466 | w={e_bc_zero:0.165, e_pde:1.87, e_symm:0.902, e_term:0.187, e_traj:1.87}
# Epoch 4600: total=14.099890 | e_pde=2.472914 | e_bc_zero=0.000059 | e_term=1.342608 | e_symm=2.947014 | e_traj=3.503313 | w={e_bc_zero:0.165, e_pde:1.87, e_symm:0.902, e_term:0.187, e_traj:1.87}
# Epoch 4700: total=12.170835 | e_pde=2.234960 | e_bc_zero=0.003456 | e_term=1.248135 | e_symm=1.338345 | e_traj=3.495435 | w={e_bc_zero:0.165, e_pde:1.87, e_symm:0.902, e_term:0.187, e_traj:1.87}
# Epoch 4800: total=13.133387 | e_pde=2.462013 | e_bc_zero=0.003040 | e_term=1.238357 | e_symm=1.921259 | e_traj=3.502346 | w={e_bc_zero:0.165, e_pde:1.87, e_symm:0.902, e_term:0.187, e_traj:1.87}
# Epoch 4900: total=13.010230 | e_pde=2.318508 | e_bc_zero=0.000925 | e_term=1.094680 | e_symm=2.125896 | e_traj=3.496228 | w={e_bc_zero:0.165, e_pde:1.87, e_symm:0.902, e_term:0.187, e_traj:1.87}
# Training completed in 202.08 s total.
# Done. Checkpoints in: /content/runs/pinn_oe

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/pinn_oe/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_history.pkl (deflated 58%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/c6839ac90a5813c23c1da075634a6298 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/560210cd2dfb024ee0882c9b5bdeb160 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/fea5794006bc28084bbf16b7d38efcbd (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/fe6386440d23da2b5b5717014132ab8c (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/dbefd575717a753a46bb6f31f0651817 (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/d/23b1bf155dcc9a798a32cfb5754289b0 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/5c4a4dda17eb5fe7fa7f27313e3d11dc (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/0545b2269027bf8af6df8c1620275849 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/83976ad861cab0207e8853301f17cf1c (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/d/fcb40b9f0f3f9f3e0dc4c89c8e63d1e5 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/alpha_0p9_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p75_config.json (deflated 56%)
#   adding: content/runs/pinn_oe/2d_lam0_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/666862920a317584b03086129cc7dea8 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/e5314e3f0abcfc63d0030d64b7ba702a (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/d1fd7843d519eec9cfecff80390b1d77 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/d6c6e0b4d76c4729f4661c75a0eba05a (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/c41083a2195abf5027d2af708571ca78 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/76dea853a95a6967acbc5d3beadc1665 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/7543603673dec664143957f5b4051bd0 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/f91bb09b6f34c5ff2d4fee831b92aad5 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/5df145daee7d774e5984ca5e46086873 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/7484f6efa143e7498e841ed07b4cb83b (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p5_config.json (deflated 56%)
#   adding: content/runs/pinn_oe/alpha_0p25_history.pkl (deflated 59%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/dc743240f2b838d12ee9bbfac8e582aa (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/f01485fae75336ae33313d18c573bfde (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/c64a1474e5e9c51d2e25c51ae9c44812 (deflated 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/cee1bd5865cfc5594c793be28ccca551 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/7bd3df56376767d4d42d99dceb4cf03b (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p9_config.json (deflated 56%)
#   adding: content/runs/pinn_oe/alpha_1p0_history.pkl (deflated 56%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/e291b211cc79e7ef7ef3c761fa2d3c98 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/0f6e9ae511e42213ade8ea9228664aea (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/aacf3b11215b507900807353f7512568 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/40a444d1aea3cb72f23971c326f2efe0 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/a00f7a10170e2f1b7e969065d7d015a8 (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/manifest.ocdbt (deflated 7%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_1p0_config.json (deflated 56%)
#   adding: content/runs/pinn_oe/2d_lam0_config.json (deflated 53%)
#   adding: content/runs/pinn_oe/alpha_0p25_config.json (deflated 55%)
#   adding: content/runs/pinn_oe/alpha_0p75_history.pkl (deflated 57%)
#   adding: content/runs/pinn_oe/alpha_0p9_history.pkl (deflated 56%)

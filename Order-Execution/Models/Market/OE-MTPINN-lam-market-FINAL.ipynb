# %% [markdown]
# **RAN ON GOOGLE COLAB**

# %%
# !pip install ml-collections
# Out:
# Collecting ml-collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml-collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: ml-collections
# Successfully installed ml-collections-1.1.0

# %%
# ====== Imports ======
import os, json, time, pickle, shutil
import numpy as np
import jax
import jax.numpy as jnp
from jax import jit, grad, value_and_grad, vmap
import flax
import flax.linen as nn
from flax.training import train_state
from flax.linen.initializers import glorot_normal, zeros, normal
import optax
import ml_collections
import orbax.checkpoint as ocp

jran = jax.random


# ====== NN definition ======
activation_fn = { "tanh": jnp.tanh, "sin": jnp.sin }

def _get_activation(s):
    if s in activation_fn:
        return activation_fn[s]
    raise NotImplementedError(f"Activation {s} not supported yet!")

def _weight_fact(init_fn, mean, stddev):
    def init(key, shape):
        key1, key2 = jran.split(key)
        w = init_fn(key1, shape)
        g = mean + normal(stddev)(key2, (shape[-1],))
        g = jnp.exp(g)
        v = w / g
        return g, v
    return init

class Dense(nn.Module):
    features: int
    kernel_init: callable = glorot_normal()
    bias_init: callable = zeros
    reparam: dict | None = None

    @nn.compact
    def __call__(self, x):
        if self.reparam is None:
            kernel = self.param("kernel", self.kernel_init, (x.shape[-1], self.features))
        elif self.reparam["type"] == "weight_fact":
            g, v = self.param(
                "kernel",
                _weight_fact(self.kernel_init, mean=self.reparam["mean"], stddev=self.reparam["stddev"]),
                (x.shape[-1], self.features),
            )
            kernel = g * v
        bias = self.param("bias", self.bias_init, (self.features,))
        return jnp.dot(x, kernel) + bias

class MLP(nn.Module):
    arch_name: str = "MLP"
    hidden_dim: tuple[int, ...] = (32, 16)
    out_dim: int = 1
    activation: str = "tanh"
    periodicity: dict | None = None
    fourier_emb: dict | None = None
    reparam: dict | None = None

    def setup(self):
        self.activation_fn = _get_activation(self.activation)

    @nn.compact
    def __call__(self, x):
        for h in self.hidden_dim:
            x = Dense(features=h, reparam=self.reparam)(x)
            x = self.activation_fn(x)
        x = Dense(features=self.out_dim, reparam=self.reparam)(x)
        return x

def ann_gen(config):
    reparam = None
    if getattr(config, "ann_reparam", False) == "weight_fact":
        reparam = ml_collections.ConfigDict({"type": "weight_fact", "mean": 0.5, "stddev": 0.1})
    if config.ann_str == "MLP":
        return MLP(
            arch_name=config.ann_str,
            hidden_dim=tuple(config.ann_hidden_dim),
            out_dim=config.ann_out_dim,
            activation=config.ann_activation_str,
            periodicity=config.ann_periodicity,
            fourier_emb=config.ann_fourier_emb,
            reparam=reparam,
        )
    raise NotImplementedError(f"Unknown arch {config.ann_str}")


# ====== Derivatives ======
def derivatives_2d(fn2d, x):
    def f(z): return fn2d(z)[0]
    dx = vmap(grad(f), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_x   = dx.T[1]
    return Gamma_tau, Gamma_x

def derivatives_3d(fn3d, x):
    def f(z): return fn3d(z)[0]
    def f_dx(z): return grad(f)(z)[2]
    dx  = vmap(grad(f), 0)(x)
    d2x = vmap(grad(f_dx), 0)(x)
    Gamma_tau = dx.T[0]
    Gamma_X   = dx.T[1]
    Gamma_S   = dx.T[2]
    Gamma_SS  = d2x.T[2]
    return Gamma_tau, Gamma_X, Gamma_S, Gamma_SS


# ====== Data samplers ======
def get_data_2d(n_pde=10000, n_bc=500, T=5.0, x_range=(-10.,10.), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde])
    # x=0 boundary along tau
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc])
    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), T

def get_data_3d(n_pde=10000, n_bc=1000, n_term=100, T=5.0, x_range=(-10.,10.), s_range=(10,100), seed=0):
    rng = np.random.default_rng(seed)
    X_pde = rng.uniform(x_range[0], x_range[1], size=(n_pde, 1))
    S_pde = rng.uniform(s_range[0], s_range[1], size=(n_pde, 1))
    tau   = rng.uniform(0, T, size=(n_pde, 1))
    x_tau_pde = np.hstack([tau, X_pde, S_pde])
    # IC: V(tau,0,S) <= 0
    tau_bc = rng.uniform(0, T, size=(n_bc, 1))
    x_bc   = np.zeros((n_bc, 1))
    S_bc   = rng.uniform(s_range[0], s_range[1], size=(n_bc, 1))
    x_bc_zero = np.hstack([tau_bc, x_bc, S_bc])
    # Terminal at tau=0, x=0: V=0
    tau_term = np.zeros((n_term, 1))
    S_term   = rng.uniform(s_range[0], s_range[1], size=(n_term, 1))
    x_term   = np.zeros((n_term, 1))
    x_term_zero = np.hstack([tau_term, x_term, S_term])
    return jnp.array(x_tau_pde), jnp.array(x_bc_zero), jnp.array(x_term_zero), T


# ====== Error terms ======
def error_2d(config, fn2d, data):
    x_tau_pde, x_bc_zero, T = data
    Gamma_tau, Gamma_X = derivatives_2d(fn2d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    kappa = config.kappa
    # PDE residual
    e_pde = ( Gamma_tau - (kappa**2 * X_vals**2) + 0.25 * Gamma_X**2 )**2
    # IC at x=0
    e_bc_zero = fn2d(x_bc_zero).squeeze()**2

    # Symmetry 
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1])
    e_symm = (fn2d(z).squeeze() - fn2d(z_flip).squeeze())**2
    # Multi-trajectory penalty 
    def single_path_penalty_2d(fn2d, *, X0, T=1.0, Ndt=200):
        X0 = jnp.atleast_1d(X0); dt = T / Ndt
        def f(z): return fn2d(z)[0]
        def step(carry, _):
            x_curr, t_curr = carry
            tau = T - t_curr
            z = jnp.stack([tau, x_curr], axis=1)
            dX = vmap(grad(f))(z)[:,1]
            v = 0.5 * dX
            return (x_curr - dt*v, t_curr + dt), None
        (x_T, _), _ = jax.lax.scan(step, (X0, jnp.zeros_like(X0)), None, length=Ndt)

        abs_x = jnp.abs(x_T)
        loss_per_path = jnp.where(abs_x <= 1.0, abs_x, x_T**2)
        return jnp.mean(loss_per_path)

    def multi_T_traj_penalty_2d(fn2d, *, X0, T_list, Ndt=200):
        T_list = jnp.atleast_1d(jnp.array(T_list))
        penalties = jax.vmap(lambda Ti: single_path_penalty_2d(fn2d, X0=X0, T=Ti, Ndt=Ndt))(T_list)
        return jnp.mean(penalties)

    Ndt     = config.traj_Ndt
    n_X     = config.n_X
    T_list  = config.T_list
    X0_vals = jnp.linspace(config.x_range[0], config.x_range[1], n_X)
    e_traj  = multi_T_traj_penalty_2d(fn2d, X0=X0_vals, T_list=T_list, Ndt=Ndt)

    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_symm": jnp.mean(e_symm),
        "e_traj": jnp.mean(e_traj),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_symm": e_symm, "e_traj": e_traj}, metrics

def error_3d(config, fn3d, data):
    x_tau_pde, x_bc_zero, x_term_zero, T = data
    Gamma_tau, Gamma_X, _, Gamma_SS = derivatives_3d(fn3d, x_tau_pde)
    tau_vals = x_tau_pde[:,0]
    X_vals   = x_tau_pde[:,1]
    S_vals   = x_tau_pde[:,2]

    kappa = config.kappa
    sigma = config.sigma
    lam   = config.lam

    # PDE residual
    e_pde = (
        Gamma_tau
        - 0.5 * sigma**2 * S_vals**2 * Gamma_SS
        - (kappa**2 * X_vals**2 + lam * S_vals * X_vals)
        + 0.25 * Gamma_X**2
    )**2
    # IC
    e_bc_zero = jnp.maximum(fn3d(x_bc_zero).squeeze() - 1e-6, 0.0)**2
    # Terminal
    e_term = fn3d(x_term_zero).squeeze()**2
    # Symmetry
    z = x_tau_pde
    z_flip = z.at[:, 1].set(-z[:, 1]).at[:, 2].set(-z[:, 2])
    e_symm = (fn3d(z).squeeze() - fn3d(z_flip).squeeze())**2
    # Multi-trajectory 
    def single_path_penalty_3d(fn3d, *, X0, S0, T=1.0, Ndt=200):
        X0 = jnp.atleast_1d(X0); S0 = jnp.atleast_1d(S0)
        dt = T / Ndt
        def f(z): return fn3d(z)[0]
        def step(carry, _):
            x_curr, t_curr = carry
            tau = T - t_curr
            z = jnp.stack([tau, x_curr, S0], axis=1)
            dX = vmap(grad(f))(z)[:,1]
            v = 0.5 * dX
            return (x_curr - dt*v, t_curr + dt), None
        (x_T, _), _ = jax.lax.scan(step, (X0, jnp.zeros_like(X0)), None, length=Ndt)

        abs_x = jnp.abs(x_T)
        loss_per_path = jnp.where(abs_x <= 1.0, abs_x, x_T**2)
        return jnp.mean(loss_per_path)

    def multi_T_traj_penalty_3d(fn3d, *, X0, S0, T_list, Ndt=200):
        T_list = jnp.atleast_1d(jnp.array(T_list))
        penalties = jax.vmap(lambda Ti: single_path_penalty_3d(fn3d, X0=X0, S0=S0, T=Ti, Ndt=Ndt))(T_list)
        return jnp.mean(penalties)

    T_list  = config.T_list
    Ndt     = config.traj_Ndt
    n_X     = config.n_X
    X0_vals = jnp.linspace(config.x_range[0], config.x_range[1], n_X)
    n_S     = config.n_S
    S0_vals = jnp.linspace(config.s_range[0], config.s_range[1], n_S)
    S0_grid, X0_grid = jnp.meshgrid(S0_vals, X0_vals)
    e_traj  = multi_T_traj_penalty_3d(fn3d, X0=X0_grid.flatten(), S0=S0_grid.flatten(), T_list=T_list, Ndt=Ndt)

    metrics = {
        "e_pde": jnp.mean(e_pde),
        "e_bc_zero": jnp.mean(e_bc_zero),
        "e_term": jnp.mean(e_term),
        "e_symm": jnp.mean(e_symm),
        "e_traj": jnp.mean(e_traj),
    }
    return {"e_pde": e_pde, "e_bc_zero": e_bc_zero, "e_term": e_term, "e_symm": e_symm, "e_traj": e_traj}, metrics

def error(config, fn, data):
    return error_2d(config, fn, data) if len(data) == 3 else error_3d(config, fn, data)


# ====== 2D -> 3D parameter inflation ======
def inflate_2d_to_3d_params(params_2d, params_3d_init, first_dense="Dense_0"):
    """
    Take trained 2D params (inputs [tau, x]) and freshly inited 3D params ([tau, x, S]).
    Return params_3d with an added zero row for S in the first Dense kernel.
    """
    p2 = flax.core.unfreeze(params_2d)
    p3 = flax.core.unfreeze(params_3d_init)
    for mod, wdict in p2["params"].items():
        for name, arr in wdict.items():
            if (mod, name) == (first_dense, "kernel"):
                continue
            if arr.shape == p3["params"][mod][name].shape:
                p3["params"][mod][name] = arr
    k2 = p2["params"][first_dense]["kernel"]   
    H  = k2.shape[1]
    k3 = jnp.concatenate([k2, jnp.zeros((1, H))], axis=0)
    p3["params"][first_dense]["kernel"] = k3
    p3["params"][first_dense]["bias"]   = p2["params"][first_dense]["bias"]
    return flax.core.freeze(p3)


# ====== Loss assembly ======
def adj(loss, lw, m):  
    return lw * jnp.mean(m * loss)

ALL_COMPONENTS = ['e_pde', 'e_bc_zero', 'e_term', 'e_symm', 'e_traj']

def make_loss_lb():
    def loss_fn(config, fn, data, l_ws, params_sa):
        err, metrics = error(config, fn, data)
        components = [k for k in ALL_COMPONENTS if k in err]
        loss_terms = {}
        for k in components:
            w_k = l_ws.get(k, 1.0)
            m_k = params_sa.get(k, jnp.ones_like(err[k]))
            loss_terms[k] = adj(err[k], w_k, m_k)
        return loss_terms, metrics
    return loss_fn

loss_fn_lb = { "MLP": make_loss_lb(), "PINN": make_loss_lb() }

def make_loss_fn(components_key):
    def loss_fn(config, fn, data, l_ws, params_sa):
        loss_terms, metrics = loss_fn_lb[components_key](config, fn, data, l_ws, params_sa)
        total = jnp.sum(jnp.array(list(loss_terms.values())))
        return total, metrics
    return loss_fn

loss_fn = { "MLP": make_loss_fn("MLP"), "PINN": make_loss_fn("PINN") }


# ====== Sample-wise masks ======
def init_params_sa(loss_str, data):
    if len(data) == 3:
        x_tau_pde, x_bc_zero, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_traj": jnp.ones(1),
        }
    elif len(data) == 4:
        x_tau_pde, x_bc_zero, x_term_zero, _ = data
        return {
            "e_pde": jnp.ones(len(x_tau_pde)),
            "e_bc_zero": jnp.ones(len(x_bc_zero)),
            "e_term": jnp.ones(len(x_term_zero)),
            "e_symm": jnp.ones(len(x_tau_pde)),
            "e_traj": jnp.ones(1),
        }
    else:
        raise ValueError("Unexpected data tuple length in init_params_sa.")

# Initial static weights 
init_l_ws = {
    "PINN": { 'e_pde': 1.0, 'e_bc_zero': 0.1, 'e_term': 0.1, 'e_symm': 0.5, 'e_traj': 5.0}
}


# ====== Rebalancer ======
class Rebalancer:
    def __init__(
        self, keys,
        ema_beta=0.95,
        power=0.2,
        w_clip=(0.5, 2.0),
        ema_floor=1e-4,
        allow_upweight_small=False,
        freeze_tol=1e-5,
        freeze_patience=10,
        base_weights=None,        
        static_keys=None,         
        relative_to_init=True,
        eps=1e-12,
    ):
        self.keys = list(keys)
        self.ema_beta = float(ema_beta)
        self.power = float(power)
        self.w_min, self.w_max = map(float, w_clip)
        self.ema_floor = float(ema_floor)
        self.allow_upweight_small = bool(allow_upweight_small)
        self.freeze_tol = float(freeze_tol)
        self.freeze_patience = int(freeze_patience)
        self.base_weights = dict(base_weights or {})
        self.static_keys = set(static_keys or ())
        self.relative_to_init = bool(relative_to_init)
        self.eps = float(eps)

        self.ema = {k: None for k in self.keys}
        self.init_ema = {k: None for k in self.keys}
        self.below_ctr = {k: 0 for k in self.keys}
        self.frozen = {k: False for k in self.keys}

    def _smooth_update(self, old, new):
        if old is None:
            return new
        return self.ema_beta * old + (1.0 - self.ema_beta) * new

    def step(self, metrics, weights):
        for k in self.keys:
            if k not in metrics:
                continue
            val = float(metrics[k])
            val = max(val, self.ema_floor) 
            self.ema[k] = self._smooth_update(self.ema[k], val)
            if self.init_ema[k] is None:
                self.init_ema[k] = self.ema[k]

            # check freeze criterion
            if self.ema[k] < self.freeze_tol:
                self.below_ctr[k] += 1
            else:
                self.below_ctr[k] = 0
            if self.freeze_patience > 0 and self.below_ctr[k] >= self.freeze_patience:
                self.frozen[k] = True

        present = [
            k for k in self.keys
            if (k in metrics and self.ema[k] is not None and not self.frozen[k] and k not in self.static_keys)
        ]
        if not present:
            new_w = dict(weights)
            for k in self.keys:
                if self.frozen[k]:
                    new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
            return new_w

        def rel_ema(k):
            if not self.relative_to_init:
                return max(self.ema[k], self.ema_floor)
            denom = max(self.init_ema[k] or self.ema_floor, self.ema_floor)
            return max(self.ema[k] / denom, self.ema_floor)

        rels = {k: rel_ema(k) for k in present}
        gmean = float(np.exp(np.mean([np.log(max(rels[k], self.eps)) for k in present])))

        new_w = dict(weights)
        for k in self.keys:
            if self.frozen[k]:
                new_w[k] = float(self.base_weights.get(k, new_w.get(k, 1.0)))
                continue
            if k in self.static_keys or k not in rels:
                new_w[k] = float(new_w.get(k, 1.0))
                continue

            ratio = max(rels[k] / gmean, self.eps)
            if not self.allow_upweight_small and ratio < 1.0:
                mult = 1.0 
            else:
                mult = ratio ** (-self.power)

            new_w[k] = float(np.clip(new_w.get(k, 1.0) * mult, self.w_min, self.w_max))

        mean_w = float(np.mean([new_w[k] for k in present])) if present else 1.0
        if mean_w > 0:
            for k in present:
                new_w[k] = new_w[k] / mean_w
        return new_w


# ====== Training ======
def calibration(config, data, params_init=None, l_ws=None, params_sa=None):
    ann = ann_gen(config)
    ofunc = loss_fn[config.loss_str]

    if l_ws is None:
        l_ws = dict(init_l_ws[config.loss_str])
    if params_sa is None:
        params_sa = init_params_sa(config.loss_str, data)

        rebal_cfg = getattr(config, "rebal", None)
    if rebal_cfg is None:
        rebal_cfg = ml_collections.ConfigDict({})

    rebal = Rebalancer(
        keys=[k for k in ALL_COMPONENTS if k in (params_sa.keys())],
        ema_beta=getattr(rebal_cfg, "ema_beta", 0.98),
        power=getattr(rebal_cfg, "power", 0.2),
        w_clip=tuple(getattr(rebal_cfg, "w_clip", (0.3, 3.0))),
        ema_floor=getattr(rebal_cfg, "ema_floor", 1e-3),
        allow_upweight_small=getattr(rebal_cfg, "allow_upweight_small", False),
        freeze_tol=getattr(rebal_cfg, "freeze_tol", 1e-4),
        freeze_patience=getattr(rebal_cfg, "freeze_patience", 10),
        base_weights=dict(getattr(rebal_cfg, "base_weights", {"e_bc_zero": 0.1})),
        static_keys=set(getattr(rebal_cfg, "static_keys", ())),
        relative_to_init=getattr(rebal_cfg, "relative_to_init", True),
    )


    key = jran.PRNGKey(config.seed)
    _, key_init = jran.split(key, 2)
    dummy = jnp.ones((1, config.ann_in_dim))
    params0 = ann.init(key_init, dummy) if params_init is None else params_init

    state = train_state.TrainState.create(
        apply_fn=ann.apply,
        params=params0,
        tx=optax.adamw(learning_rate=5e-4)
    )

    @jit
    def train_step(state, data, l_ws, params_sa):
        def wrapped_loss(params):
            def fn(x): return ann.apply(params, x)
            return ofunc(config, fn, data, l_ws, params_sa)
        (loss, metrics), grads = value_and_grad(wrapped_loss, has_aux=True)(state.params)
        state = state.apply_gradients(grads=grads)
        return state, loss, metrics

    hist = []
    for epoch in range(config.num_epochs):
        state, loss, metrics = train_step(state, data, l_ws, params_sa)

        if (epoch >= rebal_cfg.start_epoch) and ((epoch - rebal_cfg.start_epoch) % rebal_cfg.every == 0):
            l_ws = rebal.step(metrics, l_ws)

        if epoch % 100 == 0:
            w_str = "{"+", ".join(f"{k}:{l_ws.get(k,1.0):.3g}" for k in sorted(l_ws.keys()))+"}"
            keys = ['e_pde','e_bc_zero','e_term','e_symm','e_traj']
            msg  = " | ".join(f"{k}={float(metrics[k]):.6f}" for k in keys if k in metrics)
            print(f"Epoch {epoch}: total={float(loss):.6f} | {msg} | w={w_str}")

        hist.append((int(epoch), float(loss), {k: float(metrics[k]) for k in metrics}))

    return (lambda x: ann.apply(state.params, x)), hist, state.params, ann


# ====== Curriculum runner ======
def save_params_overwrite(path, params):
    path = os.path.abspath(path)
    if os.path.exists(path):
        shutil.rmtree(path)
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    try:
        ckptr.save(path, params, force=True)  
    except TypeError:
        ckptr.save(path, params)     

def save_stage(run_dir, tag, *, params, config, history):
    """
    writes:
      - {run_dir}/{tag}_params/  (Orbax checkpoint, overwrites)
      - {run_dir}/{tag}_config.json
      - {run_dir}/{tag}_history.pkl
    """
    run_dir = os.path.abspath(run_dir)
    os.makedirs(run_dir, exist_ok=True)
    save_params_overwrite(os.path.join(run_dir, f"{tag}_params"), params)
    def _to_jsonable(obj):
        try:
            return obj.to_dict()
        except Exception:
            if isinstance(obj, (dict, list, str, int, float, bool)) or obj is None:
                return obj
            if hasattr(obj, "items"):
                return {k: _to_jsonable(v) for k, v in obj.items()}
            return str(obj)
    with open(os.path.join(run_dir, f"{tag}_config.json"), "w") as f:
        json.dump(_to_jsonable(config), f, indent=2)
    with open(os.path.join(run_dir, f"{tag}_history.pkl"), "wb") as f:
        pickle.dump(history, f)

def restore_params(run_dir, tag):
    ckptr = ocp.Checkpointer(ocp.PyTreeCheckpointHandler())
    return ckptr.restore(os.path.abspath(os.path.join(run_dir, f"{tag}_params")))

def run_curriculum(config2d, config3d, lam_star, workdir=None):
    # ---- Phase A: 2D (lambda=0) ----
    config2d.dim = 2
    config2d.ann_in_dim = 2
    config2d.lam = 0.0
    alphas = config3d.alphas
    workdir = os.path.abspath(workdir or getattr(config3d, "workdir", "runs/pinn_oe"))
    os.makedirs(workdir, exist_ok=True)

    data2d = get_data_2d(
        n_pde=config2d.pts_num, n_bc=config2d.n_term_zero,
        T=config2d.T, x_range=config2d.x_range, seed=config2d.seed
    )
    _, hist2d, params_2d, _ = calibration(config2d, data2d)

    # save 2D stage
    save_stage(workdir, "2d_lam0", params=params_2d, config=config2d, history=hist2d)

    if alphas is None:
        return params_2d, {"2d": hist2d}

    # ---- Phase B: inflate to 3D, then curriculum over lambda ----
    config3d.dim = 3
    config3d.ann_in_dim = 3
    ann3d = ann_gen(config3d)
    params_3d_init = ann3d.init(jran.PRNGKey(1), jnp.ones((1,3)))
    params = inflate_2d_to_3d_params(params_2d, params_3d_init)

    data3d = get_data_3d(
        n_pde=config3d.pts_num, n_bc=config3d.n_bc_zero, n_term=config3d.n_term_zero,
        T=config3d.T, x_range=config3d.x_range, s_range=config3d.s_range, seed=config3d.seed
    )

    all_hist = {"2d": hist2d}
    start = time.time()
    for alpha in alphas:
        lam_stage = float(alpha * lam_star)
        print(f"\n=== 3D stage: alpha={alpha}, lambda={lam_stage} ===")
        config3d.lam = lam_stage
        _, hist, params, _ = calibration(config3d, data3d, params_init=params)
        all_hist[f"alpha_{alpha}"] = hist
        tag = f"alpha_{alpha}".replace('.', 'p')  
        save_stage(workdir, tag, params=params, config=config3d, history=hist)

    print(f"Training completed in {time.time() - start:.2f} s total.")
    return params, all_hist


# ====== Model builder ======
def build_model_fn(config, params):
    ann = ann_gen(config)
    return jax.jit(lambda x: ann.apply(params, x))  


# ====== Default configs ======
T_days = 2/6.5
def default_configs():
    config2d = ml_collections.ConfigDict({
        "seed": 42,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (32, 32, 32),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 2,
        "ann_in_dim": 2,
        "num_epochs": 20000,
        "pts_num": 30000,
        "x_range": (-1.0, 1.0),
        "T": T_days,
        "T_list": [T_days/20, T_days/10, T_days/4, T_days/2, 3*T_days/4, T_days],
        "traj_Ndt": 50,
        "n_X": 200,
        "kappa": 0.2,
        "lam": 0.0,             # not used in 2D residual
        "n_term_zero": 2000,    
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 5000,
            "ema_beta": 0.9,
            "power": 0.1,
            "w_clip": (0.1, 5.0),
        }),
    })

    config3d = ml_collections.ConfigDict({
        "seed": 43,
        "loss_str": "PINN",
        "ann_str": "MLP",
        "ann_hidden_dim": (32, 32, 32),
        "ann_out_dim": 1,
        "ann_activation_str": "tanh",
        "ann_periodicity": None,
        "ann_fourier_emb": None,
        "ann_reparam": False,
        "dim": 3,
        "ann_in_dim": 3,
        "num_epochs": 5000,
        "pts_num": 20000,
        "x_range": (-1.0, 1.0),
        "s_range": (590, 620),
        "T": T_days,
        "T_list": [T_days/20, T_days/10, T_days/4, T_days/2, 3*T_days/4, T_days],
        "traj_Ndt": 50,
        "n_X": 200,
        "n_S": 41,
        "kappa": 0.2,
        "sigma": 0.0038,
        "lam": 0.05,             
        "n_bc_zero": 2000,      
        "n_term_zero": 200,     
        "alphas": (0.25, 0.5, 0.75, 1.0),
        "workdir": os.path.abspath("runs/pinn_oe"),
        "rebal": ml_collections.ConfigDict({
            "start_epoch": 500,
            "every": 1000,
            "ema_beta": 0.95,
            "power": 0.1,
            "w_clip": (0.1, 5.0),
        }),
    })
    return config2d, config3d


config2d, config3d = default_configs()
final_params, all_hist = run_curriculum(config2d, config3d, lam_star=config3d.lam, workdir=config3d.workdir)
model_PINN = build_model_fn(config3d, final_params)
print("Done. Checkpoints in:", config3d.workdir)
# Out:
# Epoch 0: total=3.161170 | e_pde=0.435387 | e_bc_zero=0.012398 | e_symm=0.402689 | e_traj=0.504640 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 100: total=2.489887 | e_pde=0.000409 | e_bc_zero=0.006769 | e_symm=0.000056 | e_traj=0.497755 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 200: total=2.383743 | e_pde=0.000463 | e_bc_zero=0.030305 | e_symm=0.000357 | e_traj=0.476014 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 300: total=2.153421 | e_pde=0.055451 | e_bc_zero=0.032343 | e_symm=0.002721 | e_traj=0.418675 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 400: total=1.988062 | e_pde=0.065783 | e_bc_zero=0.016829 | e_symm=0.000479 | e_traj=0.384071 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 500: total=1.760694 | e_pde=0.069863 | e_bc_zero=0.016935 | e_symm=0.000973 | e_traj=0.337730 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 600: total=1.001189 | e_pde=0.091568 | e_bc_zero=0.010203 | e_symm=0.000671 | e_traj=0.311807 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 700: total=0.940113 | e_pde=0.083443 | e_bc_zero=0.011139 | e_symm=0.000587 | e_traj=0.293267 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 800: total=0.874412 | e_pde=0.085353 | e_bc_zero=0.009102 | e_symm=0.000813 | e_traj=0.271222 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 900: total=0.826732 | e_pde=0.089843 | e_bc_zero=0.005835 | e_symm=0.000671 | e_traj=0.254669 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1000: total=0.782401 | e_pde=0.082626 | e_bc_zero=0.005532 | e_symm=0.001350 | e_traj=0.241422 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1100: total=0.737181 | e_pde=0.068798 | e_bc_zero=0.006480 | e_symm=0.001957 | e_traj=0.229185 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1200: total=0.702229 | e_pde=0.064253 | e_bc_zero=0.004935 | e_symm=0.002031 | e_traj=0.218583 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1300: total=0.676828 | e_pde=0.064689 | e_bc_zero=0.004202 | e_symm=0.002048 | e_traj=0.210126 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1400: total=0.656958 | e_pde=0.068005 | e_bc_zero=0.004648 | e_symm=0.001696 | e_traj=0.202933 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1500: total=0.640265 | e_pde=0.067713 | e_bc_zero=0.004225 | e_symm=0.001929 | e_traj=0.197467 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1600: total=0.624877 | e_pde=0.067112 | e_bc_zero=0.003235 | e_symm=0.001959 | e_traj=0.192526 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1700: total=0.610896 | e_pde=0.065605 | e_bc_zero=0.003433 | e_symm=0.002147 | e_traj=0.188191 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1800: total=0.598607 | e_pde=0.063793 | e_bc_zero=0.002434 | e_symm=0.002382 | e_traj=0.184495 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 1900: total=0.586935 | e_pde=0.061587 | e_bc_zero=0.001969 | e_symm=0.002732 | e_traj=0.181058 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2000: total=0.578825 | e_pde=0.067376 | e_bc_zero=0.002900 | e_symm=0.002761 | e_traj=0.177203 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2100: total=0.568067 | e_pde=0.063064 | e_bc_zero=0.002052 | e_symm=0.002829 | e_traj=0.174525 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2200: total=0.560051 | e_pde=0.062360 | e_bc_zero=0.001579 | e_symm=0.002817 | e_traj=0.172031 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2300: total=0.552384 | e_pde=0.062283 | e_bc_zero=0.001887 | e_symm=0.002651 | e_traj=0.169527 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2400: total=0.546992 | e_pde=0.063627 | e_bc_zero=0.001388 | e_symm=0.002707 | e_traj=0.167484 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2500: total=0.538637 | e_pde=0.061828 | e_bc_zero=0.001500 | e_symm=0.002533 | e_traj=0.165101 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2600: total=0.531934 | e_pde=0.061948 | e_bc_zero=0.001702 | e_symm=0.002387 | e_traj=0.162876 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2700: total=0.526045 | e_pde=0.062407 | e_bc_zero=0.001639 | e_symm=0.002482 | e_traj=0.160832 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2800: total=0.519633 | e_pde=0.059982 | e_bc_zero=0.000666 | e_symm=0.002565 | e_traj=0.159212 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 2900: total=0.514912 | e_pde=0.061026 | e_bc_zero=0.000971 | e_symm=0.002951 | e_traj=0.157401 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3000: total=0.508822 | e_pde=0.059329 | e_bc_zero=0.000669 | e_symm=0.002238 | e_traj=0.155808 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3100: total=0.504733 | e_pde=0.059986 | e_bc_zero=0.000587 | e_symm=0.002724 | e_traj=0.154280 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3200: total=0.499461 | e_pde=0.058740 | e_bc_zero=0.000977 | e_symm=0.002475 | e_traj=0.152807 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3300: total=0.494874 | e_pde=0.057914 | e_bc_zero=0.000841 | e_symm=0.002389 | e_traj=0.151470 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3400: total=0.489677 | e_pde=0.055148 | e_bc_zero=0.000692 | e_symm=0.002419 | e_traj=0.150308 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3500: total=0.485852 | e_pde=0.054512 | e_bc_zero=0.000576 | e_symm=0.003032 | e_traj=0.149114 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3600: total=0.482319 | e_pde=0.055721 | e_bc_zero=0.000816 | e_symm=0.002697 | e_traj=0.147735 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3700: total=0.478214 | e_pde=0.053893 | e_bc_zero=0.000519 | e_symm=0.002943 | e_traj=0.146727 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3800: total=0.475529 | e_pde=0.056368 | e_bc_zero=0.000616 | e_symm=0.002331 | e_traj=0.145406 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 3900: total=0.471258 | e_pde=0.053843 | e_bc_zero=0.000489 | e_symm=0.003007 | e_traj=0.144436 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4000: total=0.477169 | e_pde=0.068256 | e_bc_zero=0.000431 | e_symm=0.002104 | e_traj=0.143596 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4100: total=0.464365 | e_pde=0.052173 | e_bc_zero=0.000510 | e_symm=0.003144 | e_traj=0.142481 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4200: total=0.463391 | e_pde=0.054945 | e_bc_zero=0.000556 | e_symm=0.003607 | e_traj=0.141558 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4300: total=0.458588 | e_pde=0.051755 | e_bc_zero=0.000424 | e_symm=0.003111 | e_traj=0.140663 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4400: total=0.456671 | e_pde=0.054288 | e_bc_zero=0.000651 | e_symm=0.003299 | e_traj=0.139501 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4500: total=0.454029 | e_pde=0.053884 | e_bc_zero=0.000686 | e_symm=0.003013 | e_traj=0.138738 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4600: total=0.451797 | e_pde=0.052745 | e_bc_zero=0.000368 | e_symm=0.002917 | e_traj=0.138245 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4700: total=0.450935 | e_pde=0.055121 | e_bc_zero=0.000398 | e_symm=0.002770 | e_traj=0.137500 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4800: total=0.447304 | e_pde=0.054334 | e_bc_zero=0.000597 | e_symm=0.003278 | e_traj=0.136404 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 4900: total=0.444195 | e_pde=0.052309 | e_bc_zero=0.000459 | e_symm=0.003021 | e_traj=0.135811 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5000: total=0.442278 | e_pde=0.053718 | e_bc_zero=0.000426 | e_symm=0.003360 | e_traj=0.134864 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5100: total=0.442821 | e_pde=0.058244 | e_bc_zero=0.000389 | e_symm=0.002560 | e_traj=0.134218 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5200: total=0.439783 | e_pde=0.056241 | e_bc_zero=0.000430 | e_symm=0.003884 | e_traj=0.133483 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5300: total=0.435657 | e_pde=0.051749 | e_bc_zero=0.000366 | e_symm=0.002898 | e_traj=0.133120 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5400: total=0.435038 | e_pde=0.054331 | e_bc_zero=0.000431 | e_symm=0.003043 | e_traj=0.132383 | w={e_bc_zero:0.0606, e_pde:0.606, e_symm:0.303, e_term:0.1, e_traj:3.03}
# Epoch 5500: total=0.432971 | e_pde=0.053516 | e_bc_zero=0.000419 | e_symm=0.002767 | e_traj=0.131892 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 5600: total=0.426931 | e_pde=0.052831 | e_bc_zero=0.000333 | e_symm=0.002705 | e_traj=0.131254 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 5700: total=0.443306 | e_pde=0.079578 | e_bc_zero=0.000305 | e_symm=0.005338 | e_traj=0.131096 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 5800: total=0.424171 | e_pde=0.051904 | e_bc_zero=0.000278 | e_symm=0.002626 | e_traj=0.130530 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 5900: total=0.422889 | e_pde=0.052643 | e_bc_zero=0.000313 | e_symm=0.003064 | e_traj=0.129911 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6000: total=0.422323 | e_pde=0.053985 | e_bc_zero=0.000341 | e_symm=0.002600 | e_traj=0.129499 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6100: total=0.419431 | e_pde=0.050994 | e_bc_zero=0.000317 | e_symm=0.003057 | e_traj=0.129090 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6200: total=0.421338 | e_pde=0.056818 | e_bc_zero=0.000351 | e_symm=0.002194 | e_traj=0.128644 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6300: total=0.416689 | e_pde=0.051779 | e_bc_zero=0.000318 | e_symm=0.002513 | e_traj=0.128074 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6400: total=0.417429 | e_pde=0.054415 | e_bc_zero=0.000264 | e_symm=0.003448 | e_traj=0.127703 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6500: total=0.413588 | e_pde=0.051107 | e_bc_zero=0.000257 | e_symm=0.002399 | e_traj=0.127190 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6600: total=0.411322 | e_pde=0.050133 | e_bc_zero=0.000297 | e_symm=0.002596 | e_traj=0.126610 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6700: total=0.413095 | e_pde=0.055628 | e_bc_zero=0.000254 | e_symm=0.002198 | e_traj=0.126141 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6800: total=0.409586 | e_pde=0.051118 | e_bc_zero=0.000265 | e_symm=0.002427 | e_traj=0.125853 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 6900: total=0.407472 | e_pde=0.050045 | e_bc_zero=0.000257 | e_symm=0.002315 | e_traj=0.125375 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7000: total=0.437761 | e_pde=0.100756 | e_bc_zero=0.000310 | e_symm=0.004093 | e_traj=0.125137 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7100: total=0.405599 | e_pde=0.050229 | e_bc_zero=0.000180 | e_symm=0.002126 | e_traj=0.124736 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7200: total=0.404388 | e_pde=0.049392 | e_bc_zero=0.000266 | e_symm=0.002579 | e_traj=0.124453 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7300: total=0.402439 | e_pde=0.048865 | e_bc_zero=0.000195 | e_symm=0.002590 | e_traj=0.123911 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7400: total=0.403927 | e_pde=0.053126 | e_bc_zero=0.000262 | e_symm=0.002111 | e_traj=0.123599 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7500: total=0.400727 | e_pde=0.050082 | e_bc_zero=0.000202 | e_symm=0.002498 | e_traj=0.123106 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7600: total=0.399998 | e_pde=0.050925 | e_bc_zero=0.000196 | e_symm=0.002648 | e_traj=0.122681 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7700: total=0.426461 | e_pde=0.092631 | e_bc_zero=0.000191 | e_symm=0.004543 | e_traj=0.122961 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7800: total=0.397044 | e_pde=0.047567 | e_bc_zero=0.000182 | e_symm=0.002093 | e_traj=0.122424 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 7900: total=0.396250 | e_pde=0.048906 | e_bc_zero=0.000190 | e_symm=0.002472 | e_traj=0.121855 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8000: total=0.410963 | e_pde=0.074320 | e_bc_zero=0.000175 | e_symm=0.003361 | e_traj=0.121581 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8100: total=0.394422 | e_pde=0.049457 | e_bc_zero=0.000209 | e_symm=0.002368 | e_traj=0.121145 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8200: total=0.395797 | e_pde=0.053058 | e_bc_zero=0.000168 | e_symm=0.002056 | e_traj=0.120915 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8300: total=0.406029 | e_pde=0.069445 | e_bc_zero=0.000168 | e_symm=0.003540 | e_traj=0.120897 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8400: total=0.391760 | e_pde=0.049136 | e_bc_zero=0.000173 | e_symm=0.002392 | e_traj=0.120322 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8500: total=0.394502 | e_pde=0.056412 | e_bc_zero=0.000139 | e_symm=0.001816 | e_traj=0.119838 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8600: total=0.390075 | e_pde=0.049387 | e_bc_zero=0.000145 | e_symm=0.002339 | e_traj=0.119717 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8700: total=0.409358 | e_pde=0.079918 | e_bc_zero=0.000148 | e_symm=0.004091 | e_traj=0.119857 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8800: total=0.388248 | e_pde=0.048716 | e_bc_zero=0.000181 | e_symm=0.002361 | e_traj=0.119240 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 8900: total=0.387378 | e_pde=0.049061 | e_bc_zero=0.000135 | e_symm=0.002656 | e_traj=0.118854 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9000: total=0.395581 | e_pde=0.062321 | e_bc_zero=0.000163 | e_symm=0.003891 | e_traj=0.118810 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9100: total=0.388218 | e_pde=0.053293 | e_bc_zero=0.000176 | e_symm=0.001996 | e_traj=0.118351 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9200: total=0.384927 | e_pde=0.048895 | e_bc_zero=0.000173 | e_symm=0.002019 | e_traj=0.118133 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9300: total=0.385249 | e_pde=0.050843 | e_bc_zero=0.000178 | e_symm=0.002639 | e_traj=0.117790 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9400: total=0.383410 | e_pde=0.049539 | e_bc_zero=0.000197 | e_symm=0.002335 | e_traj=0.117467 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9500: total=0.383510 | e_pde=0.049904 | e_bc_zero=0.000151 | e_symm=0.002391 | e_traj=0.117424 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9600: total=0.381707 | e_pde=0.049157 | e_bc_zero=0.000145 | e_symm=0.002063 | e_traj=0.117006 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9700: total=0.383972 | e_pde=0.054185 | e_bc_zero=0.000143 | e_symm=0.001968 | e_traj=0.116763 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9800: total=0.380630 | e_pde=0.050568 | e_bc_zero=0.000151 | e_symm=0.002227 | e_traj=0.116348 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 9900: total=0.380666 | e_pde=0.051807 | e_bc_zero=0.000156 | e_symm=0.002378 | e_traj=0.116098 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10000: total=0.390795 | e_pde=0.069516 | e_bc_zero=0.000245 | e_symm=0.002665 | e_traj=0.115896 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10100: total=0.379313 | e_pde=0.051408 | e_bc_zero=0.000177 | e_symm=0.002476 | e_traj=0.115717 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10200: total=0.462316 | e_pde=0.187526 | e_bc_zero=0.000213 | e_symm=0.002185 | e_traj=0.116147 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10300: total=0.435964 | e_pde=0.145426 | e_bc_zero=0.000166 | e_symm=0.002115 | e_traj=0.115804 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10400: total=0.380009 | e_pde=0.055827 | e_bc_zero=0.000204 | e_symm=0.002418 | e_traj=0.115070 | w={e_bc_zero:0.0991, e_pde:0.601, e_symm:0.295, e_term:0.1, e_traj:3}
# Epoch 10500: total=0.416314 | e_pde=0.115186 | e_bc_zero=0.000121 | e_symm=0.001953 | e_traj=0.115330 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 10600: total=0.381253 | e_pde=0.057615 | e_bc_zero=0.000163 | e_symm=0.002905 | e_traj=0.114847 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 10700: total=0.385754 | e_pde=0.067164 | e_bc_zero=0.000129 | e_symm=0.001758 | e_traj=0.114555 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 10800: total=0.390187 | e_pde=0.072007 | e_bc_zero=0.000121 | e_symm=0.003524 | e_traj=0.114894 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 10900: total=0.376021 | e_pde=0.053424 | e_bc_zero=0.000127 | e_symm=0.002099 | e_traj=0.114022 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11000: total=0.378590 | e_pde=0.058980 | e_bc_zero=0.000120 | e_symm=0.001893 | e_traj=0.113791 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11100: total=0.434955 | e_pde=0.151140 | e_bc_zero=0.000119 | e_symm=0.007255 | e_traj=0.113664 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11200: total=0.423344 | e_pde=0.132956 | e_bc_zero=0.000115 | e_symm=0.002210 | e_traj=0.113909 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11300: total=0.414405 | e_pde=0.117006 | e_bc_zero=0.000120 | e_symm=0.004966 | e_traj=0.113848 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11400: total=0.377985 | e_pde=0.061000 | e_bc_zero=0.000102 | e_symm=0.001806 | e_traj=0.113197 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11500: total=0.370603 | e_pde=0.048732 | e_bc_zero=0.000122 | e_symm=0.002448 | e_traj=0.113123 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11600: total=0.371227 | e_pde=0.050501 | e_bc_zero=0.000123 | e_symm=0.002729 | e_traj=0.112951 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11700: total=0.372820 | e_pde=0.053698 | e_bc_zero=0.000127 | e_symm=0.002125 | e_traj=0.112902 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11800: total=0.371795 | e_pde=0.053020 | e_bc_zero=0.000147 | e_symm=0.002392 | e_traj=0.112671 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 11900: total=0.381722 | e_pde=0.070577 | e_bc_zero=0.000145 | e_symm=0.002082 | e_traj=0.112505 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12000: total=0.398277 | e_pde=0.097554 | e_bc_zero=0.000186 | e_symm=0.004286 | e_traj=0.112424 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12100: total=0.415417 | e_pde=0.125295 | e_bc_zero=0.000099 | e_symm=0.005510 | e_traj=0.112484 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12200: total=0.367679 | e_pde=0.049465 | e_bc_zero=0.000124 | e_symm=0.002402 | e_traj=0.112011 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12300: total=0.382378 | e_pde=0.072429 | e_bc_zero=0.000113 | e_symm=0.003102 | e_traj=0.112258 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12400: total=0.369171 | e_pde=0.052142 | e_bc_zero=0.000110 | e_symm=0.002490 | e_traj=0.111966 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12500: total=0.372425 | e_pde=0.057510 | e_bc_zero=0.000125 | e_symm=0.002866 | e_traj=0.111942 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12600: total=0.394284 | e_pde=0.094271 | e_bc_zero=0.000126 | e_symm=0.001838 | e_traj=0.111989 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12700: total=0.366588 | e_pde=0.050687 | e_bc_zero=0.000121 | e_symm=0.002319 | e_traj=0.111414 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12800: total=0.367738 | e_pde=0.052288 | e_bc_zero=0.000142 | e_symm=0.002077 | e_traj=0.111500 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 12900: total=0.365347 | e_pde=0.050337 | e_bc_zero=0.000135 | e_symm=0.002270 | e_traj=0.111075 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13000: total=0.385692 | e_pde=0.082696 | e_bc_zero=0.000115 | e_symm=0.003511 | e_traj=0.111277 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13100: total=0.373869 | e_pde=0.066068 | e_bc_zero=0.000178 | e_symm=0.003358 | e_traj=0.110671 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13200: total=0.367296 | e_pde=0.054279 | e_bc_zero=0.000152 | e_symm=0.002219 | e_traj=0.110943 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13300: total=0.363616 | e_pde=0.049421 | e_bc_zero=0.000135 | e_symm=0.002195 | e_traj=0.110690 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13400: total=0.419611 | e_pde=0.141262 | e_bc_zero=0.000128 | e_symm=0.002557 | e_traj=0.110984 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13500: total=0.407168 | e_pde=0.119230 | e_bc_zero=0.000191 | e_symm=0.004698 | e_traj=0.111026 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13600: total=0.368977 | e_pde=0.059418 | e_bc_zero=0.000105 | e_symm=0.002740 | e_traj=0.110431 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13700: total=0.362697 | e_pde=0.049333 | e_bc_zero=0.000116 | e_symm=0.002232 | e_traj=0.110400 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13800: total=0.402874 | e_pde=0.115867 | e_bc_zero=0.000134 | e_symm=0.002109 | e_traj=0.110520 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 13900: total=0.367859 | e_pde=0.058750 | e_bc_zero=0.000080 | e_symm=0.001994 | e_traj=0.110265 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14000: total=0.363568 | e_pde=0.053865 | e_bc_zero=0.000098 | e_symm=0.001979 | e_traj=0.109812 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14100: total=0.371396 | e_pde=0.064840 | e_bc_zero=0.000186 | e_symm=0.002826 | e_traj=0.110145 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14200: total=0.364727 | e_pde=0.055839 | e_bc_zero=0.000121 | e_symm=0.002694 | e_traj=0.109735 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14300: total=0.365985 | e_pde=0.058815 | e_bc_zero=0.000129 | e_symm=0.001973 | e_traj=0.109630 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14400: total=0.443497 | e_pde=0.184443 | e_bc_zero=0.000169 | e_symm=0.005411 | e_traj=0.110052 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14500: total=0.398753 | e_pde=0.112847 | e_bc_zero=0.000119 | e_symm=0.004411 | e_traj=0.109531 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14600: total=0.358870 | e_pde=0.049492 | e_bc_zero=0.000128 | e_symm=0.002324 | e_traj=0.109088 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14700: total=0.369690 | e_pde=0.067099 | e_bc_zero=0.000121 | e_symm=0.001843 | e_traj=0.109226 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14800: total=0.371128 | e_pde=0.068489 | e_bc_zero=0.000182 | e_symm=0.001779 | e_traj=0.109431 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 14900: total=0.362337 | e_pde=0.053683 | e_bc_zero=0.000117 | e_symm=0.002740 | e_traj=0.109366 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15000: total=0.357431 | e_pde=0.048156 | e_bc_zero=0.000145 | e_symm=0.002070 | e_traj=0.108900 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15100: total=0.365218 | e_pde=0.061001 | e_bc_zero=0.000125 | e_symm=0.001818 | e_traj=0.108956 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15200: total=0.359445 | e_pde=0.050938 | e_bc_zero=0.000170 | e_symm=0.002015 | e_traj=0.109020 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15300: total=0.357053 | e_pde=0.048197 | e_bc_zero=0.000126 | e_symm=0.002189 | e_traj=0.108755 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15400: total=0.374876 | e_pde=0.077720 | e_bc_zero=0.000099 | e_symm=0.003207 | e_traj=0.108705 | w={e_bc_zero:0.1, e_pde:0.599, e_symm:0.289, e_term:0.1, e_traj:3.01}
# Epoch 15500: total=0.356431 | e_pde=0.047581 | e_bc_zero=0.000121 | e_symm=0.002211 | e_traj=0.108669 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 15600: total=0.360352 | e_pde=0.054984 | e_bc_zero=0.000130 | e_symm=0.001984 | e_traj=0.108197 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 15700: total=0.432113 | e_pde=0.169257 | e_bc_zero=0.000148 | e_symm=0.005206 | e_traj=0.109042 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 15800: total=0.357147 | e_pde=0.049708 | e_bc_zero=0.000133 | e_symm=0.002341 | e_traj=0.108147 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 15900: total=0.360819 | e_pde=0.053504 | e_bc_zero=0.000206 | e_symm=0.002748 | e_traj=0.108571 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16000: total=0.382224 | e_pde=0.089522 | e_bc_zero=0.000145 | e_symm=0.003077 | e_traj=0.108501 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16100: total=0.375281 | e_pde=0.080204 | e_bc_zero=0.000129 | e_symm=0.001857 | e_traj=0.108160 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16200: total=0.371220 | e_pde=0.074948 | e_bc_zero=0.000131 | e_symm=0.001793 | e_traj=0.107862 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16300: total=0.371262 | e_pde=0.075190 | e_bc_zero=0.000117 | e_symm=0.003408 | e_traj=0.107679 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16400: total=0.370257 | e_pde=0.074954 | e_bc_zero=0.000146 | e_symm=0.001947 | e_traj=0.107527 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16500: total=0.357764 | e_pde=0.053507 | e_bc_zero=0.000155 | e_symm=0.002225 | e_traj=0.107609 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16600: total=0.371060 | e_pde=0.076028 | e_bc_zero=0.000231 | e_symm=0.001826 | e_traj=0.107589 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16700: total=0.363256 | e_pde=0.064296 | e_bc_zero=0.000156 | e_symm=0.001901 | e_traj=0.107323 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16800: total=0.354023 | e_pde=0.049308 | e_bc_zero=0.000150 | e_symm=0.002058 | e_traj=0.107217 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 16900: total=0.379929 | e_pde=0.090887 | e_bc_zero=0.000106 | e_symm=0.001807 | e_traj=0.107591 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17000: total=0.360216 | e_pde=0.059472 | e_bc_zero=0.000120 | e_symm=0.002817 | e_traj=0.107187 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17100: total=0.354116 | e_pde=0.048643 | e_bc_zero=0.000113 | e_symm=0.002539 | e_traj=0.107336 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17200: total=0.379422 | e_pde=0.091259 | e_bc_zero=0.000109 | e_symm=0.003626 | e_traj=0.107181 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17300: total=0.392801 | e_pde=0.114004 | e_bc_zero=0.000174 | e_symm=0.001966 | e_traj=0.107261 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17400: total=0.420575 | e_pde=0.158679 | e_bc_zero=0.000148 | e_symm=0.005441 | e_traj=0.107294 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17500: total=0.364966 | e_pde=0.071094 | e_bc_zero=0.000162 | e_symm=0.001947 | e_traj=0.106539 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17600: total=0.368929 | e_pde=0.077751 | e_bc_zero=0.000126 | e_symm=0.001923 | e_traj=0.106537 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17700: total=0.395580 | e_pde=0.122703 | e_bc_zero=0.000148 | e_symm=0.002225 | e_traj=0.106437 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17800: total=0.353278 | e_pde=0.051860 | e_bc_zero=0.000149 | e_symm=0.001851 | e_traj=0.106485 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 17900: total=0.358277 | e_pde=0.060371 | e_bc_zero=0.000144 | e_symm=0.002376 | e_traj=0.106407 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18000: total=0.372933 | e_pde=0.084932 | e_bc_zero=0.000133 | e_symm=0.003356 | e_traj=0.106309 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18100: total=0.352606 | e_pde=0.051976 | e_bc_zero=0.000164 | e_symm=0.001950 | e_traj=0.106230 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18200: total=0.364537 | e_pde=0.071262 | e_bc_zero=0.000201 | e_symm=0.002545 | e_traj=0.106307 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18300: total=0.358453 | e_pde=0.063244 | e_bc_zero=0.000220 | e_symm=0.002025 | e_traj=0.105927 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18400: total=0.409267 | e_pde=0.143067 | e_bc_zero=0.000280 | e_symm=0.005450 | e_traj=0.106635 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18500: total=0.349242 | e_pde=0.049096 | e_bc_zero=0.000146 | e_symm=0.002114 | e_traj=0.105672 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18600: total=0.414720 | e_pde=0.156223 | e_bc_zero=0.000138 | e_symm=0.002792 | e_traj=0.106088 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18700: total=0.367382 | e_pde=0.076716 | e_bc_zero=0.000138 | e_symm=0.003061 | e_traj=0.106124 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18800: total=0.358311 | e_pde=0.064334 | e_bc_zero=0.000142 | e_symm=0.002515 | e_traj=0.105622 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 18900: total=0.349189 | e_pde=0.045895 | e_bc_zero=0.000181 | e_symm=0.001800 | e_traj=0.106316 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19000: total=0.354314 | e_pde=0.058564 | e_bc_zero=0.000218 | e_symm=0.002025 | e_traj=0.105483 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19100: total=0.363493 | e_pde=0.072034 | e_bc_zero=0.000226 | e_symm=0.001834 | e_traj=0.105874 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19200: total=0.368093 | e_pde=0.080552 | e_bc_zero=0.000138 | e_symm=0.001954 | e_traj=0.105703 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19300: total=0.353531 | e_pde=0.058079 | e_bc_zero=0.000184 | e_symm=0.002235 | e_traj=0.105302 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19400: total=0.347369 | e_pde=0.047722 | e_bc_zero=0.000172 | e_symm=0.002047 | e_traj=0.105329 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19500: total=0.350431 | e_pde=0.053251 | e_bc_zero=0.000154 | e_symm=0.002053 | e_traj=0.105249 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19600: total=0.364716 | e_pde=0.077325 | e_bc_zero=0.000225 | e_symm=0.002146 | e_traj=0.105203 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19700: total=0.347038 | e_pde=0.049455 | e_bc_zero=0.000154 | e_symm=0.001912 | e_traj=0.104890 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19800: total=0.454173 | e_pde=0.225049 | e_bc_zero=0.000269 | e_symm=0.005922 | e_traj=0.105236 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
# Epoch 19900: total=0.353850 | e_pde=0.060589 | e_bc_zero=0.000188 | e_symm=0.002727 | e_traj=0.104865 | w={e_bc_zero:0.101, e_pde:0.598, e_symm:0.28, e_term:0.1, e_traj:3.02}
#
# === 3D stage: alpha=0.25, lambda=0.0125 ===
# Epoch 0: total=20.321764 | e_pde=19.795033 | e_bc_zero=0.000120 | e_term=0.006797 | e_symm=0.001904 | e_traj=0.105018 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 100: total=24.980831 | e_pde=16.337765 | e_bc_zero=26.165504 | e_term=26.387203 | e_symm=1.931006 | e_traj=0.484459 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 200: total=14.703068 | e_pde=7.825851 | e_bc_zero=19.601990 | e_term=21.011074 | e_symm=1.297732 | e_traj=0.433409 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 300: total=8.212813 | e_pde=2.553445 | e_bc_zero=13.745574 | e_term=15.441546 | e_symm=1.452291 | e_traj=0.402902 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 400: total=6.394608 | e_pde=1.536395 | e_bc_zero=11.053720 | e_term=12.473546 | e_symm=1.074205 | e_traj=0.393677 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 500: total=5.253146 | e_pde=1.131857 | e_bc_zero=8.030914 | e_term=9.157817 | e_symm=0.954253 | e_traj=0.385058 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 600: total=3.409956 | e_pde=0.955354 | e_bc_zero=6.004320 | e_term=6.919412 | e_symm=0.857493 | e_traj=0.378573 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 700: total=3.024319 | e_pde=0.844972 | e_bc_zero=4.402582 | e_term=5.164207 | e_symm=0.766364 | e_traj=0.373551 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 800: total=2.707144 | e_pde=0.752187 | e_bc_zero=3.047411 | e_term=3.620872 | e_symm=0.728101 | e_traj=0.368901 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 900: total=2.451967 | e_pde=0.661819 | e_bc_zero=2.016474 | e_term=2.466638 | e_symm=0.712382 | e_traj=0.363863 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1000: total=2.243196 | e_pde=0.571916 | e_bc_zero=1.264581 | e_term=1.624412 | e_symm=0.698717 | e_traj=0.359142 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1100: total=2.073334 | e_pde=0.486271 | e_bc_zero=0.748188 | e_term=1.025555 | e_symm=0.673200 | e_traj=0.355605 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1200: total=1.936620 | e_pde=0.413550 | e_bc_zero=0.391640 | e_term=0.586657 | e_symm=0.643489 | e_traj=0.352389 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1300: total=1.832393 | e_pde=0.339802 | e_bc_zero=0.192595 | e_term=0.328917 | e_symm=0.628681 | e_traj=0.349823 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1400: total=1.756987 | e_pde=0.278291 | e_bc_zero=0.099971 | e_term=0.198562 | e_symm=0.614963 | e_traj=0.347748 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1500: total=1.700232 | e_pde=0.229872 | e_bc_zero=0.049770 | e_term=0.116625 | e_symm=0.603319 | e_traj=0.346028 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 1600: total=1.641349 | e_pde=0.197836 | e_bc_zero=0.020801 | e_term=0.063174 | e_symm=0.588550 | e_traj=0.343755 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 1700: total=1.603246 | e_pde=0.168870 | e_bc_zero=0.010341 | e_term=0.042577 | e_symm=0.560860 | e_traj=0.342850 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 1800: total=1.570889 | e_pde=0.149807 | e_bc_zero=0.005518 | e_term=0.026633 | e_symm=0.529862 | e_traj=0.341570 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 1900: total=1.544247 | e_pde=0.136467 | e_bc_zero=0.003482 | e_term=0.020169 | e_symm=0.500784 | e_traj=0.340169 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2000: total=1.519535 | e_pde=0.127269 | e_bc_zero=0.001692 | e_term=0.012160 | e_symm=0.470414 | e_traj=0.338624 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2100: total=1.499629 | e_pde=0.120670 | e_bc_zero=0.001758 | e_term=0.012209 | e_symm=0.440403 | e_traj=0.337557 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2200: total=1.481559 | e_pde=0.118609 | e_bc_zero=0.000735 | e_term=0.006339 | e_symm=0.411638 | e_traj=0.336141 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2300: total=1.466573 | e_pde=0.117275 | e_bc_zero=0.000518 | e_term=0.005112 | e_symm=0.387584 | e_traj=0.334796 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2400: total=1.453268 | e_pde=0.116002 | e_bc_zero=0.000382 | e_term=0.004581 | e_symm=0.367455 | e_traj=0.333481 | w={e_bc_zero:0.0992, e_pde:0.74, e_symm:0.37, e_term:0.0992, e_traj:3.69}
# Epoch 2500: total=1.439717 | e_pde=0.117713 | e_bc_zero=0.000162 | e_term=0.003823 | e_symm=0.346577 | e_traj=0.331584 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2600: total=1.424079 | e_pde=0.117594 | e_bc_zero=0.000109 | e_term=0.003803 | e_symm=0.327364 | e_traj=0.329690 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2700: total=1.412173 | e_pde=0.116234 | e_bc_zero=0.000125 | e_term=0.004486 | e_symm=0.305890 | e_traj=0.328873 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2800: total=1.400284 | e_pde=0.118144 | e_bc_zero=0.000045 | e_term=0.005641 | e_symm=0.287389 | e_traj=0.327092 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2900: total=1.386613 | e_pde=0.118121 | e_bc_zero=0.000026 | e_term=0.005664 | e_symm=0.270043 | e_traj=0.325131 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3000: total=1.374385 | e_pde=0.119757 | e_bc_zero=0.000013 | e_term=0.006066 | e_symm=0.253538 | e_traj=0.323131 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3100: total=1.360526 | e_pde=0.119608 | e_bc_zero=0.000012 | e_term=0.005167 | e_symm=0.234929 | e_traj=0.321295 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3200: total=1.347537 | e_pde=0.122110 | e_bc_zero=0.000012 | e_term=0.006089 | e_symm=0.220783 | e_traj=0.318663 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3300: total=1.333424 | e_pde=0.122498 | e_bc_zero=0.000020 | e_term=0.004573 | e_symm=0.205590 | e_traj=0.316323 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3400: total=1.319346 | e_pde=0.123967 | e_bc_zero=0.000016 | e_term=0.004021 | e_symm=0.190672 | e_traj=0.313722 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3500: total=1.305243 | e_pde=0.125257 | e_bc_zero=0.000009 | e_term=0.004545 | e_symm=0.174966 | e_traj=0.311199 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 3600: total=1.289466 | e_pde=0.124859 | e_bc_zero=0.000027 | e_term=0.003496 | e_symm=0.161521 | e_traj=0.308812 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 3700: total=1.276868 | e_pde=0.125489 | e_bc_zero=0.000019 | e_term=0.003071 | e_symm=0.148585 | e_traj=0.306580 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 3800: total=1.264193 | e_pde=0.124476 | e_bc_zero=0.000022 | e_term=0.003253 | e_symm=0.137031 | e_traj=0.304503 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 3900: total=1.251994 | e_pde=0.122914 | e_bc_zero=0.000022 | e_term=0.003560 | e_symm=0.124311 | e_traj=0.302783 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4000: total=1.240519 | e_pde=0.121164 | e_bc_zero=0.000027 | e_term=0.002348 | e_symm=0.114816 | e_traj=0.301013 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4100: total=1.229518 | e_pde=0.122640 | e_bc_zero=0.000017 | e_term=0.003484 | e_symm=0.105202 | e_traj=0.298663 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4200: total=1.220770 | e_pde=0.120170 | e_bc_zero=0.000055 | e_term=0.002152 | e_symm=0.097274 | e_traj=0.297625 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4300: total=1.210415 | e_pde=0.122728 | e_bc_zero=0.000009 | e_term=0.002384 | e_symm=0.090551 | e_traj=0.294964 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4400: total=1.200423 | e_pde=0.121914 | e_bc_zero=0.000001 | e_term=0.005118 | e_symm=0.082590 | e_traj=0.293143 | w={e_bc_zero:0.101, e_pde:0.748, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4500: total=1.192279 | e_pde=0.121908 | e_bc_zero=0.000006 | e_term=0.002763 | e_symm=0.076113 | e_traj=0.291650 | w={e_bc_zero:0.102, e_pde:0.755, e_symm:0.375, e_term:0.102, e_traj:3.67}
# Epoch 4600: total=1.182744 | e_pde=0.122188 | e_bc_zero=0.000018 | e_term=0.002180 | e_symm=0.069465 | e_traj=0.290302 | w={e_bc_zero:0.102, e_pde:0.755, e_symm:0.375, e_term:0.102, e_traj:3.67}
# Epoch 4700: total=1.174484 | e_pde=0.124996 | e_bc_zero=0.000016 | e_term=0.002699 | e_symm=0.064033 | e_traj=0.288012 | w={e_bc_zero:0.102, e_pde:0.755, e_symm:0.375, e_term:0.102, e_traj:3.67}
# Epoch 4800: total=1.167553 | e_pde=0.125141 | e_bc_zero=0.000000 | e_term=0.004679 | e_symm=0.059282 | e_traj=0.286523 | w={e_bc_zero:0.102, e_pde:0.755, e_symm:0.375, e_term:0.102, e_traj:3.67}
# Epoch 4900: total=1.160215 | e_pde=0.128196 | e_bc_zero=0.000000 | e_term=0.005579 | e_symm=0.054772 | e_traj=0.284328 | w={e_bc_zero:0.102, e_pde:0.755, e_symm:0.375, e_term:0.102, e_traj:3.67}
#
# === 3D stage: alpha=0.5, lambda=0.025 ===
# Epoch 0: total=20.364532 | e_pde=18.920372 | e_bc_zero=0.000047 | e_term=0.002123 | e_symm=0.053009 | e_traj=0.283488 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 100: total=2.529825 | e_pde=0.886629 | e_bc_zero=0.017881 | e_term=0.102081 | e_symm=0.375552 | e_traj=0.288685 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 200: total=2.238129 | e_pde=0.654679 | e_bc_zero=0.018858 | e_term=0.087477 | e_symm=0.263353 | e_traj=0.288228 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 300: total=2.095996 | e_pde=0.575292 | e_bc_zero=0.002248 | e_term=0.012704 | e_symm=0.196130 | e_traj=0.284229 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 400: total=1.818684 | e_pde=0.358585 | e_bc_zero=0.000639 | e_term=0.007067 | e_symm=0.134912 | e_traj=0.278374 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 500: total=1.750239 | e_pde=0.308565 | e_bc_zero=0.000244 | e_term=0.003505 | e_symm=0.093523 | e_traj=0.278907 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 600: total=1.291999 | e_pde=0.305668 | e_bc_zero=0.001306 | e_term=0.015955 | e_symm=0.075677 | e_traj=0.277209 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 700: total=1.259425 | e_pde=0.284614 | e_bc_zero=0.000148 | e_term=0.002926 | e_symm=0.063358 | e_traj=0.274206 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 800: total=1.271756 | e_pde=0.304505 | e_bc_zero=0.000860 | e_term=0.008348 | e_symm=0.061212 | e_traj=0.273624 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 900: total=1.220729 | e_pde=0.243641 | e_bc_zero=0.000695 | e_term=0.008010 | e_symm=0.060704 | e_traj=0.272183 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1000: total=1.253884 | e_pde=0.300132 | e_bc_zero=0.000133 | e_term=0.002715 | e_symm=0.056174 | e_traj=0.270340 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1100: total=1.191378 | e_pde=0.236127 | e_bc_zero=0.000001 | e_term=0.001478 | e_symm=0.063386 | e_traj=0.265696 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1200: total=1.281096 | e_pde=0.351964 | e_bc_zero=0.001329 | e_term=0.017853 | e_symm=0.044999 | e_traj=0.268057 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1300: total=1.213546 | e_pde=0.264831 | e_bc_zero=0.000000 | e_term=0.013463 | e_symm=0.075613 | e_traj=0.264434 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1400: total=1.134057 | e_pde=0.190247 | e_bc_zero=0.000019 | e_term=0.000985 | e_symm=0.039155 | e_traj=0.261942 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1500: total=1.163795 | e_pde=0.200453 | e_bc_zero=0.000000 | e_term=0.007659 | e_symm=0.083839 | e_traj=0.263270 | w={e_bc_zero:0.099, e_pde:0.739, e_symm:0.369, e_term:0.099, e_traj:3.69}
# Epoch 1600: total=1.101060 | e_pde=0.166337 | e_bc_zero=0.000065 | e_term=0.001860 | e_symm=0.035006 | e_traj=0.261259 | w={e_bc_zero:0.099, e_pde:0.739, e_symm:0.369, e_term:0.099, e_traj:3.69}
# ...
# Epoch 1800: total=0.895554 | e_pde=0.151123 | e_bc_zero=0.000008 | e_term=0.001231 | e_symm=0.040177 | e_traj=0.208207 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 1900: total=0.881308 | e_pde=0.119738 | e_bc_zero=0.000000 | e_term=0.001834 | e_symm=0.029686 | e_traj=0.211668 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2000: total=0.919616 | e_pde=0.134750 | e_bc_zero=0.000000 | e_term=0.008583 | e_symm=0.063718 | e_traj=0.215447 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2100: total=1.023943 | e_pde=0.288926 | e_bc_zero=0.000000 | e_term=0.030111 | e_symm=0.053790 | e_traj=0.213245 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2200: total=0.873619 | e_pde=0.114806 | e_bc_zero=0.000000 | e_term=0.000990 | e_symm=0.023504 | e_traj=0.211215 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2300: total=0.992569 | e_pde=0.229915 | e_bc_zero=0.000179 | e_term=0.001266 | e_symm=0.037837 | e_traj=0.218932 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2400: total=1.179705 | e_pde=0.439294 | e_bc_zero=0.000995 | e_term=0.045171 | e_symm=0.188230 | e_traj=0.211425 | w={e_bc_zero:0.0991, e_pde:0.739, e_symm:0.37, e_term:0.0991, e_traj:3.69}
# Epoch 2500: total=0.866790 | e_pde=0.116555 | e_bc_zero=0.000000 | e_term=0.001182 | e_symm=0.022273 | e_traj=0.209134 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2600: total=0.918323 | e_pde=0.154304 | e_bc_zero=0.000598 | e_term=0.006972 | e_symm=0.054800 | e_traj=0.212270 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2700: total=1.042830 | e_pde=0.300624 | e_bc_zero=0.000377 | e_term=0.019602 | e_symm=0.133113 | e_traj=0.208443 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2800: total=0.913562 | e_pde=0.177704 | e_bc_zero=0.000000 | e_term=0.009966 | e_symm=0.026157 | e_traj=0.209092 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 2900: total=0.954913 | e_pde=0.221037 | e_bc_zero=0.000000 | e_term=0.015615 | e_symm=0.055217 | e_traj=0.208530 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3000: total=1.012545 | e_pde=0.209524 | e_bc_zero=0.000000 | e_term=0.063071 | e_symm=0.069197 | e_traj=0.223774 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3100: total=0.892029 | e_pde=0.152056 | e_bc_zero=0.000000 | e_term=0.001696 | e_symm=0.026319 | e_traj=0.208613 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3200: total=0.917639 | e_pde=0.175052 | e_bc_zero=0.000005 | e_term=0.000813 | e_symm=0.025895 | e_traj=0.211005 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3300: total=0.908287 | e_pde=0.167344 | e_bc_zero=0.000008 | e_term=0.000703 | e_symm=0.027253 | e_traj=0.209884 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3400: total=1.252569 | e_pde=0.484310 | e_bc_zero=0.000000 | e_term=0.005105 | e_symm=0.186202 | e_traj=0.223494 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.37, e_term:0.1, e_traj:3.69}
# Epoch 3500: total=0.942809 | e_pde=0.218871 | e_bc_zero=0.000000 | e_term=0.002406 | e_symm=0.035530 | e_traj=0.208019 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 3600: total=0.936076 | e_pde=0.214715 | e_bc_zero=0.000000 | e_term=0.001871 | e_symm=0.033008 | e_traj=0.207357 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 3700: total=0.892617 | e_pde=0.149687 | e_bc_zero=0.000041 | e_term=0.001088 | e_symm=0.021226 | e_traj=0.209855 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 3800: total=0.865944 | e_pde=0.127059 | e_bc_zero=0.000000 | e_term=0.002202 | e_symm=0.025338 | e_traj=0.206728 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 3900: total=0.872281 | e_pde=0.133190 | e_bc_zero=0.000006 | e_term=0.001639 | e_symm=0.021373 | e_traj=0.207628 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4000: total=1.274152 | e_pde=0.265538 | e_bc_zero=0.003213 | e_term=0.019439 | e_symm=0.406975 | e_traj=0.250606 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4100: total=0.938494 | e_pde=0.155071 | e_bc_zero=0.000000 | e_term=0.015781 | e_symm=0.069884 | e_traj=0.215916 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4200: total=0.887353 | e_pde=0.150785 | e_bc_zero=0.000012 | e_term=0.001692 | e_symm=0.051219 | e_traj=0.205169 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4300: total=1.054865 | e_pde=0.342744 | e_bc_zero=0.000004 | e_term=0.001052 | e_symm=0.084737 | e_traj=0.208640 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4400: total=0.877497 | e_pde=0.141447 | e_bc_zero=0.000000 | e_term=0.006171 | e_symm=0.025712 | e_traj=0.206822 | w={e_bc_zero:0.1, e_pde:0.741, e_symm:0.371, e_term:0.1, e_traj:3.69}
# Epoch 4500: total=0.895579 | e_pde=0.103745 | e_bc_zero=0.000000 | e_term=0.006375 | e_symm=0.085301 | e_traj=0.213302 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4600: total=0.864507 | e_pde=0.114403 | e_bc_zero=0.000003 | e_term=0.001147 | e_symm=0.021440 | e_traj=0.209367 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4700: total=0.874827 | e_pde=0.141572 | e_bc_zero=0.000025 | e_term=0.002437 | e_symm=0.030869 | e_traj=0.205704 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4800: total=0.971491 | e_pde=0.201566 | e_bc_zero=0.000001 | e_term=0.001013 | e_symm=0.069350 | e_traj=0.216001 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.372, e_term:0.101, e_traj:3.68}
# Epoch 4900: total=1.052368 | e_pde=0.311744 | e_bc_zero=0.000728 | e_term=0.035072 | e_symm=0.147929 | e_traj=0.206864 | w={e_bc_zero:0.1, e_pde:0.743, e_symm:0.372, e_term:0.101, e_traj:3.68}
#
# === 3D stage: alpha=1.0, lambda=0.05 ===
# Epoch 0: total=20.923885 | e_pde=19.811722 | e_bc_zero=0.000000 | e_term=0.002948 | e_symm=0.073590 | e_traj=0.215015 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 100: total=1.298575 | e_pde=0.222240 | e_bc_zero=0.000000 | e_term=0.129014 | e_symm=0.044956 | e_traj=0.208191 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 200: total=1.224903 | e_pde=0.188831 | e_bc_zero=0.000000 | e_term=0.040473 | e_symm=0.031472 | e_traj=0.203258 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 300: total=1.199557 | e_pde=0.179732 | e_bc_zero=0.000000 | e_term=0.017947 | e_symm=0.027730 | e_traj=0.200833 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 400: total=1.191387 | e_pde=0.179095 | e_bc_zero=0.000000 | e_term=0.009757 | e_symm=0.029087 | e_traj=0.199354 | w={e_bc_zero:0.1, e_pde:1, e_symm:0.5, e_term:0.1, e_traj:5}
# Epoch 500: total=1.184221 | e_pde=0.176144 | e_bc_zero=0.000001 | e_term=0.004190 | e_symm=0.026305 | e_traj=0.198901 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 600: total=0.879303 | e_pde=0.172368 | e_bc_zero=0.000000 | e_term=0.004354 | e_symm=0.026485 | e_traj=0.198444 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 700: total=0.880208 | e_pde=0.169255 | e_bc_zero=0.000000 | e_term=0.002950 | e_symm=0.029057 | e_traj=0.199080 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 800: total=0.877045 | e_pde=0.177047 | e_bc_zero=0.000001 | e_term=0.002015 | e_symm=0.025914 | e_traj=0.197007 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 900: total=0.874467 | e_pde=0.172598 | e_bc_zero=0.000001 | e_term=0.003903 | e_symm=0.024859 | e_traj=0.197274 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1000: total=0.872562 | e_pde=0.171704 | e_bc_zero=0.000010 | e_term=0.002150 | e_symm=0.027222 | e_traj=0.196740 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1100: total=0.882698 | e_pde=0.186753 | e_bc_zero=0.000006 | e_term=0.001549 | e_symm=0.026725 | e_traj=0.196509 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1200: total=0.878743 | e_pde=0.180442 | e_bc_zero=0.000001 | e_term=0.001528 | e_symm=0.023029 | e_traj=0.197081 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1300: total=0.868964 | e_pde=0.165037 | e_bc_zero=0.000001 | e_term=0.003226 | e_symm=0.025689 | e_traj=0.197241 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1400: total=1.060706 | e_pde=0.366236 | e_bc_zero=0.000000 | e_term=0.006754 | e_symm=0.050650 | e_traj=0.205822 | w={e_bc_zero:0.0746, e_pde:0.746, e_symm:0.373, e_term:0.0746, e_traj:3.73}
# Epoch 1500: total=0.964165 | e_pde=0.264051 | e_bc_zero=0.000000 | e_term=0.003173 | e_symm=0.032337 | e_traj=0.202289 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 1600: total=0.902644 | e_pde=0.210040 | e_bc_zero=0.000004 | e_term=0.002256 | e_symm=0.022606 | e_traj=0.200036 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 1700: total=0.910895 | e_pde=0.197911 | e_bc_zero=0.000000 | e_term=0.006143 | e_symm=0.045669 | e_traj=0.202281 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 1800: total=0.877662 | e_pde=0.164641 | e_bc_zero=0.000000 | e_term=0.004226 | e_symm=0.039701 | e_traj=0.200576 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 1900: total=1.077401 | e_pde=0.363391 | e_bc_zero=0.000000 | e_term=0.005775 | e_symm=0.100032 | e_traj=0.208889 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2000: total=0.886640 | e_pde=0.193753 | e_bc_zero=0.000000 | e_term=0.001121 | e_symm=0.021485 | e_traj=0.199099 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2100: total=1.068784 | e_pde=0.425190 | e_bc_zero=0.000125 | e_term=0.010392 | e_symm=0.068139 | e_traj=0.197281 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2200: total=0.863198 | e_pde=0.176036 | e_bc_zero=0.000010 | e_term=0.001453 | e_symm=0.028442 | e_traj=0.195586 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2300: total=0.914811 | e_pde=0.235840 | e_bc_zero=0.000046 | e_term=0.003868 | e_symm=0.044677 | e_traj=0.195929 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2400: total=1.225638 | e_pde=0.556309 | e_bc_zero=0.000008 | e_term=0.001188 | e_symm=0.099551 | e_traj=0.210669 | w={e_bc_zero:0.099, e_pde:0.738, e_symm:0.369, e_term:0.099, e_traj:3.7}
# Epoch 2500: total=0.874860 | e_pde=0.193598 | e_bc_zero=0.000002 | e_term=0.002907 | e_symm=0.034835 | e_traj=0.194560 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 2600: total=0.969588 | e_pde=0.220806 | e_bc_zero=0.001397 | e_term=0.042415 | e_symm=0.232292 | e_traj=0.194046 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 2700: total=0.994950 | e_pde=0.344107 | e_bc_zero=0.000086 | e_term=0.008642 | e_symm=0.025692 | e_traj=0.197906 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 2800: total=0.950860 | e_pde=0.275500 | e_bc_zero=0.000100 | e_term=0.011399 | e_symm=0.061225 | e_traj=0.196020 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 2900: total=0.891844 | e_pde=0.217016 | e_bc_zero=0.000012 | e_term=0.002154 | e_symm=0.028932 | e_traj=0.195170 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3000: total=1.126106 | e_pde=0.477327 | e_bc_zero=0.000022 | e_term=0.001745 | e_symm=0.036276 | e_traj=0.205998 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3100: total=1.062679 | e_pde=0.303093 | e_bc_zero=0.000000 | e_term=0.004214 | e_symm=0.166553 | e_traj=0.210476 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3200: total=0.856297 | e_pde=0.159812 | e_bc_zero=0.000030 | e_term=0.003036 | e_symm=0.046521 | e_traj=0.195165 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3300: total=0.882230 | e_pde=0.168980 | e_bc_zero=0.000026 | e_term=0.003765 | e_symm=0.080611 | e_traj=0.196938 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3400: total=0.832231 | e_pde=0.129459 | e_bc_zero=0.000001 | e_term=0.003118 | e_symm=0.023637 | e_traj=0.196979 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.369, e_term:0.1, e_traj:3.7}
# Epoch 3500: total=0.867351 | e_pde=0.136524 | e_bc_zero=0.000000 | e_term=0.006963 | e_symm=0.079937 | e_traj=0.199356 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 3600: total=1.277214 | e_pde=0.698363 | e_bc_zero=0.000420 | e_term=0.031567 | e_symm=0.071932 | e_traj=0.198328 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 3700: total=0.903557 | e_pde=0.207728 | e_bc_zero=0.000000 | e_term=0.002129 | e_symm=0.030221 | e_traj=0.199925 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 3800: total=1.164681 | e_pde=0.487335 | e_bc_zero=0.000002 | e_term=0.004699 | e_symm=0.084997 | e_traj=0.209371 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 3900: total=0.961626 | e_pde=0.222645 | e_bc_zero=0.000000 | e_term=0.005732 | e_symm=0.095458 | e_traj=0.206113 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4000: total=0.850859 | e_pde=0.153617 | e_bc_zero=0.000013 | e_term=0.002097 | e_symm=0.066684 | e_traj=0.192848 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4100: total=0.997496 | e_pde=0.339888 | e_bc_zero=0.000220 | e_term=0.003073 | e_symm=0.049439 | e_traj=0.197078 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4200: total=0.978658 | e_pde=0.249580 | e_bc_zero=0.000716 | e_term=0.032322 | e_symm=0.211227 | e_traj=0.193177 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4300: total=1.063940 | e_pde=0.384210 | e_bc_zero=0.000717 | e_term=0.035872 | e_symm=0.151911 | e_traj=0.195191 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4400: total=0.839404 | e_pde=0.121977 | e_bc_zero=0.000000 | e_term=0.005683 | e_symm=0.050500 | e_traj=0.197555 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4500: total=1.339315 | e_pde=0.653089 | e_bc_zero=0.029922 | e_term=0.154875 | e_symm=0.156167 | e_traj=0.211679 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4600: total=1.000538 | e_pde=0.295712 | e_bc_zero=0.000000 | e_term=0.006299 | e_symm=0.083174 | e_traj=0.203275 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4700: total=0.949176 | e_pde=0.207264 | e_bc_zero=0.000210 | e_term=0.006356 | e_symm=0.055477 | e_traj=0.209730 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4800: total=0.824617 | e_pde=0.118674 | e_bc_zero=0.000002 | e_term=0.003807 | e_symm=0.024972 | e_traj=0.196780 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Epoch 4900: total=0.901236 | e_pde=0.200645 | e_bc_zero=0.000001 | e_term=0.003007 | e_symm=0.031736 | e_traj=0.200527 | w={e_bc_zero:0.1, e_pde:0.736, e_symm:0.365, e_term:0.1, e_traj:3.7}
# Training completed in 207.80 s total.
# Done. Checkpoints in: /content/runs/pinn_oe

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/pinn_oe/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_history.pkl (deflated 57%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/d/62bb7d6f41ac59cf4674432bcd260b0f (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/b0ccc77b4c14f4fca87fbfdd5d47d8d1 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/e2fb382c80d3375f7f73914b42c199c6 (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/28d8ee2386968463dea83bccb2d51b62 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/d/6fca51b228b6ad9572c9908ea61d748f (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p5_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p75_config.json (deflated 57%)
#   adding: content/runs/pinn_oe/2d_lam0_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/d/2f1957b93ec29c2c4b39d4ae87959e3c (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/52fdc89281027eabeb9d21054efdfdbf (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/bc18587892233c56b12f389df94234c5 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/fc2b28ea2ce5e17fab2792e2b11b2f81 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/d/4074724cb447a736fb093afa199d67ab (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_CHECKPOINT_METADATA (deflated 38%)
#   adding: content/runs/pinn_oe/alpha_0p25_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/d/58269bd1e3fc740e5591685f9ec24b92 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/7227894e15dfa4ae4e8a76aef764491c (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/b7b4d2ad547c7ecf227a1e41d53776dc (deflated 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/dc0636401e90c9a2642f84654474b421 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/d/1951a744edc1803ab0d368362998b616 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/manifest.ocdbt (deflated 6%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_0p75_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_0p5_config.json (deflated 57%)
#   adding: content/runs/pinn_oe/alpha_0p25_history.pkl (deflated 60%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/d/ca45c51d71011d9094b483dd5dcaf69d (deflated 1%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/f438079640095cf9d1088ec4808c89f6 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/3847280604800432077494b7b0cd9a54 (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/2036ed53215ff307340bbaa88835cd7c (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/d/d702c5b97d3a198b50247f623914a858 (deflated 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/2d_lam0_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_CHECKPOINT_METADATA (deflated 40%)
#   adding: content/runs/pinn_oe/2d_lam0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_1p0_history.pkl (deflated 57%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/d/69c2fb305798e33998820858520c4de5 (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/8943f7fd6ad08ac96aac1b89112be926 (deflated 1%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/37be7d9c590186a9347383ba3d7968d5 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/5b8dc8231fe49837045f227808cf1f70 (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/d/2152b8955b8aa29fb8f25acdeeb07b5b (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/ocdbt.process_0/manifest.ocdbt (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_sharding (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/manifest.ocdbt (deflated 5%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/ (stored 0%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/array_metadatas/process_0 (deflated 85%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_CHECKPOINT_METADATA (deflated 39%)
#   adding: content/runs/pinn_oe/alpha_1p0_params/_METADATA (deflated 87%)
#   adding: content/runs/pinn_oe/alpha_1p0_config.json (deflated 57%)
#   adding: content/runs/pinn_oe/2d_lam0_config.json (deflated 56%)
#   adding: content/runs/pinn_oe/alpha_0p25_config.json (deflated 57%)
#   adding: content/runs/pinn_oe/alpha_0p75_history.pkl (deflated 57%)
